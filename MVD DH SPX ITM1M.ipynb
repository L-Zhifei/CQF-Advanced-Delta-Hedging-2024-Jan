# %%
# %pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import scipy.stats as stats

# %%
import os
os.getcwd()
# Out:
# '/Users/zhifei_li/Desktop/Knowledge/Investment Research/CQF/Courses/Final Project/Advanced Hedging with Greeks/Workings'

# %%
### Set working directory
dir_path = "/Users/zhifei_li/Desktop/Knowledge/Investment Research/CQF/Courses/Final Project/Advanced Hedging with Greeks/Workings"
os.chdir(dir_path)

# %% [markdown]
# # 0.1. Data Import

# %% [markdown]
# ## SPX Data

# %%
spx_path = "/Data/Index/SPX Index"

# %%
import os

# %%
def combine_year_files(year_folder_path, year):
    # Initialize an empty list to store DataFrames
    dataframes = []

    # Iterate over each month (01 to 12)
    for month in range(1, 13):
        file_name = f"spx_eod_{year}{month:02d}.txt"
        file_path = os.path.join(year_folder_path, file_name)
        
        if os.path.exists(file_path):
            # Read the data file into a DataFrame
            df = pd.read_csv(file_path, delimiter=',')  
            dataframes.append(df)
        else:
            print(f"File {file_path} does not exist.")

    # Concatenate all DataFrames into one
    if dataframes:
        combined_df = pd.concat(dataframes, ignore_index=True)
        return combined_df
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no files were read

# Example usage
year_folder_path = dir_path + spx_path + '/spx_eod_2010'  # Replace with your specific year folder path
year = 2010  # Specify the year
df_2010 = combine_year_files(year_folder_path, year)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')

# %%
year_folder_path = dir_path + spx_path + '/spx_eod_2011'
year = 2011  # Specify the year
df_2011 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2012'
year = 2012  # Specify the year
df_2012 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2013'
year = 2013  # Specify the year
df_2013 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2014'
year = 2014  # Specify the year
df_2014 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2015'
year = 2015  # Specify the year
df_2015 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2016'
year = 2016  # Specify the year
df_2016 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2017'
year = 2017  # Specify the year
df_2017 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2018'
year = 2018  # Specify the year
df_2018 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2019'
year = 2019  # Specify the year
df_2019 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2020'
year = 2020  # Specify the year
df_2020 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2021'
year = 2021  # Specify the year
df_2021 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2022'
year = 2022  # Specify the year
df_2022 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2023'
year = 2023  # Specify the year
df_2023 = combine_year_files(year_folder_path, year)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')

# %%
df_201023 = pd.concat([df_2010,df_2011,df_2012,df_2013,df_2014,df_2015,df_2016,df_2017,df_2018,df_2019,df_2020,df_2021,df_2022,df_2023])

# %%
len(df_201023)
# Out:
# 15556477

# %% [markdown]
# ## SPX Index Data in full

# %%
df_201023.head()
# Out:
#    [QUOTE_UNIXTIME]   [QUOTE_READTIME]  [QUOTE_DATE]   [QUOTE_TIME_HOURS]  \
# 0        1262638800   2010-01-04 16:00    2010-01-04                 16.0
# 1        1262638800   2010-01-04 16:00    2010-01-04                 16.0
# 2        1262638800   2010-01-04 16:00    2010-01-04                 16.0
# 3        1262638800   2010-01-04 16:00    2010-01-04                 16.0
# 4        1262638800   2010-01-04 16:00    2010-01-04                 16.0
#
#     [UNDERLYING_LAST]  [EXPIRE_DATE]   [EXPIRE_UNIX]   [DTE]  [C_DELTA]  \
# 0             1132.99     2010-01-07      1262898000     3.0   1.000000
# 1             1132.99     2010-01-07      1262898000     3.0   1.000000
# 2             1132.99     2010-01-07      1262898000     3.0   1.000000
# 3             1132.99     2010-01-07      1262898000     3.0   1.000000
# 4             1132.99     2010-01-07      1262898000     3.0   1.000000
#
#    [C_GAMMA]  ...   [P_LAST]   [P_DELTA]  [P_GAMMA]   [P_VEGA]   [P_THETA]  \
# 0   0.000000  ...   0.050000   -0.000770   0.000040   0.004390   -0.021160
# 1   0.000000  ...   0.050000   -0.002030   0.000060   0.009110   -0.040560
# 2   0.000000  ...   0.100000   -0.003690   0.000220   0.013020   -0.058980
# 3   0.000000  ...   0.150000   -0.008940   0.000380   0.027860   -0.127580
# 4   0.000000  ...   0.200000   -0.012510   0.000660   0.038570   -0.156920
#
#       [P_RHO]     [P_IV]   [P_VOLUME]  [STRIKE_DISTANCE]  \
# 0   -0.000490   0.640130   550.000000              208.0
# 1    0.000000   0.598590                           183.0
# 2   -0.000710   0.538850                           158.0
# 3   -0.000860   0.502730                           133.0
# 4   -0.001470   0.427250   720.000000              108.0
#
#     [STRIKE_DISTANCE_PCT]
# 0                   0.184
# 1                   0.162
# 2                   0.139
# 3                   0.117
# 4                   0.095
#
# [5 rows x 33 columns]

# %%
df_201023.columns.values
# Out:
# array(['[QUOTE_UNIXTIME]', ' [QUOTE_READTIME]', ' [QUOTE_DATE]',
#        ' [QUOTE_TIME_HOURS]', ' [UNDERLYING_LAST]', ' [EXPIRE_DATE]',
#        ' [EXPIRE_UNIX]', ' [DTE]', ' [C_DELTA]', ' [C_GAMMA]',
#        ' [C_VEGA]', ' [C_THETA]', ' [C_RHO]', ' [C_IV]', ' [C_VOLUME]',
#        ' [C_LAST]', ' [C_SIZE]', ' [C_BID]', ' [C_ASK]', ' [STRIKE]',
#        ' [P_BID]', ' [P_ASK]', ' [P_SIZE]', ' [P_LAST]', ' [P_DELTA]',
#        ' [P_GAMMA]', ' [P_VEGA]', ' [P_THETA]', ' [P_RHO]', ' [P_IV]',
#        ' [P_VOLUME]', ' [STRIKE_DISTANCE]', ' [STRIKE_DISTANCE_PCT]'],
#       dtype=object)

# %%
df_201023.columns = ['unixtime','time','date','hours','underlying','expiry','expire_unit','dte','c_delta','c_gamma','c_vega','c_theta','c_rho','c_iv','c_volume','c_last','c_size','c_bid','c_ask','strike',
                 'p_bid','p_ask','p_size','p_last','p_delta','p_gamma','p_vega','p_theta','p_rho','p_iv','p_volume','strike_distance','strike_distance_pct']

# %%
unique_strik_df_201023 = df_201023['strike'].unique()

# %%
unique_strik_df_201023.shape
# Out:
# (1029,)

# %% [markdown]
# # 0.2. Bucketing

# %%
df_201023['c_delta'] = df_201023['c_delta'].apply(pd.to_numeric, errors='coerce')

# %%
#bucketing by moneyness
def moneyness_bucketing(value):
    if 0.45 <= abs(value) <= 0.55:
        return 'ATM'
    elif 0 <= abs(value) <= 0.4:
        return 'OTM'
    elif 0.6 <= abs(value) <= 1:
        return 'ITM'
    else:
        return None

df_201023['moneyness_bucket'] = df_201023['c_delta'].apply(moneyness_bucketing)

# %%
# bucketing by maturities
def days_to_maturity_bucketing(value):
    if 0<=value<=30:
        return '1M'
    elif 31<=value<=60:
        return '2M'
    elif 61<=value<=91:
        return '3M'
    elif 92<=value<=122:
        return '4M'
    elif 123<=value<=182:
        return '6M'
    elif 183<=value<=365:
        return '12M'
    elif value >= 366:
        return '12MM'
    else:
        return None

df_201023['maturity_bucket'] = df_201023['dte'].apply(days_to_maturity_bucketing)

# %%
df_201023.head()
# Out:
#      unixtime               time         date  hours  underlying       expiry  \
# 0  1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99   2010-01-07
# 1  1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99   2010-01-07
# 2  1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99   2010-01-07
# 3  1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99   2010-01-07
# 4  1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99   2010-01-07
#
#    expire_unit  dte  c_delta    c_gamma  ...    p_gamma     p_vega  \
# 0   1262898000  3.0      1.0   0.000000  ...   0.000040   0.004390
# 1   1262898000  3.0      1.0   0.000000  ...   0.000060   0.009110
# 2   1262898000  3.0      1.0   0.000000  ...   0.000220   0.013020
# 3   1262898000  3.0      1.0   0.000000  ...   0.000380   0.027860
# 4   1262898000  3.0      1.0   0.000000  ...   0.000660   0.038570
#
#       p_theta       p_rho       p_iv     p_volume strike_distance  \
# 0   -0.021160   -0.000490   0.640130   550.000000           208.0
# 1   -0.040560    0.000000   0.598590                        183.0
# 2   -0.058980   -0.000710   0.538850                        158.0
# 3   -0.127580   -0.000860   0.502730                        133.0
# 4   -0.156920   -0.001470   0.427250   720.000000           108.0
#
#   strike_distance_pct moneyness_bucket  maturity_bucket
# 0               0.184              ITM               1M
# 1               0.162              ITM               1M
# 2               0.139              ITM               1M
# 3               0.117              ITM               1M
# 4               0.095              ITM               1M
#
# [5 rows x 35 columns]

# %%
df_201023.isna().sum()
# Out:
# unixtime                    0
# time                        0
# date                        0
# hours                       0
# underlying                  0
# expiry                      0
# expire_unit                 0
# dte                         0
# c_delta                   534
# c_gamma                     0
# c_vega                      0
# c_theta                     0
# c_rho                       0
# c_iv                        0
# c_volume                    0
# c_last                      0
# c_size                      0
# c_bid                       0
# c_ask                       0
# strike                      0
# p_bid                       0
# p_ask                       0
# p_size                      0
# p_last                      0
# p_delta                     0
# p_gamma                     0
# p_vega                      0
# p_theta                     0
# p_rho                       0
# p_iv                        0
# p_volume                    0
# strike_distance             0
# strike_distance_pct         0
# moneyness_bucket       616786
# maturity_bucket        101625
# dtype: int64

# %%
df_201023[df_201023['moneyness_bucket'].isna()]
# Out:
#            unixtime               time         date  hours  underlying  \
# 129      1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99
# 132      1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99
# 292      1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99
# 293      1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99
# 298      1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99
# ...             ...                ...          ...    ...         ...
# 2009065  1703883600   2023-12-29 16:00   2023-12-29   16.0     4772.17
# 2009066  1703883600   2023-12-29 16:00   2023-12-29   16.0     4772.17
# 2009067  1703883600   2023-12-29 16:00   2023-12-29   16.0     4772.17
# 2009073  1703883600   2023-12-29 16:00   2023-12-29   16.0     4772.17
# 2009074  1703883600   2023-12-29 16:00   2023-12-29   16.0     4772.17
#
#               expiry  expire_unit     dte  c_delta    c_gamma  ...    p_gamma  \
# 129       2010-01-14   1263502800    10.0  0.58839   0.011950  ...   0.012100
# 132       2010-01-14   1263502800    10.0  0.40086   0.012590  ...   0.013180
# 292       2010-02-18   1266526800    45.0  0.59339   0.005330  ...   0.005240
# 293       2010-02-18   1266526800    45.0  0.56734   0.005400  ...   0.005420
# 298       2010-02-18   1266526800    45.0  0.42435   0.005720  ...   0.005780
# ...              ...          ...     ...      ...        ...  ...        ...
# 2009065   2029-12-21   1892581200  2184.0  0.57589    0.00013  ...    0.00036
# 2009066   2029-12-21   1892581200  2184.0  0.56424    0.00013  ...     0.0004
# 2009067   2029-12-21   1892581200  2184.0  0.55204    0.00007  ...    0.00041
# 2009073   2029-12-21   1892581200  2184.0  0.43376    0.00016  ...        0.0
# 2009074   2029-12-21   1892581200  2184.0  0.40602    0.00015  ...        0.0
#
#             p_vega     p_theta       p_rho       p_iv     p_volume  \
# 129       0.764450   -0.630970   -0.143770   0.163730
# 132       0.755020   -0.590090   -0.211400   0.148310    45.000000
# 292       1.557070   -0.343420   -0.610140   0.184290   294.000000
# 293       1.577770   -0.345300   -0.649800   0.181600    83.000000
# 298       1.567850   -0.330330   -0.868610   0.167770     1.000000
# ...            ...         ...         ...        ...          ...
# 2009065   37.07644    -0.05115   -64.61351   0.174590
# 2009066   36.46357     -0.0457     -63.349   0.167670
# 2009067   35.19295    -0.03984   -60.73328   0.161020
# 2009073        0.0         0.0         0.0
# 2009074        0.0         0.0         0.0
#
#         strike_distance strike_distance_pct moneyness_bucket  maturity_bucket
# 129                 8.0               0.007             None               1M
# 132                 7.0               0.006             None               1M
# 292                18.0               0.016             None               2M
# 293                13.0               0.011             None               2M
# 298                12.0               0.011             None               2M
# ...                 ...                 ...              ...              ...
# 2009065           327.8               0.069             None             12MM
# 2009066           427.8               0.090             None             12MM
# 2009067           527.8               0.111             None             12MM
# 2009073          1427.8               0.299             None             12MM
# 2009074          1627.8               0.341             None             12MM
#
# [616786 rows x 35 columns]

# %%
# qqq_2012to2023_K210 = qqq_2012to2023[qqq_2012to2023['strike'] == 210]

# %%
#len(qqq_2012to2023_K210)

# %%
df_201023_call = df_201023[['date','underlying','expiry','dte','c_delta','c_gamma','c_vega','c_theta','c_rho','c_iv','c_volume','c_last','c_size','c_bid','c_ask','strike','moneyness_bucket','maturity_bucket']]

# %% [markdown]
# ### Remove the null IV or replace with previous IV

# %% [markdown]
# #### Remove null IV

# %%
df_201023_call_nn = df_201023_call[df_201023_call['c_iv'] != ' ']
#might take 17.1s

# %% [markdown]
# # Initial Attempt on Bucket of 1M and ATM

# %%
df1M_ATM = df_201023_call_nn[(df_201023_call_nn['moneyness_bucket'] == "ATM")&(df_201023_call_nn['maturity_bucket'] == '1M')]

# %%
len(df1M_ATM)
# Out:
# 152189

# %%
#check for the nulls in all columns within this bucket
df1M_ATM.isnull().sum()
# Out:
# date                0
# underlying          0
# expiry              0
# dte                 0
# c_delta             0
# c_gamma             0
# c_vega              0
# c_theta             0
# c_rho               0
# c_iv                0
# c_volume            0
# c_last              0
# c_size              0
# c_bid               0
# c_ask               0
# strike              0
# moneyness_bucket    0
# maturity_bucket     0
# dtype: int64

# %%
df_201023_call_nn['c_iv'] = df_201023_call_nn['c_iv'].apply(pd.to_numeric, errors='coerce')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1875108132.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['c_iv'] = df_201023_call_nn['c_iv'].apply(pd.to_numeric, errors='coerce')

# %%
# some IVs are not null but empty, like " "
#check for the nulls in all columns within this bucket
df_201023_call_nn.isnull().sum()
# Out:
# date                     0
# underlying               0
# expiry                   0
# dte                      0
# c_delta                  0
# c_gamma                  0
# c_vega                   0
# c_theta                  0
# c_rho                    0
# c_iv                     0
# c_volume                 0
# c_last                   0
# c_size                   0
# c_bid                    0
# c_ask                    0
# strike                   0
# moneyness_bucket    616252
# maturity_bucket      79922
# dtype: int64

# %%
df_201023_call_nn['1m_c_iv'] = np.nan
df_201023_call_nn['3m_c_iv'] = np.nan
df_201023_call_nn['6m_c_iv'] = np.nan
df_201023_call_nn['9m_c_iv'] = np.nan
df_201023_call_nn['12m_c_iv'] = np.nan
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/508980085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['1m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/508980085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['3m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/508980085.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['6m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/508980085.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['9m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/508980085.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['12m_c_iv'] = np.nan

# %%
df_201023_call_nn.isnull().sum()
# Out:
# date                       0
# underlying                 0
# expiry                     0
# dte                        0
# c_delta                    0
# c_gamma                    0
# c_vega                     0
# c_theta                    0
# c_rho                      0
# c_iv                       0
# c_volume                   0
# c_last                     0
# c_size                     0
# c_bid                      0
# c_ask                      0
# strike                     0
# moneyness_bucket      616252
# maturity_bucket        79922
# 1m_c_iv             11900876
# 3m_c_iv             11900876
# 6m_c_iv             11900876
# 9m_c_iv             11900876
# 12m_c_iv            11900876
# dtype: int64

# %% [markdown]
# # 1. Get the Term Structure of IV for 1M, 3M, 6M, 9M and 12M expiry

# %%
df_201023_call_nn.dtypes
# Out:
# date                 object
# underlying          float64
# expiry               object
# dte                 float64
# c_delta             float64
# c_gamma              object
# c_vega               object
# c_theta              object
# c_rho                object
# c_iv                float64
# c_volume             object
# c_last               object
# c_size               object
# c_bid                object
# c_ask                object
# strike              float64
# moneyness_bucket     object
# maturity_bucket      object
# 1m_c_iv             float64
# 3m_c_iv             float64
# 6m_c_iv             float64
# 9m_c_iv             float64
# 12m_c_iv            float64
# dtype: object

# %%
df_201023_call_nn['date'] = pd.to_datetime(df_201023_call_nn['date'])
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2378075591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['date'] = pd.to_datetime(df_201023_call_nn['date'])

# %%
df_201023_call_nn['after_1M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 1)
df_201023_call_nn['after_3M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 3)
df_201023_call_nn['after_6M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 6)
df_201023_call_nn['after_9M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 9)
df_201023_call_nn['after_12M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 12)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3939291843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_1M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 1)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3939291843.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_3M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 3)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3939291843.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_6M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 6)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3939291843.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_9M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 9)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3939291843.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_12M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 12)

# %%
df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_1M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_3M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_6M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_9M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_12M'], df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/4158665109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_1M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/4158665109.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_3M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/4158665109.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_6M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/4158665109.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_9M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/4158665109.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_12M'], df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn.dtypes
# Out:
# date                datetime64[ns]
# underlying                 float64
# expiry                      object
# dte                        float64
# c_delta                    float64
# c_gamma                     object
# c_vega                      object
# c_theta                     object
# c_rho                       object
# c_iv                       float64
# c_volume                    object
# c_last                      object
# c_size                      object
# c_bid                       object
# c_ask                       object
# strike                     float64
# moneyness_bucket            object
# maturity_bucket             object
# 1m_c_iv                    float64
# 3m_c_iv                    float64
# 6m_c_iv                    float64
# 9m_c_iv                    float64
# 12m_c_iv                   float64
# after_1M            datetime64[ns]
# after_3M            datetime64[ns]
# after_6M            datetime64[ns]
# after_9M            datetime64[ns]
# after_12M           datetime64[ns]
# dtype: object

# %%
df_201023_call_nn['expiry'] = pd.to_datetime(df_201023_call_nn['expiry'])
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3893983512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['expiry'] = pd.to_datetime(df_201023_call_nn['expiry'])

# %%
df_201023_call_nn['c_vega'] = df_201023_call_nn['c_vega'].apply(pd.to_numeric, errors='coerce')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3475713582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['c_vega'] = df_201023_call_nn['c_vega'].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# sometimes there is no IV data on the exact expiry date, so we can remove them or find the nearest as it is. Let's try the second approach first.
# ## Approach1: Find the nearest IV if no IV at certain maturity date exists

# %%
# lots of dates there is not expiry date exactly equals the after_1M, 3M, 6M, 9M and 12M, so we fill in with the nearest expiry to these after_XM dates
df_201023_call_nn['diff_1M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_1M']).dt.days.abs()
min_diff_idx_1M = df_201023_call_nn.groupby('date')['diff_1M'].idxmin()
df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_1M), df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3919769646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['diff_1M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_1M']).dt.days.abs()
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3919769646.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_1M), df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn['diff_3M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_3M']).dt.days.abs()
min_diff_idx_3M = df_201023_call_nn.groupby('date')['diff_3M'].idxmin()
df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_3M), df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1324646977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['diff_3M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_3M']).dt.days.abs()
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1324646977.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_3M), df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn['diff_6M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_6M']).dt.days.abs()
min_diff_idx_6M = df_201023_call_nn.groupby('date')['diff_6M'].idxmin()
df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_6M), df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/228897655.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['diff_6M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_6M']).dt.days.abs()
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/228897655.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_6M), df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn['diff_9M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_9M']).dt.days.abs()
min_diff_idx_9M = df_201023_call_nn.groupby('date')['diff_9M'].idxmin()
df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_9M), df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3914460780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['diff_9M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_9M']).dt.days.abs()
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3914460780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_9M), df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn['diff_12M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_12M']).dt.days.abs()
min_diff_idx_12M = df_201023_call_nn.groupby('date')['diff_12M'].idxmin()
df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_12M), df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2006450873.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['diff_12M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_12M']).dt.days.abs()
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2006450873.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_12M), df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn[df_201023_call_nn['date'] == '2023-01-03']['1m_c_iv']
# Out:
# Series([], Name: 1m_c_iv, dtype: float64)

# %%
def grouped_bfill(group):
    group['1m_c_iv'] = group['1m_c_iv'].fillna(method = "bfill")
    group['3m_c_iv'] = group['3m_c_iv'].fillna(method = "bfill")
    group['6m_c_iv'] = group['6m_c_iv'].fillna(method = "bfill")
    group['9m_c_iv'] = group['9m_c_iv'].fillna(method = "bfill")
    group['12m_c_iv'] = group['12m_c_iv'].fillna(method = "bfill")
    return group

# %%
df_201023_call_nn = df_201023_call_nn.groupby('date').apply(grouped_bfill)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1538367704.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   group['1m_c_iv'] = group['1m_c_iv'].fillna(method = "bfill")
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1538367704.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   group['3m_c_iv'] = group['3m_c_iv'].fillna(method = "bfill")
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1538367704.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   group['6m_c_iv'] = group['6m_c_iv'].fillna(method = "bfill")
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1538367704.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   group['9m_c_iv'] = group['9m_c_iv'].fillna(method = "bfill")
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1538367704.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   group['12m_c_iv'] = group['12m_c_iv'].fillna(method = "bfill")
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2635986667.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_201023_call_nn = df_201023_call_nn.groupby('date').apply(grouped_bfill)

# %%
# drop the after_XM
df_201023_call_nn = df_201023_call_nn.drop(columns = ['after_1M','after_3M','after_6M','after_9M','after_12M','diff_1M','diff_3M','diff_6M','diff_9M','diff_12M'])

# %%
df_201023_call_nn_nearest = df_201023_call_nn

# %%
df_201023_call_nn_nearest.isna().sum()
# Out:
# date                      0
# underlying                0
# expiry                    0
# dte                       0
# c_delta                   0
# c_gamma                   0
# c_vega                    0
# c_theta                   0
# c_rho                     0
# c_iv                      0
# c_volume                  0
# c_last                    0
# c_size                    0
# c_bid                     0
# c_ask                     0
# strike                    0
# moneyness_bucket     616252
# maturity_bucket       79922
# 1m_c_iv             2017393
# 3m_c_iv             1723430
# 6m_c_iv             1268160
# 9m_c_iv             1022602
# 12m_c_iv             752372
# dtype: int64

# %%
#iv term structure
df_201023_call_nn_nearest_iv_ts = df_201023_call_nn_nearest.drop_duplicates(subset = ['date'], keep = 'first')

# %%
df_201023_call_nn_nearest_iv_ts
# Out:
#                          date  underlying     expiry  dte  c_delta    c_gamma  \
# date
# 2010-01-04 6       2010-01-04     1132.99 2010-01-07  3.0  0.96734   0.002540
# 2010-01-05 945     2010-01-05     1136.40 2010-01-07  2.0  0.75900   0.020560
# 2010-01-06 1882    2010-01-06     1136.99 2010-01-07  1.0  0.79670   0.020920
# 2010-01-07 2825    2010-01-07     1141.48 2010-01-07  0.0  0.91761   0.013420
# 2010-01-08 3767    2010-01-08     1144.70 2010-01-14  6.0  1.00000   0.000000
# ...                       ...         ...        ...  ...      ...        ...
# 2023-12-22 1963713 2023-12-22     4755.11 2023-12-22  0.0  1.00000        0.0
# 2023-12-26 1972767 2023-12-26     4774.94 2023-12-26  0.0  0.99808        0.0
# 2023-12-27 1982011 2023-12-27     4782.50 2023-12-27  0.0  0.05014    0.08597
# 2023-12-28 1990970 2023-12-28     4783.83 2023-12-28  0.0  0.99940        0.0
# 2023-12-29 2000050 2023-12-29     4772.17 2023-12-29  0.0  0.99963        0.0
#
#                      c_vega     c_theta      c_rho      c_iv  ...  \
# date                                                          ...
# 2010-01-04 6        0.07711   -0.109830   0.023630   0.29808  ...
# 2010-01-05 945      0.31971   -0.736550   0.056430   0.15651  ...
# 2010-01-06 1882     0.23676   -0.873410   0.038210   0.17280  ...
# 2010-01-07 2825     0.08995   -0.320540   0.016590   0.20482  ...
# 2010-01-08 3767     0.00000    0.000000   0.000000  -0.00023  ...
# ...                     ...         ...        ...       ...  ...
# 2023-12-22 1963713  0.00000     -0.4818    0.08785   0.00008  ...
# 2023-12-26 1972767  0.01086    -1.46029    0.02345  11.50847  ...
# 2023-12-27 1982011  0.22042    -0.02463      0.005   0.00549  ...
# 2023-12-28 1990970  0.00756    -0.86962    0.02345  10.87366  ...
# 2023-12-29 2000050  0.00479    -0.47978    0.03757   6.72564  ...
#
#                           c_bid        c_ask  strike moneyness_bucket  \
# date
# 2010-01-04 6          57.190000    59.000000  1075.0              ITM
# 2010-01-05 945        12.590000    13.900000  1125.0              ITM
# 2010-01-06 1882       12.090000    14.510000  1125.0              ITM
# 2010-01-07 2825       15.500000    18.100000  1125.0              ITM
# 2010-01-08 3767      593.500000   595.910000   550.0              ITM
# ...                         ...          ...     ...              ...
# 2023-12-22 1963713        369.1        371.6  4385.0              ITM
# 2023-12-26 1972767       3575.2       3577.6  1200.0              ITM
# 2023-12-27 1982011          0.0         0.05  4785.0              OTM
# 2023-12-28 1990970       3584.3       3585.1  1200.0              ITM
# 2023-12-29 2000050       2869.6       2875.7  1900.0              ITM
#
#                    maturity_bucket  1m_c_iv  3m_c_iv  6m_c_iv  9m_c_iv  \
# date
# 2010-01-04 6                    1M  0.16969  0.28876  0.27779  0.27541
# 2010-01-05 945                  1M  0.23767  0.26365  0.26165  0.22220
# 2010-01-06 1882                 1M  0.19795  0.14768  0.14885  0.26217
# 2010-01-07 2825                 1M  0.24470  0.24326  0.18279  0.23415
# 2010-01-08 3767                 1M  0.23196  0.14736 -0.00008  0.18271
# ...                            ...      ...      ...      ...      ...
# 2023-12-22 1963713              1M  1.83818  0.12021  0.43725  0.28586
# 2023-12-26 1972767              1M  0.10445  0.21300  0.20769  0.10305
# 2023-12-27 1982011              1M  0.23864  0.12175 -0.00031  0.31331
# 2023-12-28 1990970              1M  0.00014  0.09874  0.53267  0.09373
# 2023-12-29 2000050              1M  1.88043  1.12276  0.10290  1.14090
#
#                     12m_c_iv
# date
# 2010-01-04 6         0.26812
# 2010-01-05 945       0.41198
# 2010-01-06 1882      0.25994
# 2010-01-07 2825      0.15733
# 2010-01-08 3767      0.51525
# ...                      ...
# 2023-12-22 1963713   0.11469
# 2023-12-26 1972767   0.11731
# 2023-12-27 1982011   0.84911
# 2023-12-28 1990970   0.14312
# 2023-12-29 2000050   0.17091
#
# [3499 rows x 23 columns]

# %%
# drop index
df_201023_call_nn_nearest_iv_ts['date_ts'] = df_201023_call_nn_nearest_iv_ts['date']
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2685722844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn_nearest_iv_ts['date_ts'] = df_201023_call_nn_nearest_iv_ts['date']

# %%
# debug for all to check no null in these iv

# %%
df_201023_call_nn_nearest_iv_ts = df_201023_call_nn_nearest_iv_ts[['date_ts','underlying','strike','1m_c_iv','3m_c_iv','6m_c_iv','9m_c_iv','12m_c_iv']]

# %%
df_201023_call_nn_nearest_iv_ts = df_201023_call_nn_nearest_iv_ts.reset_index()

# %%
df_201023_call_nn_nearest_iv_ts
# Out:
#            date  level_1    date_ts  underlying  strike  1m_c_iv  3m_c_iv  \
# 0    2010-01-04        6 2010-01-04     1132.99  1075.0  0.16969  0.28876
# 1    2010-01-05      945 2010-01-05     1136.40  1125.0  0.23767  0.26365
# 2    2010-01-06     1882 2010-01-06     1136.99  1125.0  0.19795  0.14768
# 3    2010-01-07     2825 2010-01-07     1141.48  1125.0  0.24470  0.24326
# 4    2010-01-08     3767 2010-01-08     1144.70   550.0  0.23196  0.14736
# ...         ...      ...        ...         ...     ...      ...      ...
# 3494 2023-12-22  1963713 2023-12-22     4755.11  4385.0  1.83818  0.12021
# 3495 2023-12-26  1972767 2023-12-26     4774.94  1200.0  0.10445  0.21300
# 3496 2023-12-27  1982011 2023-12-27     4782.50  4785.0  0.23864  0.12175
# 3497 2023-12-28  1990970 2023-12-28     4783.83  1200.0  0.00014  0.09874
# 3498 2023-12-29  2000050 2023-12-29     4772.17  1900.0  1.88043  1.12276
#
#       6m_c_iv  9m_c_iv  12m_c_iv
# 0     0.27779  0.27541   0.26812
# 1     0.26165  0.22220   0.41198
# 2     0.14885  0.26217   0.25994
# 3     0.18279  0.23415   0.15733
# 4    -0.00008  0.18271   0.51525
# ...       ...      ...       ...
# 3494  0.43725  0.28586   0.11469
# 3495  0.20769  0.10305   0.11731
# 3496 -0.00031  0.31331   0.84911
# 3497  0.53267  0.09373   0.14312
# 3498  0.10290  1.14090   0.17091
#
# [3499 rows x 10 columns]

# %%
iv_cols = ['1m_c_iv', '3m_c_iv', '6m_c_iv', '9m_c_iv', '12m_c_iv']
df_201023_call_nn_nearest_iv_ts[iv_cols] = df_201023_call_nn_nearest_iv_ts[iv_cols].apply(pd.to_numeric, errors='coerce')

# %%
# plot the term structure in the diagram
groups = df_201023_call_nn_nearest_iv_ts


plt.figure(figsize=(14, 8))
plt.plot(groups['date_ts'], groups['1m_c_iv'], marker='', linestyle='-', label='1M IV')
plt.plot(groups['date_ts'], groups['3m_c_iv'], marker='', linestyle='-', label='3M IV')
plt.plot(groups['date_ts'], groups['6m_c_iv'], marker='', linestyle='-', label='6M IV')
plt.plot(groups['date_ts'], groups['9m_c_iv'], marker='', linestyle='-', label='9M IV')
plt.plot(groups['date_ts'], groups['12m_c_iv'], marker='', linestyle='-', label='12M IV')
plt.title(f'IV for QQQ ETF Call Option over Time of different maturities 1M, 3M, 6M, 9M, 12M of different moneyness, at K = 210')
plt.xlabel('date')
plt.ylabel('IV')
plt.legend()
plt.grid(True)
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %%
# plot the term structure in the diagram
groups = df_201023_call_nn_nearest_iv_ts

plt.figure(figsize=(14, 8))
plt.plot(groups['date_ts'], groups['1m_c_iv'], marker='o', linestyle='-', label='1M IV')
plt.plot(groups['date_ts'], groups['3m_c_iv'], marker='s', linestyle='-', label='3M IV')
plt.plot(groups['date_ts'], groups['6m_c_iv'], marker='^', linestyle='-', label='6M IV')
plt.plot(groups['date_ts'], groups['9m_c_iv'], marker='d', linestyle='-', label='9M IV')
plt.plot(groups['date_ts'], groups['12m_c_iv'], marker='x', linestyle='-', label='12M IV')
plt.title(f'IV for QQQ ETF Call Option over Time of different maturities 1M, 3M, 6M, 9M, 12M of different moneyness, at K = 210')
plt.xlabel('date')
plt.ylabel('IV')
plt.legend()
plt.grid(True)
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Approach 2: remove the null

# %%
df_201023_call_nn = df_201023_call[df_201023_call['c_iv'] != ' ']

df_201023_call_nn['c_iv'] = df_201023_call_nn['c_iv'].apply(pd.to_numeric, errors='coerce')

df_201023_call_nn['1m_c_iv'] = np.nan
df_201023_call_nn['3m_c_iv'] = np.nan
df_201023_call_nn['6m_c_iv'] = np.nan
df_201023_call_nn['9m_c_iv'] = np.nan
df_201023_call_nn['12m_c_iv'] = np.nan

df_201023_call_nn['date'] = pd.to_datetime(df_201023_call_nn['date'])
df_201023_call_nn['expiry'] = pd.to_datetime(df_201023_call_nn['expiry'])

df_201023_call_nn['after_1M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 1)
df_201023_call_nn['after_3M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 3)
df_201023_call_nn['after_6M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 6)
df_201023_call_nn['after_9M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 9)
df_201023_call_nn['after_12M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 12)

df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_1M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_3M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_6M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_9M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_12M'], df_201023_call_nn['c_iv'], np.nan)

df_201023_call_nn['c_vega'] = df_201023_call_nn['c_vega'].apply(pd.to_numeric, errors='coerce')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['c_iv'] = df_201023_call_nn['c_iv'].apply(pd.to_numeric, errors='coerce')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['1m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['3m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['6m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['9m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['12m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['date'] = pd.to_datetime(df_201023_call_nn['date'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['expiry'] = pd.to_datetime(df_201023_call_nn['expiry'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_1M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 1)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_3M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 3)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_6M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 6)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_9M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 9)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_12M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 12)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_1M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_3M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_6M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_9M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_12M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2229713605.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['c_vega'] = df_201023_call_nn['c_vega'].apply(pd.to_numeric, errors='coerce')

# %%
df_201023_call_nn.isna().sum()
# Out:
# date                       0
# underlying                 0
# expiry                     0
# dte                        0
# c_delta                    0
# c_gamma                    0
# c_vega                     0
# c_theta                    0
# c_rho                      0
# c_iv                       0
# c_volume                   0
# c_last                     0
# c_size                     0
# c_bid                      0
# c_ask                      0
# strike                     0
# moneyness_bucket      616252
# maturity_bucket        79922
# 1m_c_iv             11775199
# 3m_c_iv             11858735
# 6m_c_iv             11891968
# 9m_c_iv             11891352
# 12m_c_iv            11892870
# after_1M                   0
# after_3M                   0
# after_6M                   0
# after_9M                   0
# after_12M                  0
# dtype: int64

# %%
len(df_201023_call_nn)
# Out:
# 11900876

# %%
no1M = ~(df_201023_call_nn['1m_c_iv'].isna())
no3M = ~(df_201023_call_nn['3m_c_iv'].isna())
no6M = ~(df_201023_call_nn['6m_c_iv'].isna())
no9M = ~(df_201023_call_nn['9m_c_iv'].isna())
no12M = ~(df_201023_call_nn['12m_c_iv'].isna())

df_201023_call_nn_nonull = df_201023_call_nn[no1M&no3M&no6M&no9M&no12M]

# %%
def grouped_bfill(group):
    group['1m_c_iv'] = group['1m_c_iv'].fillna(method = "bfill")
    group['3m_c_iv'] = group['3m_c_iv'].fillna(method = "bfill")
    group['6m_c_iv'] = group['6m_c_iv'].fillna(method = "bfill")
    group['9m_c_iv'] = group['9m_c_iv'].fillna(method = "bfill")
    group['12m_c_iv'] = group['12m_c_iv'].fillna(method = "bfill")
    return group

# %%
df_201023_call_nn_nonull = df_201023_call_nn_nonull.groupby('date').apply(grouped_bfill)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3519310890.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_201023_call_nn_nonull = df_201023_call_nn_nonull.groupby('date').apply(grouped_bfill)

# %%
df_201023_call_nn_nonull_iv_ts = df_201023_call_nn_nonull.drop_duplicates(subset = ['date'], keep = 'first')

df_201023_call_nn_nonull_iv_ts['date_ts'] = df_201023_call_nn_nonull_iv_ts['date']
df_201023_call_nn_nonull_iv_ts = df_201023_call_nn_nonull_iv_ts[['date_ts','underlying','strike','1m_c_iv','3m_c_iv','6m_c_iv','9m_c_iv','12m_c_iv']]
df_201023_call_nn_nonull_iv_ts = df_201023_call_nn_nonull_iv_ts.reset_index()

iv_cols = ['1m_c_iv', '3m_c_iv', '6m_c_iv', '9m_c_iv', '12m_c_iv']
df_201023_call_nn_nonull_iv_ts[iv_cols] = df_201023_call_nn_nonull_iv_ts[iv_cols].apply(pd.to_numeric, errors='coerce')

# %%
df_201023_call_nn_nonull_iv_ts
# Out:
# Empty DataFrame
# Columns: [date, date_ts, underlying, strike, 1m_c_iv, 3m_c_iv, 6m_c_iv, 9m_c_iv, 12m_c_iv]
# Index: []

# %%
# # plot the term structure in the diagram
# groups = df1M_ATM_noull_iv_ts


# plt.figure(figsize=(14, 8))
# plt.plot(groups['date_ts'], groups['1m_c_iv'], marker='', linestyle='-', label='1M IV')
# plt.plot(groups['date_ts'], groups['3m_c_iv'], marker='', linestyle='-', label='3M IV')
# plt.plot(groups['date_ts'], groups['6m_c_iv'], marker='', linestyle='-', label='6M IV')
# plt.plot(groups['date_ts'], groups['9m_c_iv'], marker='', linestyle='-', label='9M IV')
# plt.plot(groups['date_ts'], groups['12m_c_iv'], marker='', linestyle='-', label='12M IV')
# plt.title(f'IV for QQQ ETF Call Option over Time of different maturities 1M, 3M, 6M, 9M, 12M of different moneyness, at K = 210')
# plt.xlabel('date')
# plt.ylabel('IV')
# plt.legend()
# plt.grid(True)
# plt.xticks(rotation = 45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Using the 6M ATM Bucket

# %% [markdown]
# ### 2.0 Calculate the Option Price by BSM risk-neutral method

# %% [markdown]
# $c_t = S_t N(d_1) - K e^{(-r (T - t))} N (d_2)$

# %%
# import the risk free data: the three-month treasury bill rate

rf_rate = pd.read_csv(dir_path + "/Data" + "/3M_risk_free.csv")

# %%
rf_rate
# Out:
#             DATE DGS3MO
# 0     2009-12-01   0.06
# 1     2009-12-02   0.05
# 2     2009-12-03   0.06
# 3     2009-12-04   0.06
# 4     2009-12-07   0.04
# ...          ...    ...
# 3826  2024-07-31   5.41
# 3827  2024-08-01   5.37
# 3828  2024-08-02   5.29
# 3829  2024-08-05   5.35
# 3830  2024-08-06   5.34
#
# [3831 rows x 2 columns]

# %%
rf_rate.dtypes
# Out:
# DATE      object
# DGS3MO    object
# dtype: object

# %%
rf_rate['DATE'] = pd.to_datetime(rf_rate['DATE'])

# %%
rf_rate[rf_rate['DGS3MO'].isna()]
# Out:
# Empty DataFrame
# Columns: [DATE, DGS3MO]
# Index: []

# %%
# check for 10-09
rf_rate[rf_rate['DATE'] == '2017-10-09']
# Out:
#            DATE DGS3MO
# 2049 2017-10-09      .

# %%
rf_rate[rf_rate['DGS3MO'] == '.']
#
# Out:
#            DATE DGS3MO
# 18   2009-12-25      .
# 23   2010-01-01      .
# 34   2010-01-18      .
# 54   2010-02-15      .
# 129  2010-05-31      .
# ...         ...    ...
# 3709 2024-02-19      .
# 3738 2024-03-29      .
# 3779 2024-05-27      .
# 3796 2024-06-19      .
# 3807 2024-07-04      .
#
# [157 rows x 2 columns]

# %%
date_no_rate = rf_rate.loc[rf_rate['DGS3MO'] == '.', 'DATE']
date_no_rate.unique()
# Out:
# <DatetimeArray>
# ['2009-12-25 00:00:00', '2010-01-01 00:00:00', '2010-01-18 00:00:00',
#  '2010-02-15 00:00:00', '2010-05-31 00:00:00', '2010-07-05 00:00:00',
#  '2010-09-06 00:00:00', '2010-10-11 00:00:00', '2010-11-11 00:00:00',
#  '2010-11-25 00:00:00',
#  ...
#  '2023-10-09 00:00:00', '2023-11-23 00:00:00', '2023-12-25 00:00:00',
#  '2024-01-01 00:00:00', '2024-01-15 00:00:00', '2024-02-19 00:00:00',
#  '2024-03-29 00:00:00', '2024-05-27 00:00:00', '2024-06-19 00:00:00',
#  '2024-07-04 00:00:00']
# Length: 157, dtype: datetime64[ns]

# %% [markdown]
# Some of these days are holidays so can be filled with previous day rate

# %%
rf_rate['DGS3MO'] = np.where(rf_rate['DGS3MO']=='.', np.nan, rf_rate['DGS3MO'])

# %%
rf_rate['DGS3MO'][rf_rate['DGS3MO'].isna()]
# Out:
# 18      NaN
# 23      NaN
# 34      NaN
# 54      NaN
# 129     NaN
#        ...
# 3709    NaN
# 3738    NaN
# 3779    NaN
# 3796    NaN
# 3807    NaN
# Name: DGS3MO, Length: 157, dtype: object

# %%
rf_rate['DGS3MO'] = rf_rate['DGS3MO'].fillna(method = "ffill")
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1211909483.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rf_rate['DGS3MO'] = rf_rate['DGS3MO'].fillna(method = "ffill")

# %%
# roughly check for other non-numeric values
rf_rate['DGS3MO'].unique()
# Out:
# array(['0.06', '0.05', '0.04', '0.03', '0.02', '0.08', '0.07', '0.11',
#        '0.10', '0.09', '0.12', '0.13', '0.14', '0.15', '0.16', '0.17',
#        '0.18', '0.01', '0.00', '0.19', '0.22', '0.21', '0.23', '0.29',
#        '0.27', '0.26', '0.24', '0.25', '0.20', '0.28', '0.31', '0.32',
#        '0.35', '0.33', '0.34', '0.30', '0.36', '0.37', '0.38', '0.41',
#        '0.43', '0.45', '0.48', '0.55', '0.51', '0.47', '0.44', '0.46',
#        '0.49', '0.52', '0.54', '0.53', '0.50', '0.63', '0.67', '0.71',
#        '0.74', '0.76', '0.73', '0.75', '0.79', '0.78', '0.77', '0.80',
#        '0.82', '0.81', '0.83', '0.85', '0.86', '0.90', '0.91', '0.89',
#        '0.88', '0.93', '0.92', '0.94', '0.98', '0.96', '0.97', '1.00',
#        '1.01', '1.02', '1.03', '0.99', '1.04', '1.06', '1.05', '1.07',
#        '1.11', '1.15', '1.16', '1.17', '1.18', '1.13', '1.08', '1.10',
#        '1.09', '1.12', '1.19', '1.22', '1.23', '1.24', '1.26', '1.25',
#        '1.27', '1.29', '1.30', '1.28', '1.33', '1.34', '1.32', '1.31',
#        '1.38', '1.37', '1.35', '1.47', '1.44', '1.39', '1.41', '1.45',
#        '1.42', '1.43', '1.46', '1.48', '1.51', '1.52', '1.55', '1.62',
#        '1.59', '1.58', '1.66', '1.64', '1.63', '1.65', '1.70', '1.68',
#        '1.67', '1.71', '1.73', '1.76', '1.77', '1.78', '1.80', '1.81',
#        '1.74', '1.72', '1.79', '1.75', '1.82', '1.87', '1.85', '1.84',
#        '1.86', '1.88', '1.90', '1.92', '1.93', '1.91', '1.94', '1.95',
#        '1.98', '1.96', '1.97', '1.99', '2.01', '2.02', '2.00', '2.04',
#        '2.03', '2.05', '2.06', '2.08', '2.07', '2.09', '2.12', '2.13',
#        '2.11', '2.14', '2.15', '2.16', '2.17', '2.18', '2.22', '2.21',
#        '2.20', '2.19', '2.23', '2.25', '2.27', '2.28', '2.31', '2.30',
#        '2.32', '2.34', '2.33', '2.36', '2.35', '2.37', '2.38', '2.39',
#        '2.41', '2.40', '2.42', '2.43', '2.45', '2.44', '2.46', '2.47',
#        '2.48', '2.49', '2.29', '2.24', '2.26', '2.10', '1.89', '1.83',
#        '1.69', '1.54', '1.53', '1.56', '1.57', '1.61', '1.60', '0.95',
#        '0.72', '0.62', '0.42', '0.40', '0.39', '0.59', '0.66', '0.65',
#        '0.68', '0.70', '1.21', '2.50', '2.52', '2.51', '2.62', '2.55',
#        '2.56', '2.58', '2.65', '2.67', '2.63', '2.72', '2.70', '2.68',
#        '2.71', '2.74', '2.82', '2.80', '2.88', '2.89', '2.97', '2.96',
#        '2.94', '3.04', '3.07', '3.06', '3.08', '3.17', '3.28', '3.24',
#        '3.22', '3.20', '3.37', '3.35', '3.31', '3.29', '3.39', '3.40',
#        '3.36', '3.33', '3.46', '3.45', '3.67', '3.70', '3.79', '3.81',
#        '3.97', '4.04', '4.07', '4.09', '4.16', '4.14', '4.11', '4.13',
#        '4.18', '4.22', '4.23', '4.25', '4.21', '4.29', '4.28', '4.34',
#        '4.31', '4.32', '4.41', '4.40', '4.38', '4.37', '4.33', '4.36',
#        '4.35', '4.46', '4.45', '4.42', '4.53', '4.55', '4.66', '4.67',
#        '4.70', '4.73', '4.72', '4.71', '4.69', '4.77', '4.79', '4.81',
#        '4.80', '4.84', '4.86', '4.89', '4.88', '4.90', '4.91', '4.93',
#        '5.04', '5.06', '5.05', '5.01', '4.87', '4.75', '4.74', '4.52',
#        '4.78', '4.97', '4.85', '4.95', '5.08', '5.02', '5.10', '5.14',
#        '5.21', '5.20', '5.16', '5.12', '5.18', '5.27', '5.24', '5.26',
#        '5.31', '5.29', '5.25', '5.23', '5.40', '5.34', '5.37', '5.38',
#        '5.55', '5.52', '5.50', '5.46', '5.44', '5.42', '5.36', '5.33',
#        '5.39', '5.41', '5.43', '5.48', '5.49', '5.47', '5.51', '5.54',
#        '5.53', '5.56', '5.57', '5.58', '5.61', '5.62', '5.63', '5.60',
#        '5.59', '5.45', '5.5', '5.4', '5.35'], dtype=object)

# %% [markdown]
# # CHANGE BUCKET HERE

# %%
df_201023_call_nn = df_201023_call[df_201023_call['c_iv'] != ' ']
df1M_ATM = df_201023_call_nn[(df_201023_call_nn['moneyness_bucket'] == "ITM")&(df_201023_call_nn['maturity_bucket'] == '1M')]

# %%
df1M_ATM.dtypes
# Out:
# date                 object
# underlying          float64
# expiry               object
# dte                 float64
# c_delta             float64
# c_gamma              object
# c_vega               object
# c_theta              object
# c_rho                object
# c_iv                 object
# c_volume             object
# c_last               object
# c_size               object
# c_bid                object
# c_ask                object
# strike              float64
# moneyness_bucket     object
# maturity_bucket      object
# dtype: object

# %%
df1M_ATM['date'] = pd.to_datetime(df1M_ATM['date'])
df1M_ATM['expiry'] = pd.to_datetime(df1M_ATM['expiry'])
df1M_ATM['c_vega'] = df1M_ATM['c_vega'].apply(pd.to_numeric, errors='coerce')
df1M_ATM['c_iv'] = df1M_ATM['c_iv'].apply(pd.to_numeric, errors='coerce')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3390608471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['date'] = pd.to_datetime(df1M_ATM['date'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3390608471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['expiry'] = pd.to_datetime(df1M_ATM['expiry'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3390608471.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['c_vega'] = df1M_ATM['c_vega'].apply(pd.to_numeric, errors='coerce')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3390608471.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['c_iv'] = df1M_ATM['c_iv'].apply(pd.to_numeric, errors='coerce')

# %%
df1M_ATM.dtypes
# Out:
# date                datetime64[ns]
# underlying                 float64
# expiry              datetime64[ns]
# dte                        float64
# c_delta                    float64
# c_gamma                     object
# c_vega                     float64
# c_theta                     object
# c_rho                       object
# c_iv                       float64
# c_volume                    object
# c_last                      object
# c_size                      object
# c_bid                       object
# c_ask                       object
# strike                     float64
# moneyness_bucket            object
# maturity_bucket             object
# dtype: object

# %%
df1M_ATM['date_rate'] = df1M_ATM['date']
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2246093883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['date_rate'] = df1M_ATM['date']

# %%
df1M_ATM[df1M_ATM['c_iv'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate]
# Index: []

# %%
len(rf_rate)
# Out:
# 3831

# %%
len(df1M_ATM)
# Out:
# 2412583

# %%
#convert rf_rate to numeric
rf_rate['DGS3MO'] = rf_rate['DGS3MO'].apply(pd.to_numeric, errors='coerce')

# %%
# fill NA for those missing c_iv (due to holidays)
df1M_ATM['c_iv'] = np.where(df1M_ATM['c_iv'] == ' ', np.nan, df1M_ATM['c_iv'])
df1M_ATM['c_iv'] = df1M_ATM['c_iv'].fillna(method = 'ffill')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3529903446.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['c_iv'] = np.where(df1M_ATM['c_iv'] == ' ', np.nan, df1M_ATM['c_iv'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3529903446.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1M_ATM['c_iv'] = df1M_ATM['c_iv'].fillna(method = 'ffill')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3529903446.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['c_iv'] = df1M_ATM['c_iv'].fillna(method = 'ffill')

# %%
# left merge the risk free interest rates
df1M_ATM_rate = df1M_ATM.merge(rf_rate, left_on = 'date_rate', right_on = 'DATE', how = 'left')

# %%
len(df1M_ATM_rate)
# Out:
# 2412583

# %%
df1M_ATM_rate = df1M_ATM_rate.rename(columns = {'DGS3MO':'rate'})

# %%
df1M_ATM_rate.isna().sum()
# Out:
# date                0
# underlying          0
# expiry              0
# dte                 0
# c_delta             0
# c_gamma             0
# c_vega              0
# c_theta             0
# c_rho               0
# c_iv                0
# c_volume            0
# c_last              0
# c_size              0
# c_bid               0
# c_ask               0
# strike              0
# moneyness_bucket    0
# maturity_bucket     0
# date_rate           0
# DATE                0
# rate                0
# dtype: int64

# %%
df1M_ATM_rate.head()
# Out:
#         date  underlying     expiry   dte  c_delta    c_gamma   c_vega  \
# 0 2010-01-04     1132.99 2010-01-07   3.0  0.96734   0.002540  0.07711
# 1 2010-01-04     1132.99 2010-01-07   3.0  0.89961   0.007920  0.20451
# 2 2010-01-04     1132.99 2010-01-07   3.0  0.63727   0.018470  0.44247
# 3 2010-01-04     1132.99 2010-01-14  10.0  0.95620   0.000450  0.15318
# 4 2010-01-04     1132.99 2010-01-14  10.0  0.95593   0.000500  0.15421
#
#       c_theta      c_rho     c_iv  ...       c_last      c_size        c_bid  \
# 0   -0.109830   0.023630  0.29808  ...     0.000000   101 x 101    57.190000
# 1   -0.421270   0.060390  0.23357  ...    33.000000   101 x 101    32.900000
# 2   -0.888310   0.067420  0.17923  ...    12.500000   101 x 101    11.710000
# 3   -0.010140   0.029790  0.39947  ...   132.500000   103 x 103   131.600000
# 4   -0.059850   0.035040  0.38652  ...   122.600000   204 x 103   126.600000
#
#          c_ask  strike  moneyness_bucket maturity_bucket  date_rate  \
# 0    59.000000  1075.0               ITM              1M 2010-01-04
# 1    34.700000  1100.0               ITM              1M 2010-01-04
# 2    13.000000  1125.0               ITM              1M 2010-01-04
# 3   134.400000  1000.0               ITM              1M 2010-01-04
# 4   129.500000  1005.0               ITM              1M 2010-01-04
#
#         DATE  rate
# 0 2010-01-04  0.08
# 1 2010-01-04  0.08
# 2 2010-01-04  0.08
# 3 2010-01-04  0.08
# 4 2010-01-04  0.08
#
# [5 rows x 21 columns]

# %%
# check for days with no rates
rf_rate[rf_rate['DATE'] == '2010-01-04']
# Out:
#          DATE  DGS3MO
# 24 2010-01-04    0.08

# %%
df1M_ATM_rate['rate'] = df1M_ATM_rate['rate'].fillna(method = 'ffill')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/4229273609.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1M_ATM_rate['rate'] = df1M_ATM_rate['rate'].fillna(method = 'ffill')

# %%
df1M_ATM_rate.isna().sum()
# Out:
# date                0
# underlying          0
# expiry              0
# dte                 0
# c_delta             0
# c_gamma             0
# c_vega              0
# c_theta             0
# c_rho               0
# c_iv                0
# c_volume            0
# c_last              0
# c_size              0
# c_bid               0
# c_ask               0
# strike              0
# moneyness_bucket    0
# maturity_bucket     0
# date_rate           0
# DATE                0
# rate                0
# dtype: int64

# %% [markdown]
# ## Pricing of the call

# %%
pricing = ['underlying','strike','dte','c_iv','rate']
df1M_ATM_rate[pricing].dtypes
# Out:
# underlying    float64
# strike        float64
# dte           float64
# c_iv          float64
# rate          float64
# dtype: object

# %%
df1M_ATM_rate[df1M_ATM_rate['c_iv'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate, DATE, rate]
# Index: []
#
# [0 rows x 21 columns]

# %%
df1M_ATM_rate_converted = df1M_ATM_rate

# %%
df1M_ATM_rate_converted[pricing].dtypes
# Out:
# underlying    float64
# strike        float64
# dte           float64
# c_iv          float64
# rate          float64
# dtype: object

# %%
# be aware of data types and convert all to numeric
df1M_ATM_rate_converted[pricing] = df1M_ATM_rate_converted[pricing].apply(pd.to_numeric, errors = 'coerce')

# %%
df1M_ATM_rate_converted[pricing].dtypes
# Out:
# underlying    float64
# strike        float64
# dte           float64
# c_iv          float64
# rate          float64
# dtype: object

# %%
df1M_ATM_rate_converted[df1M_ATM_rate_converted['c_iv'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate, DATE, rate]
# Index: []
#
# [0 rows x 21 columns]

# %%
list_null_c_iv = df1M_ATM_rate_converted[df1M_ATM_rate_converted['c_iv'].isna()].index.tolist()

# %% [markdown]
# after converting objects to numerics there are some c_iv becoming null

# %%
# get those null c_iv lines from the raw dataset (before conversion)
df1M_ATM_rate_converted.loc[list_null_c_iv]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate, DATE, rate]
# Index: []
#
# [0 rows x 21 columns]

# %%
from scipy.stats import norm

# %%
def option_pricing_call(df):
    S = df['underlying']
    K = df['strike']
    tau = df['dte']/256
    sigma = df['c_iv']
    r = df['rate']/100
    d1 = (np.log(S/K) + (r + (1/2) * sigma**2) * tau)/(sigma * np.sqrt(tau))
    d2 = d1 - sigma * np.sqrt(tau)
    value = S * norm.cdf(d1) - K * np.exp(-r * tau) * norm.cdf(d2)
    return value

# %%
df1M_ATM_rate_converted.dtypes
# Out:
# date                datetime64[ns]
# underlying                 float64
# expiry              datetime64[ns]
# dte                        float64
# c_delta                    float64
# c_gamma                     object
# c_vega                     float64
# c_theta                     object
# c_rho                       object
# c_iv                       float64
# c_volume                    object
# c_last                      object
# c_size                      object
# c_bid                       object
# c_ask                       object
# strike                     float64
# moneyness_bucket            object
# maturity_bucket             object
# date_rate           datetime64[ns]
# DATE                datetime64[ns]
# rate                       float64
# dtype: object

# %%
df1M_ATM_rate_converted['c_price'] = df1M_ATM_rate_converted.apply(lambda row: option_pricing_call(row), axis=1)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/832289472.py:7: RuntimeWarning: divide by zero encountered in scalar divide
#   d1 = (np.log(S/K) + (r + (1/2) * sigma**2) * tau)/(sigma * np.sqrt(tau))

# %%
df1M_ATM_rate_converted[df1M_ATM_rate_converted['c_price'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate, DATE, rate, c_price]
# Index: []
#
# [0 rows x 22 columns]

# %%
df1M_ATM_rate_converted[df1M_ATM_rate_converted['c_iv'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate, DATE, rate, c_price]
# Index: []
#
# [0 rows x 22 columns]

# %%
# NA price only when dte = 0, therefore price should be 0 as well

# %%
df1M_ATM_rate_converted['c_price'] = df1M_ATM_rate_converted['c_price'].fillna(0)

# %%
# convert c_vega to numerics
df1M_ATM_rate_converted['c_vega'] = df1M_ATM_rate_converted['c_vega'].apply(pd.to_numeric, errors = 'coerce')

# %%
df1M_ATM_rate_converted[['underlying','c_price','c_bid','c_ask','c_last']]
# Out:
#          underlying     c_price        c_bid        c_ask       c_last
# 0           1132.99   58.773630    57.190000    59.000000     0.000000
# 1           1132.99   34.686975    32.900000    34.700000    33.000000
# 2           1132.99   13.315387    11.710000    13.000000    12.500000
# 3           1132.99  135.058348   131.600000   134.400000   132.500000
# 4           1132.99  130.055080   126.600000   129.500000   122.600000
# ...             ...         ...          ...          ...          ...
# 2412578     4772.17  106.427609         88.0         92.6         84.6
# 2412579     4772.17  105.358607         86.7         91.2         98.3
# 2412580     4772.17   99.481632         81.1         85.5        94.72
# 2412581     4772.17   95.778029         77.8         82.0         80.9
# 2412582     4772.17   92.354827         74.3         78.6         65.5
#
# [2412583 rows x 5 columns]

# %% [markdown]
# Differences between our theoretical price and actual bid, ask and last price might be that we didnt include the divident factor $q$, which is unknown.

# %%
df1M_ATM_rate_converted['c_delta'] = df1M_ATM_rate_converted['c_delta'].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# # 3. Fitting Process

# %% [markdown]
# ## 3.1 Qudratic Regression

# %%
# for each bucket, generate the dependent variable which is independent on implied vol
def reg_variables(df):
    df['1D_call_change'] = df['c_price'].pct_change().fillna(0) #from Richard's tutorial the change in option price is a percentage
    df['1D_stock_change'] = df['underlying'].diff().fillna(0)
    df['LHS'] = df['1D_call_change'] - df['c_delta'] * df['1D_stock_change']
    df['vega_term'] = (df['c_vega']/np.sqrt(df['dte']))*(df['1D_stock_change']/df['underlying'])
    df['RHS1'] = df['c_delta']
    df['RHS2'] = df['c_delta'] ** 2
    return df

# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/homebrew/lib/python3.11/site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in /opt/homebrew/lib/python3.11/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/homebrew/lib/python3.11/site-packages (from statsmodels) (1.14.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/homebrew/lib/python3.11/site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /opt/homebrew/lib/python3.11/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /Users/zhifei_li/Library/Python/3.11/lib/python/site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/zhifei_li/Library/Python/3.11/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in /Users/zhifei_li/Library/Python/3.11/lib/python/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

# %% [markdown]
# Test on the method: proves to be right

# %%
df1M_ATM_regression = df1M_ATM_rate_converted[['date','underlying','expiry','dte','c_delta','c_vega','c_iv','strike','c_price']]

# %%
df1M_ATM_regression
# Out:
#               date  underlying     expiry   dte  c_delta   c_vega     c_iv  \
# 0       2010-01-04     1132.99 2010-01-07   3.0  0.96734  0.07711  0.29808
# 1       2010-01-04     1132.99 2010-01-07   3.0  0.89961  0.20451  0.23357
# 2       2010-01-04     1132.99 2010-01-07   3.0  0.63727  0.44247  0.17923
# 3       2010-01-04     1132.99 2010-01-14  10.0  0.95620  0.15318  0.39947
# 4       2010-01-04     1132.99 2010-01-14  10.0  0.95593  0.15421  0.38652
# ...            ...         ...        ...   ...      ...      ...      ...
# 2412578 2023-12-29     4772.17 2024-01-26  28.0  0.65079  4.95382  0.11048
# 2412579 2023-12-29     4772.17 2024-01-26  28.0  0.63389  5.03279  0.11401
# 2412580 2023-12-29     4772.17 2024-01-26  28.0  0.62611  5.06642  0.10931
# 2412581 2023-12-29     4772.17 2024-01-26  28.0  0.61357  5.11687  0.10822
# 2412582 2023-12-29     4772.17 2024-01-26  28.0  0.60206  5.16237  0.10752
#
#          strike     c_price
# 0        1075.0   58.773630
# 1        1100.0   34.686975
# 2        1125.0   13.315387
# 3        1000.0  135.058348
# 4        1005.0  130.055080
# ...         ...         ...
# 2412578  4735.0  106.427609
# 2412579  4740.0  105.358607
# 2412580  4745.0   99.481632
# 2412581  4750.0   95.778029
# 2412582  4755.0   92.354827
#
# [2412583 rows x 9 columns]

# %% [markdown]
# Lots of dates have more than one observation, so applying .pct.diff() would be wrong

# %%
df1M_ATM_regression_prev = df1M_ATM_regression.copy()

# %%
df1M_ATM_regression_prev
# Out:
#               date  underlying     expiry   dte  c_delta   c_vega     c_iv  \
# 0       2010-01-04     1132.99 2010-01-07   3.0  0.96734  0.07711  0.29808
# 1       2010-01-04     1132.99 2010-01-07   3.0  0.89961  0.20451  0.23357
# 2       2010-01-04     1132.99 2010-01-07   3.0  0.63727  0.44247  0.17923
# 3       2010-01-04     1132.99 2010-01-14  10.0  0.95620  0.15318  0.39947
# 4       2010-01-04     1132.99 2010-01-14  10.0  0.95593  0.15421  0.38652
# ...            ...         ...        ...   ...      ...      ...      ...
# 2412578 2023-12-29     4772.17 2024-01-26  28.0  0.65079  4.95382  0.11048
# 2412579 2023-12-29     4772.17 2024-01-26  28.0  0.63389  5.03279  0.11401
# 2412580 2023-12-29     4772.17 2024-01-26  28.0  0.62611  5.06642  0.10931
# 2412581 2023-12-29     4772.17 2024-01-26  28.0  0.61357  5.11687  0.10822
# 2412582 2023-12-29     4772.17 2024-01-26  28.0  0.60206  5.16237  0.10752
#
#          strike     c_price
# 0        1075.0   58.773630
# 1        1100.0   34.686975
# 2        1125.0   13.315387
# 3        1000.0  135.058348
# 4        1005.0  130.055080
# ...         ...         ...
# 2412578  4735.0  106.427609
# 2412579  4740.0  105.358607
# 2412580  4745.0   99.481632
# 2412581  4750.0   95.778029
# 2412582  4755.0   92.354827
#
# [2412583 rows x 9 columns]

# %%
df1M_ATM_regression_prev['date_prev'] = df1M_ATM_regression_prev['date'] - pd.Timedelta(days = 1)
df1M_ATM_regression_prev = df1M_ATM_regression_prev.rename(columns = {'underlying':'underlying_prev','c_price':'c_price_prev','strike':'strike_prev','expiry':'expiry_prev'})
df1M_ATM_regression_prev.head()
# Out:
#         date  underlying_prev expiry_prev   dte  c_delta   c_vega     c_iv  \
# 0 2010-01-04          1132.99  2010-01-07   3.0  0.96734  0.07711  0.29808
# 1 2010-01-04          1132.99  2010-01-07   3.0  0.89961  0.20451  0.23357
# 2 2010-01-04          1132.99  2010-01-07   3.0  0.63727  0.44247  0.17923
# 3 2010-01-04          1132.99  2010-01-14  10.0  0.95620  0.15318  0.39947
# 4 2010-01-04          1132.99  2010-01-14  10.0  0.95593  0.15421  0.38652
#
#    strike_prev  c_price_prev  date_prev
# 0       1075.0     58.773630 2010-01-03
# 1       1100.0     34.686975 2010-01-03
# 2       1125.0     13.315387 2010-01-03
# 3       1000.0    135.058348 2010-01-03
# 4       1005.0    130.055080 2010-01-03

# %%
df1M_ATM_regression
# Out:
#               date  underlying     expiry   dte  c_delta   c_vega     c_iv  \
# 0       2010-01-04     1132.99 2010-01-07   3.0  0.96734  0.07711  0.29808
# 1       2010-01-04     1132.99 2010-01-07   3.0  0.89961  0.20451  0.23357
# 2       2010-01-04     1132.99 2010-01-07   3.0  0.63727  0.44247  0.17923
# 3       2010-01-04     1132.99 2010-01-14  10.0  0.95620  0.15318  0.39947
# 4       2010-01-04     1132.99 2010-01-14  10.0  0.95593  0.15421  0.38652
# ...            ...         ...        ...   ...      ...      ...      ...
# 2412578 2023-12-29     4772.17 2024-01-26  28.0  0.65079  4.95382  0.11048
# 2412579 2023-12-29     4772.17 2024-01-26  28.0  0.63389  5.03279  0.11401
# 2412580 2023-12-29     4772.17 2024-01-26  28.0  0.62611  5.06642  0.10931
# 2412581 2023-12-29     4772.17 2024-01-26  28.0  0.61357  5.11687  0.10822
# 2412582 2023-12-29     4772.17 2024-01-26  28.0  0.60206  5.16237  0.10752
#
#          strike     c_price
# 0        1075.0   58.773630
# 1        1100.0   34.686975
# 2        1125.0   13.315387
# 3        1000.0  135.058348
# 4        1005.0  130.055080
# ...         ...         ...
# 2412578  4735.0  106.427609
# 2412579  4740.0  105.358607
# 2412580  4745.0   99.481632
# 2412581  4750.0   95.778029
# 2412582  4755.0   92.354827
#
# [2412583 rows x 9 columns]

# %%
df1M_ATM_regression_diff = df1M_ATM_regression_prev.merge(df1M_ATM_regression[['date','expiry','strike','underlying','c_price']], left_on = ['date_prev','expiry_prev','strike_prev'], right_on = ['date','expiry','strike'], how = 'left')

# %%
df1M_ATM_regression_diff
# Out:
#             date_x  underlying_prev expiry_prev   dte  c_delta   c_vega  \
# 0       2010-01-04          1132.99  2010-01-07   3.0  0.96734  0.07711
# 1       2010-01-04          1132.99  2010-01-07   3.0  0.89961  0.20451
# 2       2010-01-04          1132.99  2010-01-07   3.0  0.63727  0.44247
# 3       2010-01-04          1132.99  2010-01-14  10.0  0.95620  0.15318
# 4       2010-01-04          1132.99  2010-01-14  10.0  0.95593  0.15421
# ...            ...              ...         ...   ...      ...      ...
# 2412578 2023-12-29          4772.17  2024-01-26  28.0  0.65079  4.95382
# 2412579 2023-12-29          4772.17  2024-01-26  28.0  0.63389  5.03279
# 2412580 2023-12-29          4772.17  2024-01-26  28.0  0.62611  5.06642
# 2412581 2023-12-29          4772.17  2024-01-26  28.0  0.61357  5.11687
# 2412582 2023-12-29          4772.17  2024-01-26  28.0  0.60206  5.16237
#
#             c_iv  strike_prev  c_price_prev  date_prev     date_y     expiry  \
# 0        0.29808       1075.0     58.773630 2010-01-03        NaT        NaT
# 1        0.23357       1100.0     34.686975 2010-01-03        NaT        NaT
# 2        0.17923       1125.0     13.315387 2010-01-03        NaT        NaT
# 3        0.39947       1000.0    135.058348 2010-01-03        NaT        NaT
# 4        0.38652       1005.0    130.055080 2010-01-03        NaT        NaT
# ...          ...          ...           ...        ...        ...        ...
# 2412578  0.11048       4735.0    106.427609 2023-12-28 2023-12-28 2024-01-26
# 2412579  0.11401       4740.0    105.358607 2023-12-28 2023-12-28 2024-01-26
# 2412580  0.10931       4745.0     99.481632 2023-12-28 2023-12-28 2024-01-26
# 2412581  0.10822       4750.0     95.778029 2023-12-28 2023-12-28 2024-01-26
# 2412582  0.10752       4755.0     92.354827 2023-12-28 2023-12-28 2024-01-26
#
#          strike  underlying     c_price
# 0           NaN         NaN         NaN
# 1           NaN         NaN         NaN
# 2           NaN         NaN         NaN
# 3           NaN         NaN         NaN
# 4           NaN         NaN         NaN
# ...         ...         ...         ...
# 2412578  4735.0     4783.83  116.282864
# 2412579  4740.0     4783.83  113.081372
# 2412580  4745.0     4783.83  109.809076
# 2412581  4750.0     4783.83  106.288686
# 2412582  4755.0     4783.83  102.228292
#
# [2412583 rows x 15 columns]

# %%
# drop the null in date_y since they are not provided
df1M_ATM_regression_diff = df1M_ATM_regression_diff[~(df1M_ATM_regression_diff ['date_y'].isna())]

# %%
df1M_ATM_regression_diff.isna().sum()
# Out:
# date_x             0
# underlying_prev    0
# expiry_prev        0
# dte                0
# c_delta            0
# c_vega             0
# c_iv               0
# strike_prev        0
# c_price_prev       0
# date_prev          0
# date_y             0
# expiry             0
# strike             0
# underlying         0
# c_price            0
# dtype: int64

# %%
df1M_ATM_regression_diff
# Out:
#             date_x  underlying_prev expiry_prev   dte  c_delta   c_vega  \
# 27      2010-01-05          1136.40  2010-01-07   2.0  0.75900  0.31971
# 28      2010-01-05          1136.40  2010-01-14   9.0  0.96693  0.11749
# 29      2010-01-05          1136.40  2010-01-14   9.0  0.96358  0.13429
# 30      2010-01-05          1136.40  2010-01-14   9.0  0.95541  0.16346
# 31      2010-01-05          1136.40  2010-01-14   9.0  0.94641  0.19334
# ...            ...              ...         ...   ...      ...      ...
# 2412578 2023-12-29          4772.17  2024-01-26  28.0  0.65079  4.95382
# 2412579 2023-12-29          4772.17  2024-01-26  28.0  0.63389  5.03279
# 2412580 2023-12-29          4772.17  2024-01-26  28.0  0.62611  5.06642
# 2412581 2023-12-29          4772.17  2024-01-26  28.0  0.61357  5.11687
# 2412582 2023-12-29          4772.17  2024-01-26  28.0  0.60206  5.16237
#
#             c_iv  strike_prev  c_price_prev  date_prev     date_y     expiry  \
# 27       0.15651       1125.0     13.532445 2010-01-04 2010-01-04 2010-01-07
# 28       0.23733       1060.0     77.659350 2010-01-04 2010-01-04 2010-01-14
# 29       0.23023       1065.0     72.805808 2010-01-04 2010-01-04 2010-01-14
# 30       0.22542       1070.0     68.042943 2010-01-04 2010-01-04 2010-01-14
# 31       0.21956       1075.0     63.287715 2010-01-04 2010-01-04 2010-01-14
# ...          ...          ...           ...        ...        ...        ...
# 2412578  0.11048       4735.0    106.427609 2023-12-28 2023-12-28 2024-01-26
# 2412579  0.11401       4740.0    105.358607 2023-12-28 2023-12-28 2024-01-26
# 2412580  0.10931       4745.0     99.481632 2023-12-28 2023-12-28 2024-01-26
# 2412581  0.10822       4750.0     95.778029 2023-12-28 2023-12-28 2024-01-26
# 2412582  0.10752       4755.0     92.354827 2023-12-28 2023-12-28 2024-01-26
#
#          strike  underlying     c_price
# 27       1125.0     1132.99   13.315387
# 28       1060.0     1132.99   75.845151
# 29       1065.0     1132.99   70.980451
# 30       1070.0     1132.99   66.242890
# 31       1075.0     1132.99   61.472704
# ...         ...         ...         ...
# 2412578  4735.0     4783.83  116.282864
# 2412579  4740.0     4783.83  113.081372
# 2412580  4745.0     4783.83  109.809076
# 2412581  4750.0     4783.83  106.288686
# 2412582  4755.0     4783.83  102.228292
#
# [1467918 rows x 15 columns]

# %%
df1M_ATM_regression_diff_final = df1M_ATM_regression_diff[['date_x','date_prev','expiry','strike','dte','c_delta','c_vega','c_iv','c_price','c_price_prev','underlying','underlying_prev']]

# %%
df1M_ATM_regression_diff_final
# Out:
#             date_x  date_prev     expiry  strike   dte  c_delta   c_vega  \
# 27      2010-01-05 2010-01-04 2010-01-07  1125.0   2.0  0.75900  0.31971
# 28      2010-01-05 2010-01-04 2010-01-14  1060.0   9.0  0.96693  0.11749
# 29      2010-01-05 2010-01-04 2010-01-14  1065.0   9.0  0.96358  0.13429
# 30      2010-01-05 2010-01-04 2010-01-14  1070.0   9.0  0.95541  0.16346
# 31      2010-01-05 2010-01-04 2010-01-14  1075.0   9.0  0.94641  0.19334
# ...            ...        ...        ...     ...   ...      ...      ...
# 2412578 2023-12-29 2023-12-28 2024-01-26  4735.0  28.0  0.65079  4.95382
# 2412579 2023-12-29 2023-12-28 2024-01-26  4740.0  28.0  0.63389  5.03279
# 2412580 2023-12-29 2023-12-28 2024-01-26  4745.0  28.0  0.62611  5.06642
# 2412581 2023-12-29 2023-12-28 2024-01-26  4750.0  28.0  0.61357  5.11687
# 2412582 2023-12-29 2023-12-28 2024-01-26  4755.0  28.0  0.60206  5.16237
#
#             c_iv     c_price  c_price_prev  underlying  underlying_prev
# 27       0.15651   13.315387     13.532445     1132.99          1136.40
# 28       0.23733   75.845151     77.659350     1132.99          1136.40
# 29       0.23023   70.980451     72.805808     1132.99          1136.40
# 30       0.22542   66.242890     68.042943     1132.99          1136.40
# 31       0.21956   61.472704     63.287715     1132.99          1136.40
# ...          ...         ...           ...         ...              ...
# 2412578  0.11048  116.282864    106.427609     4783.83          4772.17
# 2412579  0.11401  113.081372    105.358607     4783.83          4772.17
# 2412580  0.10931  109.809076     99.481632     4783.83          4772.17
# 2412581  0.10822  106.288686     95.778029     4783.83          4772.17
# 2412582  0.10752  102.228292     92.354827     4783.83          4772.17
#
# [1467918 rows x 12 columns]

# %%
df1M_ATM_regression_diff_final = df1M_ATM_regression_diff_final.rename({'date_x':'date'})

# %% [markdown]
# ### May also try to have V_diff in pct

# %%
df1M_ATM_regression_diff_final['S_diff'] = df1M_ATM_regression_diff_final['underlying'] - df1M_ATM_regression_diff_final['underlying_prev']
df1M_ATM_regression_diff_final['V_diff'] = abs(df1M_ATM_regression_diff_final['c_price'] - df1M_ATM_regression_diff_final['c_price_prev'])
df1M_ATM_regression_diff_final['c_vega'] = df1M_ATM_regression_diff_final['c_vega'] * 100

# %%
df1M_ATM_regression_diff_final
# Out:
#             date_x  date_prev     expiry  strike   dte  c_delta   c_vega  \
# 27      2010-01-05 2010-01-04 2010-01-07  1125.0   2.0  0.75900   31.971
# 28      2010-01-05 2010-01-04 2010-01-14  1060.0   9.0  0.96693   11.749
# 29      2010-01-05 2010-01-04 2010-01-14  1065.0   9.0  0.96358   13.429
# 30      2010-01-05 2010-01-04 2010-01-14  1070.0   9.0  0.95541   16.346
# 31      2010-01-05 2010-01-04 2010-01-14  1075.0   9.0  0.94641   19.334
# ...            ...        ...        ...     ...   ...      ...      ...
# 2412578 2023-12-29 2023-12-28 2024-01-26  4735.0  28.0  0.65079  495.382
# 2412579 2023-12-29 2023-12-28 2024-01-26  4740.0  28.0  0.63389  503.279
# 2412580 2023-12-29 2023-12-28 2024-01-26  4745.0  28.0  0.62611  506.642
# 2412581 2023-12-29 2023-12-28 2024-01-26  4750.0  28.0  0.61357  511.687
# 2412582 2023-12-29 2023-12-28 2024-01-26  4755.0  28.0  0.60206  516.237
#
#             c_iv     c_price  c_price_prev  underlying  underlying_prev  \
# 27       0.15651   13.315387     13.532445     1132.99          1136.40
# 28       0.23733   75.845151     77.659350     1132.99          1136.40
# 29       0.23023   70.980451     72.805808     1132.99          1136.40
# 30       0.22542   66.242890     68.042943     1132.99          1136.40
# 31       0.21956   61.472704     63.287715     1132.99          1136.40
# ...          ...         ...           ...         ...              ...
# 2412578  0.11048  116.282864    106.427609     4783.83          4772.17
# 2412579  0.11401  113.081372    105.358607     4783.83          4772.17
# 2412580  0.10931  109.809076     99.481632     4783.83          4772.17
# 2412581  0.10822  106.288686     95.778029     4783.83          4772.17
# 2412582  0.10752  102.228292     92.354827     4783.83          4772.17
#
#          S_diff     V_diff
# 27        -3.41   0.217057
# 28        -3.41   1.814199
# 29        -3.41   1.825357
# 30        -3.41   1.800054
# 31        -3.41   1.815011
# ...         ...        ...
# 2412578   11.66   9.855255
# 2412579   11.66   7.722766
# 2412580   11.66  10.327444
# 2412581   11.66  10.510658
# 2412582   11.66   9.873466
#
# [1467918 rows x 14 columns]

# %%
# for each bucket, generate the dependent variable which is independent on implied vol
def reg_variables(df):
    df['1D_call_change'] = df['V_diff'] #from Richard's tutorial the change in option price is a percentage
    df['1D_stock_change'] = df['S_diff']
    df['LHS'] = (df['1D_call_change'] - df['c_delta'] * df['1D_stock_change'])/((df['c_vega']/np.sqrt(df['dte']))*(df['1D_stock_change']/df['underlying']))
    df['RHS1'] = df['c_delta']
    df['RHS2'] = df['c_delta'] ** 2
    return df

# %%
# combine the independent variables RHS1 and RHS2
df1M_ATM_regression = reg_variables(df1M_ATM_regression_diff_final)

# %%
df1M_ATM_regression
# Out:
#             date_x  date_prev     expiry  strike   dte  c_delta   c_vega  \
# 27      2010-01-05 2010-01-04 2010-01-07  1125.0   2.0  0.75900   31.971
# 28      2010-01-05 2010-01-04 2010-01-14  1060.0   9.0  0.96693   11.749
# 29      2010-01-05 2010-01-04 2010-01-14  1065.0   9.0  0.96358   13.429
# 30      2010-01-05 2010-01-04 2010-01-14  1070.0   9.0  0.95541   16.346
# 31      2010-01-05 2010-01-04 2010-01-14  1075.0   9.0  0.94641   19.334
# ...            ...        ...        ...     ...   ...      ...      ...
# 2412578 2023-12-29 2023-12-28 2024-01-26  4735.0  28.0  0.65079  495.382
# 2412579 2023-12-29 2023-12-28 2024-01-26  4740.0  28.0  0.63389  503.279
# 2412580 2023-12-29 2023-12-28 2024-01-26  4745.0  28.0  0.62611  506.642
# 2412581 2023-12-29 2023-12-28 2024-01-26  4750.0  28.0  0.61357  511.687
# 2412582 2023-12-29 2023-12-28 2024-01-26  4755.0  28.0  0.60206  516.237
#
#             c_iv     c_price  c_price_prev  underlying  underlying_prev  \
# 27       0.15651   13.315387     13.532445     1132.99          1136.40
# 28       0.23733   75.845151     77.659350     1132.99          1136.40
# 29       0.23023   70.980451     72.805808     1132.99          1136.40
# 30       0.22542   66.242890     68.042943     1132.99          1136.40
# 31       0.21956   61.472704     63.287715     1132.99          1136.40
# ...          ...         ...           ...         ...              ...
# 2412578  0.11048  116.282864    106.427609     4783.83          4772.17
# 2412579  0.11401  113.081372    105.358607     4783.83          4772.17
# 2412580  0.10931  109.809076     99.481632     4783.83          4772.17
# 2412581  0.10822  106.288686     95.778029     4783.83          4772.17
# 2412582  0.10752  102.228292     92.354827     4783.83          4772.17
#
#          S_diff     V_diff  1D_call_change  1D_stock_change         LHS  \
# 27        -3.41   0.217057        0.217057            -3.41  -41.228890
# 28        -3.41   1.814199        1.814199            -3.41 -433.645124
# 29        -3.41   1.825357        1.825357            -3.41 -379.375394
# 30        -3.41   1.800054        1.800054            -3.41 -308.432719
# 31        -3.41   1.815011        1.815011            -3.41 -259.954446
# ...         ...        ...             ...              ...         ...
# 2412578   11.66   9.855255        9.855255            11.66    9.935183
# 2412579   11.66   7.722766        7.722766            11.66    1.430451
# 2412580   11.66  10.327444       10.327444            11.66   12.970826
# 2412581   11.66  10.510658       10.510658            11.66   14.240644
# 2412582   11.66   9.873466        9.873466            11.66   11.999876
#
#             RHS1      RHS2
# 27       0.75900  0.576081
# 28       0.96693  0.934954
# 29       0.96358  0.928486
# 30       0.95541  0.912808
# 31       0.94641  0.895692
# ...          ...       ...
# 2412578  0.65079  0.423528
# 2412579  0.63389  0.401817
# 2412580  0.62611  0.392014
# 2412581  0.61357  0.376468
# 2412582  0.60206  0.362476
#
# [1467918 rows x 19 columns]

# %%
df1M_ATM_regression.isna().sum()
# Out:
# date_x                0
# date_prev             0
# expiry                0
# strike                0
# dte                   0
# c_delta               0
# c_vega                0
# c_iv                  0
# c_price               0
# c_price_prev          0
# underlying            0
# underlying_prev       0
# S_diff                0
# V_diff                0
# 1D_call_change        0
# 1D_stock_change       0
# LHS                1491
# RHS1                  0
# RHS2                  0
# dtype: int64

# %%
df1M_ATM_regression = df1M_ATM_regression[~(df1M_ATM_regression['LHS'].isna())]

# %%
df1M_ATM_regression.to_csv('df1M_ATM_regression.csv')

# %%
X = df1M_ATM_regression[['RHS1','RHS2']]
X = sm.add_constant(X)
y = df1M_ATM_regression['LHS']

# %%
df1M_ATM_regression.iloc[1061]
# Out:
# date_x             2010-03-25 00:00:00
# date_prev          2010-03-24 00:00:00
# expiry             2010-04-15 00:00:00
# strike                          1145.0
# dte                               21.0
# c_delta                        0.68081
# c_vega                         102.201
# c_iv                           0.16313
# c_price                      34.407035
# c_price_prev                 33.610415
# underlying                     1167.83
# underlying_prev                1165.82
# S_diff                            2.01
# V_diff                        0.796621
# 1D_call_change                0.796621
# 1D_stock_change                   2.01
# LHS                          -14.89662
# RHS1                           0.68081
# RHS2                          0.463502
# Name: 2026, dtype: object

# %%
np.isinf(df1M_ATM_regression).sum()
# Out:
# date_x                 0
# date_prev              0
# expiry                 0
# strike                 0
# dte                    0
# c_delta                0
# c_vega                 0
# c_iv                   0
# c_price                0
# c_price_prev           0
# underlying             0
# underlying_prev        0
# S_diff                 0
# V_diff                 0
# 1D_call_change         0
# 1D_stock_change        0
# LHS                80560
# RHS1                   0
# RHS2                   0
# dtype: int64

# %%
df1M_ATM_regression_noinf = df1M_ATM_regression.replace([np.inf, -np.inf, np.nan]).dropna(axis = 1)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2712130517.py:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df1M_ATM_regression_noinf = df1M_ATM_regression.replace([np.inf, -np.inf, np.nan]).dropna(axis = 1)

# %%
np.isinf(df1M_ATM_regression_noinf).sum()
# Out:
# date_x             0
# date_prev          0
# expiry             0
# strike             0
# dte                0
# c_delta            0
# c_vega             0
# c_iv               0
# c_price            0
# c_price_prev       0
# underlying         0
# underlying_prev    0
# S_diff             0
# V_diff             0
# 1D_call_change     0
# 1D_stock_change    0
# LHS                0
# RHS1               0
# RHS2               0
# dtype: int64

# %%
X = df1M_ATM_regression_noinf[['RHS1','RHS2']]
X = sm.add_constant(X)
y = df1M_ATM_regression_noinf['LHS']

# %%
model = sm.OLS(y, X).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    LHS   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.236
# Date:                Fri, 16 Aug 2024   Prob (F-statistic):              0.291
# Time:                        23:22:47   Log-Likelihood:            -2.4852e+07
# No. Observations:             1466427   AIC:                         4.970e+07
# Df Residuals:                 1466424   BIC:                         4.970e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.381e+05   3.16e+05      1.072      0.284    -2.8e+05    9.57e+05
# RHS1       -8.657e+05    7.6e+05     -1.139      0.255   -2.36e+06    6.24e+05
# RHS2        5.443e+05   4.52e+05      1.204      0.229   -3.42e+05    1.43e+06
# ==================================================================================
# Omnibus:                 11220636.387   Durbin-Watson:                       2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   114328325087756016.000
# Skew:                        1141.643   Prob(JB):                             0.00
# Kurtosis:                 1367894.693   Cond. No.                             322.
# ==================================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = df1M_ATM_regression_noinf[['RHS1','RHS2']].values
X = sm.add_constant(X)

y = df1M_ATM_regression_noinf['LHS']

# %%
coef = np.polyfit(df1M_ATM_regression['RHS1'],y,2)

# %%
coef
# Out:
# array([ 544282.42981009, -865667.5981107 ,  338109.85769134])

# %%
X1 = df1M_ATM_regression_noinf['RHS1']
X2 = df1M_ATM_regression_noinf['RHS2']

y = df1M_ATM_regression_noinf['LHS']

# %%
from scipy.optimize import minimize

# %%
def objective(params):
    a, b, c = params
    y_pred = a + b * X1 + c * X2
    return np.sum((y - y_pred) ** 2)

initial_guess = [1,1,1]

result = minimize(objective, initial_guess, method = 'SLSQP')

a, b, c = result.x

# %%
print(f"a:{a}, b:{b}, c:{c}")
# Out:
# a:1.0, b:1.0, c:1.0

# %%
def mv_delta(df, a, b, c):
    df['c_mv_delta'] = df['c_delta']  +  (df['c_vega']/(df['underlying'] * np.sqrt(df['dte']))) * (a + b * df['c_delta'] + c * df['c_delta'] ** 2)
    return df

# %%
a = 338100
b = -865700
c = 544300
df = df1M_ATM_regression_noinf

# %%
df1M_ATM_regression_noinf_new = mv_delta(df, a, b, c)

# %%
df1M_ATM_regression_noinf_new['diff_delta'] = df1M_ATM_regression_noinf_new['c_mv_delta'] - df1M_ATM_regression_noinf_new['c_delta']

print(len(df1M_ATM_regression_noinf_new[df1M_ATM_regression_noinf_new['diff_delta']>=0]))

print(len(df1M_ATM_regression_noinf_new[df1M_ATM_regression_noinf_new['diff_delta']<0]))
# Out:
# 980986
# 485441

# %% [markdown]
# # 4. Calibration by Rolling Windows - the term structure of $a(T,t)$, $b(T,t)$, $c(T,t)$

# %%
df1M_ATM_regression_diff_final_rolling = mv_delta(df, a, b, c)

# %%
def rolling_regression(df, window_size):
    unique_dates = df['date'].unique()
    results = []

    for start_date in unique_dates: # ensure to shift by one day every time
        end_date = start_date + pd.Timedelta(days = window_size - 1)

        window_data = df[(df['date'] >= start_date) & (df['date']<= end_date)]

        if len(window_data) > 1:
            y = window_data['LHS']
            X = window_data[['RHS1','RHS2']]
            X = sm.add_constant(X)

            model = sm.OLS(y, X).fit()
            results.append({
                'start_date': start_date,
                'end_date': end_date,
                'a': model.params['const'],
                'b': model.params['RHS1'],
                'c': model.params['RHS2'],
                'rsquared': model.rsquared,
                'aic': model.aic,
                'bic': model.bic,
                'pvalues': model.pvalues,
                'tvalues': model.tvalues
            })
    return pd.DataFrame(results)

# %%
df1M_ATM_regression_diff_final_rolling = df1M_ATM_regression_diff_final_rolling.rename(columns = {'date_x':'date'})

# %%
rolling_result = rolling_regression(df1M_ATM_regression_diff_final_rolling, 66) #take three months (3*22 days) as the rolling window

# %%
rolling_result
# Out:
#      start_date   end_date             a             b             c  \
# 0    2010-01-05 2010-03-11  1.595304e+03 -3.692083e+03  1.963919e+03
# 1    2010-01-06 2010-03-12  1.180189e+05 -3.020020e+05  1.900004e+05
# 2    2010-01-07 2010-03-13  1.186560e+05 -3.037236e+05  1.911317e+05
# 3    2010-01-08 2010-03-14  1.186891e+05 -3.041272e+05  1.915837e+05
# 4    2010-01-12 2010-03-18  9.366831e+04 -2.396540e+05  1.506969e+05
# ...         ...        ...           ...           ...           ...
# 2715 2023-12-21 2024-02-24 -4.042592e+06  1.019598e+07 -6.305216e+06
# 2716 2023-12-22 2024-02-25 -4.976236e+06  1.261299e+07 -7.832892e+06
# 2717 2023-12-27 2024-03-01 -5.642808e+06  1.428405e+07 -8.859798e+06
# 2718 2023-12-28 2024-03-02 -8.439896e+06  2.147244e+07 -1.337225e+07
# 2719 2023-12-29 2024-03-03  1.479741e+06 -3.794371e+06  2.380365e+06
#
#       rsquared            aic            bic  \
# 0     0.068599    9395.511533    9409.257608
# 1     0.015269   16790.098428   16803.910260
# 2     0.015305   16463.675033   16477.425261
# 3     0.015402   16006.117728   16019.779528
# 4     0.011386   18940.126277   18954.315749
# ...        ...            ...            ...
# 2715  0.004086  334753.978062  334775.861003
# 2716  0.005457  270271.973996  270293.193776
# 2717  0.005216  206840.370015  206860.760846
# 2718  0.008304  137191.228609  137210.347884
# 2719  0.025602   51386.239614   51402.874197
#
#                                                 pvalues  \
# 0     const    0.000110
# RHS1     0.000196
# RHS2     0...
# 1     const    0.025458
# RHS1     0.017430
# RHS2     0...
# 2     const    0.027375
# RHS1     0.018850
# RHS2     0...
# 3     const    0.030558
# RHS1     0.021220
# RHS2     0...
# 4     const    0.044385
# RHS1     0.032140
# RHS2     0...
# ...                                                 ...
# 2715  const    0.000023
# RHS1     0.000006
# RHS2     0...
# 2716  const    9.440131e-06
# RHS1     2.237784e-06
# RH...
# 2717  const    0.000254
# RHS1     0.000093
# RHS2     0...
# 2718  const    0.000159
# RHS1     0.000055
# RHS2     0...
# 2719  const    5.699403e-06
# RHS1     1.302885e-06
# RH...
#
#                                                 tvalues
# 0     const    3.890013
# RHS1    -3.743805
# RHS2     3...
# 1     const    2.238939
# RHS1    -2.382902
# RHS2     2...
# 2     const    2.210634
# RHS1    -2.353801
# RHS2     2...
# 3     const    2.167183
# RHS1    -2.309251
# RHS2     2...
# 4     const    2.013480
# RHS1    -2.146263
# RHS2     2...
# ...                                                 ...
# 2715  const   -4.231502
# RHS1     4.526708
# RHS2    -4...
# 2716  const   -4.432237
# RHS1     4.733846
# RHS2    -5...
# 2717  const   -3.660371
# RHS1     3.911338
# RHS2    -4...
# 2718  const   -3.780574
# RHS1     4.037872
# RHS2    -4...
# 2719  const    4.550246
# RHS1    -4.855005
# RHS2     5...
#
# [2720 rows x 10 columns]

# %%
rolling_result['rsquared'].max()
# Out:
# 0.20559469488400905

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(rolling_result['start_date'], rolling_result['a'], label = 'a')
plt.plot(rolling_result['start_date'], rolling_result['b'], label = 'b')
plt.plot(rolling_result['start_date'], rolling_result['c'], label = 'c')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Plot of a, b, c')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ## 5. Model Validation: difference between MV and BS Deltas parabolic shape, and $E(\Delta_{imp})$ vs $\Delta_{MV}$ or $\Delta_{BS}$

# %%
df1M_ATM_regression_noinf_new.head()
# Out:
#        date_x  date_prev     expiry  strike  dte  c_delta  c_vega     c_iv  \
# 27 2010-01-05 2010-01-04 2010-01-07  1125.0  2.0  0.75900  31.971  0.15651
# 28 2010-01-05 2010-01-04 2010-01-14  1060.0  9.0  0.96693  11.749  0.23733
# 29 2010-01-05 2010-01-04 2010-01-14  1065.0  9.0  0.96358  13.429  0.23023
# 30 2010-01-05 2010-01-04 2010-01-14  1070.0  9.0  0.95541  16.346  0.22542
# 31 2010-01-05 2010-01-04 2010-01-14  1075.0  9.0  0.94641  19.334  0.21956
#
#       c_price  c_price_prev  ...  underlying_prev  S_diff    V_diff  \
# 27  13.315387     13.532445  ...           1136.4   -3.41  0.217057
# 28  75.845151     77.659350  ...           1136.4   -3.41  1.814199
# 29  70.980451     72.805808  ...           1136.4   -3.41  1.825357
# 30  66.242890     68.042943  ...           1136.4   -3.41  1.800054
# 31  61.472704     63.287715  ...           1136.4   -3.41  1.815011
#
#     1D_call_change  1D_stock_change         LHS     RHS1      RHS2  \
# 27        0.217057            -3.41  -41.228890  0.75900  0.576081
# 28        1.814199            -3.41 -433.645124  0.96693  0.934954
# 29        1.825357            -3.41 -379.375394  0.96358  0.928486
# 30        1.800054            -3.41 -308.432719  0.95541  0.912808
# 31        1.815011            -3.41 -259.954446  0.94641  0.895692
#
#     c_mv_delta  diff_delta
# 27 -107.096904 -107.855904
# 28   35.270431   34.303501
# 29   37.722584   36.759004
# 30   38.673709   37.718299
# 31   36.884178   35.937768
#
# [5 rows x 21 columns]

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_regression_noinf_new['c_delta'], df1M_ATM_regression_noinf_new['c_mv_delta'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS')
plt.legend()

plt.grid(True)
plt.show()

# %%
# the fitting line
x_fit = np.linspace(df1M_ATM_regression_noinf['RHS1'].min(), df1M_ATM_regression_noinf['RHS1'].max(), 100)
X_fit = sm.add_constant(np.column_stack((x_fit, x_fit**2)))
y_fit = model.predict(X_fit)

# %%
#plot the delta_bs vs delta_mv line and fitting line
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_regression_noinf['c_delta'], df1M_ATM_regression_noinf['c_mv_delta'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')


plt.plot(x_fit, y_fit, label = 'Quadratic Fit', color = 'red')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS')
plt.legend()

plt.grid(True)
plt.show()

# %%
df1M_ATM_regression_noinf_new
# Out:
#             date_x  date_prev     expiry  strike   dte  c_delta   c_vega  \
# 27      2010-01-05 2010-01-04 2010-01-07  1125.0   2.0  0.75900   31.971
# 28      2010-01-05 2010-01-04 2010-01-14  1060.0   9.0  0.96693   11.749
# 29      2010-01-05 2010-01-04 2010-01-14  1065.0   9.0  0.96358   13.429
# 30      2010-01-05 2010-01-04 2010-01-14  1070.0   9.0  0.95541   16.346
# 31      2010-01-05 2010-01-04 2010-01-14  1075.0   9.0  0.94641   19.334
# ...            ...        ...        ...     ...   ...      ...      ...
# 2412578 2023-12-29 2023-12-28 2024-01-26  4735.0  28.0  0.65079  495.382
# 2412579 2023-12-29 2023-12-28 2024-01-26  4740.0  28.0  0.63389  503.279
# 2412580 2023-12-29 2023-12-28 2024-01-26  4745.0  28.0  0.62611  506.642
# 2412581 2023-12-29 2023-12-28 2024-01-26  4750.0  28.0  0.61357  511.687
# 2412582 2023-12-29 2023-12-28 2024-01-26  4755.0  28.0  0.60206  516.237
#
#             c_iv     c_price  c_price_prev  ...  underlying_prev  S_diff  \
# 27       0.15651   13.315387     13.532445  ...          1136.40   -3.41
# 28       0.23733   75.845151     77.659350  ...          1136.40   -3.41
# 29       0.23023   70.980451     72.805808  ...          1136.40   -3.41
# 30       0.22542   66.242890     68.042943  ...          1136.40   -3.41
# 31       0.21956   61.472704     63.287715  ...          1136.40   -3.41
# ...          ...         ...           ...  ...              ...     ...
# 2412578  0.11048  116.282864    106.427609  ...          4772.17   11.66
# 2412579  0.11401  113.081372    105.358607  ...          4772.17   11.66
# 2412580  0.10931  109.809076     99.481632  ...          4772.17   11.66
# 2412581  0.10822  106.288686     95.778029  ...          4772.17   11.66
# 2412582  0.10752  102.228292     92.354827  ...          4772.17   11.66
#
#             V_diff  1D_call_change  1D_stock_change         LHS     RHS1  \
# 27        0.217057        0.217057            -3.41  -41.228890  0.75900
# 28        1.814199        1.814199            -3.41 -433.645124  0.96693
# 29        1.825357        1.825357            -3.41 -379.375394  0.96358
# 30        1.800054        1.800054            -3.41 -308.432719  0.95541
# 31        1.815011        1.815011            -3.41 -259.954446  0.94641
# ...            ...             ...              ...         ...      ...
# 2412578   9.855255        9.855255            11.66    9.935183  0.65079
# 2412579   7.722766        7.722766            11.66    1.430451  0.63389
# 2412580  10.327444       10.327444            11.66   12.970826  0.62611
# 2412581  10.510658       10.510658            11.66   14.240644  0.61357
# 2412582   9.873466        9.873466            11.66   11.999876  0.60206
#
#              RHS2  c_mv_delta  diff_delta
# 27       0.576081 -107.096904 -107.855904
# 28       0.934954   35.270431   34.303501
# 29       0.928486   37.722584   36.759004
# 30       0.912808   38.673709   37.718299
# 31       0.895692   36.884178   35.937768
# ...           ...         ...         ...
# 2412578  0.423528  103.141193  102.490403
# 2412579  0.401817  160.685063  160.051173
# 2412580  0.392014  189.756814  189.130704
# 2412581  0.376468  240.027994  239.414424
# 2412582  0.362476  290.038085  289.436025
#
# [1466427 rows x 21 columns]

# %%
def expected_change_iv(df, a, b, c):
    df['E_chg_iv'] = ((a + b * df['c_delta'] + c * df['c_delta'] ** 2)/np.sqrt(df['dte'])) * (df['1D_stock_change']/df['underlying'])
    return df

# %%
a = 338100
b = -865700
c = 544300
df = df1M_ATM_regression_noinf_new

# %%
df1M_ATM_regression_noinf_expiv = expected_change_iv(df, a, b, c)

# %%
df1M_ATM_regression_noinf_expiv
# Out:
#             date_x  date_prev     expiry  strike   dte  c_delta   c_vega  \
# 27      2010-01-05 2010-01-04 2010-01-07  1125.0   2.0  0.75900   31.971
# 28      2010-01-05 2010-01-04 2010-01-14  1060.0   9.0  0.96693   11.749
# 29      2010-01-05 2010-01-04 2010-01-14  1065.0   9.0  0.96358   13.429
# 30      2010-01-05 2010-01-04 2010-01-14  1070.0   9.0  0.95541   16.346
# 31      2010-01-05 2010-01-04 2010-01-14  1075.0   9.0  0.94641   19.334
# ...            ...        ...        ...     ...   ...      ...      ...
# 2412578 2023-12-29 2023-12-28 2024-01-26  4735.0  28.0  0.65079  495.382
# 2412579 2023-12-29 2023-12-28 2024-01-26  4740.0  28.0  0.63389  503.279
# 2412580 2023-12-29 2023-12-28 2024-01-26  4745.0  28.0  0.62611  506.642
# 2412581 2023-12-29 2023-12-28 2024-01-26  4750.0  28.0  0.61357  511.687
# 2412582 2023-12-29 2023-12-28 2024-01-26  4755.0  28.0  0.60206  516.237
#
#             c_iv     c_price  c_price_prev  ...  S_diff     V_diff  \
# 27       0.15651   13.315387     13.532445  ...   -3.41   0.217057
# 28       0.23733   75.845151     77.659350  ...   -3.41   1.814199
# 29       0.23023   70.980451     72.805808  ...   -3.41   1.825357
# 30       0.22542   66.242890     68.042943  ...   -3.41   1.800054
# 31       0.21956   61.472704     63.287715  ...   -3.41   1.815011
# ...          ...         ...           ...  ...     ...        ...
# 2412578  0.11048  116.282864    106.427609  ...   11.66   9.855255
# 2412579  0.11401  113.081372    105.358607  ...   11.66   7.722766
# 2412580  0.10931  109.809076     99.481632  ...   11.66  10.327444
# 2412581  0.10822  106.288686     95.778029  ...   11.66  10.510658
# 2412582  0.10752  102.228292     92.354827  ...   11.66   9.873466
#
#          1D_call_change  1D_stock_change         LHS     RHS1      RHS2  \
# 27             0.217057            -3.41  -41.228890  0.75900  0.576081
# 28             1.814199            -3.41 -433.645124  0.96693  0.934954
# 29             1.825357            -3.41 -379.375394  0.96358  0.928486
# 30             1.800054            -3.41 -308.432719  0.95541  0.912808
# 31             1.815011            -3.41 -259.954446  0.94641  0.895692
# ...                 ...              ...         ...      ...       ...
# 2412578        9.855255            11.66    9.935183  0.65079  0.423528
# 2412579        7.722766            11.66    1.430451  0.63389  0.401817
# 2412580       10.327444            11.66   12.970826  0.62611  0.392014
# 2412581       10.510658            11.66   14.240644  0.61357  0.376468
# 2412582        9.873466            11.66   11.999876  0.60206  0.362476
#
#          c_mv_delta  diff_delta   E_chg_iv
# 27      -107.096904 -107.855904  11.503820
# 28        35.270431   34.303501  -9.956161
# 29        37.722584   36.759004  -9.334143
# 30        38.673709   37.718299  -7.868555
# 31        36.884178   35.937768  -6.338460
# ...             ...         ...        ...
# 2412578  103.141193  102.490403   2.412357
# 2412579  160.685063  160.051173   3.708076
# 2412580  189.756814  189.130704   4.352707
# 2412581  240.027994  239.414424   5.455625
# 2412582  290.038085  289.436025   6.537354
#
# [1466427 rows x 22 columns]

# %%
# plot expected changes in implied vol wrt delta_bs
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_regression_noinf_expiv['E_chg_iv'], df1M_ATM_regression_noinf_expiv['c_delta'],label = 'Expected Change in IV vs BS Delta', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('BS Delta')
plt.title('Plot of Expected Change in IV vs BS Delta')
plt.legend()

plt.grid(True)
plt.show()

# %%
# plot expected changes in implied vol wrt delta_mv
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_regression_noinf_expiv['E_chg_iv'], df1M_ATM_regression_noinf_expiv['c_mv_delta'],label = 'Expected Change in IV vs MV Delta', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('MV Delta')
plt.title('Plot of Expected Change in IV vs MV Delta')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Hedging Gain

# %%
df1M_ATM_regression_noinf_expiv[df1M_ATM_regression_noinf_expiv['E_chg_iv']<0]
# Out:
#             date_x  date_prev     expiry  strike   dte  c_delta   c_vega  \
# 28      2010-01-05 2010-01-04 2010-01-14  1060.0   9.0  0.96693   11.749
# 29      2010-01-05 2010-01-04 2010-01-14  1065.0   9.0  0.96358   13.429
# 30      2010-01-05 2010-01-04 2010-01-14  1070.0   9.0  0.95541   16.346
# 31      2010-01-05 2010-01-04 2010-01-14  1075.0   9.0  0.94641   19.334
# 32      2010-01-05 2010-01-04 2010-01-14  1080.0   9.0  0.94003   21.640
# ...            ...        ...        ...     ...   ...      ...      ...
# 2412570 2023-12-29 2023-12-28 2024-01-26  4695.0  28.0  0.73241  440.395
# 2412571 2023-12-29 2023-12-28 2024-01-26  4700.0  28.0  0.72666  445.613
# 2412572 2023-12-29 2023-12-28 2024-01-26  4705.0  28.0  0.71695  452.942
# 2412573 2023-12-29 2023-12-28 2024-01-26  4710.0  28.0  0.70854  459.160
# 2412574 2023-12-29 2023-12-28 2024-01-26  4715.0  28.0  0.69607  468.360
#
#             c_iv     c_price  c_price_prev  ...  S_diff     V_diff  \
# 28       0.23733   75.845151     77.659350  ...   -3.41   1.814199
# 29       0.23023   70.980451     72.805808  ...   -3.41   1.825357
# 30       0.22542   66.242890     68.042943  ...   -3.41   1.800054
# 31       0.21956   61.472704     63.287715  ...   -3.41   1.815011
# 32       0.20960   56.896757     58.425825  ...   -3.41   1.529068
# ...          ...         ...           ...  ...     ...        ...
# 2412570  0.11800  147.446298    137.470333  ...   11.66   9.975966
# 2412571  0.11566  143.497357    132.716225  ...   11.66  10.781132
# 2412572  0.11452  139.187266    128.626717  ...   11.66  10.560549
# 2412573  0.11239  135.453843    124.026544  ...   11.66  11.427299
# 2412574  0.11308  131.882303    121.010186  ...   11.66  10.872118
#
#          1D_call_change  1D_stock_change         LHS     RHS1      RHS2  \
# 28             1.814199            -3.41 -433.645124  0.96693  0.934954
# 29             1.825357            -3.41 -379.375394  0.96358  0.928486
# 30             1.800054            -3.41 -308.432719  0.95541  0.912808
# 31             1.815011            -3.41 -259.954446  0.94641  0.895692
# 32             1.529068            -3.41 -218.080205  0.94003  0.883656
# ...                 ...              ...         ...      ...       ...
# 2412570        9.975966            11.66    7.079261  0.73241  0.536424
# 2412571       10.781132            11.66   11.245694  0.72666  0.528035
# 2412572       10.560549            11.66   10.549121  0.71695  0.514017
# 2412573       11.427299            11.66   14.968045  0.70854  0.502029
# 2412574       10.872118            11.66   12.774574  0.69607  0.484513
#
#          c_mv_delta  diff_delta  E_chg_iv
# 28        35.270431   34.303501 -9.956161
# 29        37.722584   36.759004 -9.334143
# 30        38.673709   37.718299 -7.868555
# 31        36.884178   35.937768 -6.338460
# 32        34.620851   33.680821 -5.307375
# ...             ...         ...       ...
# 2412570  -68.362436  -69.094846 -1.829371
# 2412571  -61.946692  -62.673352 -1.639924
# 2412572  -49.097649  -49.814599 -1.282368
# 2412573  -36.090260  -36.798800 -0.934476
# 2412574  -13.497595  -14.193665 -0.353357
#
# [764863 rows x 22 columns]

# %%
df1M_ATM_regression_noinf_expiv[df1M_ATM_regression_noinf_expiv['E_chg_iv']>=0]
# Out:
#             date_x  date_prev     expiry  strike   dte  c_delta   c_vega  \
# 27      2010-01-05 2010-01-04 2010-01-07  1125.0   2.0  0.75900   31.971
# 35      2010-01-05 2010-01-04 2010-01-14  1095.0   9.0  0.88648   35.648
# 36      2010-01-05 2010-01-04 2010-01-14  1100.0   9.0  0.86046   41.348
# 37      2010-01-05 2010-01-04 2010-01-14  1105.0   9.0  0.82948   47.266
# 38      2010-01-05 2010-01-04 2010-01-14  1110.0   9.0  0.79129   53.603
# ...            ...        ...        ...     ...   ...      ...      ...
# 2412578 2023-12-29 2023-12-28 2024-01-26  4735.0  28.0  0.65079  495.382
# 2412579 2023-12-29 2023-12-28 2024-01-26  4740.0  28.0  0.63389  503.279
# 2412580 2023-12-29 2023-12-28 2024-01-26  4745.0  28.0  0.62611  506.642
# 2412581 2023-12-29 2023-12-28 2024-01-26  4750.0  28.0  0.61357  511.687
# 2412582 2023-12-29 2023-12-28 2024-01-26  4755.0  28.0  0.60206  516.237
#
#             c_iv     c_price  c_price_prev  ...  S_diff     V_diff  \
# 27       0.15651   13.315387     13.532445  ...   -3.41   0.217057
# 35       0.19222   42.835464     44.586976  ...   -3.41   1.751512
# 36       0.18712   38.372650     40.164028  ...   -3.41   1.791378
# 37       0.18177   34.571438     35.835591  ...   -3.41   1.264153
# 38       0.17704   30.609426     31.674381  ...   -3.41   1.064955
# ...          ...         ...           ...  ...     ...        ...
# 2412578  0.11048  116.282864    106.427609  ...   11.66   9.855255
# 2412579  0.11401  113.081372    105.358607  ...   11.66   7.722766
# 2412580  0.10931  109.809076     99.481632  ...   11.66  10.327444
# 2412581  0.10822  106.288686     95.778029  ...   11.66  10.510658
# 2412582  0.10752  102.228292     92.354827  ...   11.66   9.873466
#
#          1D_call_change  1D_stock_change         LHS     RHS1      RHS2  \
# 27             0.217057            -3.41  -41.228890  0.75900  0.576081
# 35             1.751512            -3.41 -133.498806  0.88648  0.785847
# 36             1.791378            -3.41 -113.917505  0.86046  0.740391
# 37             1.264153            -3.41  -86.308159  0.82948  0.688037
# 38             1.064955            -3.41  -69.978937  0.79129  0.626140
# ...                 ...              ...         ...      ...       ...
# 2412578        9.855255            11.66    9.935183  0.65079  0.423528
# 2412579        7.722766            11.66    1.430451  0.63389  0.401817
# 2412580       10.327444            11.66   12.970826  0.62611  0.392014
# 2412581       10.510658            11.66   14.240644  0.61357  0.376468
# 2412582        9.873466            11.66   11.999876  0.60206  0.362476
#
#          c_mv_delta  diff_delta   E_chg_iv
# 27      -107.096904 -107.855904  11.503820
# 35       -15.782206  -16.668686   1.594486
# 36       -45.428988  -46.289448   3.817525
# 37       -75.406684  -76.236164   5.500049
# 38       -95.594425  -96.385715   6.131658
# ...             ...         ...        ...
# 2412578  103.141193  102.490403   2.412357
# 2412579  160.685063  160.051173   3.708076
# 2412580  189.756814  189.130704   4.352707
# 2412581  240.027994  239.414424   5.455625
# 2412582  290.038085  289.436025   6.537354
#
# [701564 rows x 22 columns]

# %%
def delta_mv_residual_sum(df, a, b, c):
    df['mv_error'] = df['1D_call_change'] - df['1D_stock_change'] * df['c_delta'] - (df['c_vega']/np.sqrt(df['dte'])) * (df['1D_stock_change']/df['underlying']) * (a + b * df['c_delta'] + c * df['c_delta'] ** 2)
    df['bs_error'] = df['1D_call_change'] - df['c_delta'] * df['1D_stock_change']
    return df

# %%
a = 338100
b = -865700
c = 544300
df = df1M_ATM_regression_noinf_new

# %%
delta_mv_residual_sum(df, a, b, c)
# Out:
#             date_x  date_prev     expiry  strike   dte  c_delta   c_vega  \
# 27      2010-01-05 2010-01-04 2010-01-07  1125.0   2.0  0.75900   31.971
# 28      2010-01-05 2010-01-04 2010-01-14  1060.0   9.0  0.96693   11.749
# 29      2010-01-05 2010-01-04 2010-01-14  1065.0   9.0  0.96358   13.429
# 30      2010-01-05 2010-01-04 2010-01-14  1070.0   9.0  0.95541   16.346
# 31      2010-01-05 2010-01-04 2010-01-14  1075.0   9.0  0.94641   19.334
# ...            ...        ...        ...     ...   ...      ...      ...
# 2412578 2023-12-29 2023-12-28 2024-01-26  4735.0  28.0  0.65079  495.382
# 2412579 2023-12-29 2023-12-28 2024-01-26  4740.0  28.0  0.63389  503.279
# 2412580 2023-12-29 2023-12-28 2024-01-26  4745.0  28.0  0.62611  506.642
# 2412581 2023-12-29 2023-12-28 2024-01-26  4750.0  28.0  0.61357  511.687
# 2412582 2023-12-29 2023-12-28 2024-01-26  4755.0  28.0  0.60206  516.237
#
#             c_iv     c_price  c_price_prev  ...  1D_call_change  \
# 27       0.15651   13.315387     13.532445  ...        0.217057
# 28       0.23733   75.845151     77.659350  ...        1.814199
# 29       0.23023   70.980451     72.805808  ...        1.825357
# 30       0.22542   66.242890     68.042943  ...        1.800054
# 31       0.21956   61.472704     63.287715  ...        1.815011
# ...          ...         ...           ...  ...             ...
# 2412578  0.11048  116.282864    106.427609  ...        9.855255
# 2412579  0.11401  113.081372    105.358607  ...        7.722766
# 2412580  0.10931  109.809076     99.481632  ...       10.327444
# 2412581  0.10822  106.288686     95.778029  ...       10.510658
# 2412582  0.10752  102.228292     92.354827  ...        9.873466
#
#          1D_stock_change         LHS     RHS1      RHS2  c_mv_delta  \
# 27                 -3.41  -41.228890  0.75900  0.576081 -107.096904
# 28                 -3.41 -433.645124  0.96693  0.934954   35.270431
# 29                 -3.41 -379.375394  0.96358  0.928486   37.722584
# 30                 -3.41 -308.432719  0.95541  0.912808   38.673709
# 31                 -3.41 -259.954446  0.94641  0.895692   36.884178
# ...                  ...         ...      ...       ...         ...
# 2412578            11.66    9.935183  0.65079  0.423528  103.141193
# 2412579            11.66    1.430451  0.63389  0.401817  160.685063
# 2412580            11.66   12.970826  0.62611  0.392014  189.756814
# 2412581            11.66   14.240644  0.61357  0.376468  240.027994
# 2412582            11.66   11.999876  0.60206  0.362476  290.038085
#
#          diff_delta   E_chg_iv     mv_error  bs_error
# 27      -107.855904  11.503820  -364.983385  2.805247
# 28        34.303501  -9.956161   122.086369  5.111430
# 29        36.759004  -9.334143   130.459367  5.111165
# 30        37.718299  -7.868555   133.677402  5.058002
# 31        35.937768  -6.338460   127.590057  5.042269
# ...             ...        ...          ...       ...
# 2412578  102.490403   2.412357 -1192.771056  2.267044
# 2412579  160.051173   3.708076 -1865.865064  0.331608
# 2412580  189.130704   4.352707 -2202.237005  3.027001
# 2412581  239.414424   5.455625 -2788.215751  3.356432
# 2412582  289.436025   6.537354 -3371.970610  2.853446
#
# [1466427 rows x 24 columns]

# %%
df1M_ATM_regression_noinf_new_err = delta_mv_residual_sum(df, a, b, c)

# %%
SSE_mv = (df1M_ATM_regression_noinf_new_err['mv_error'] ** 2).sum()
SSE_bs = (df1M_ATM_regression_noinf_new_err['bs_error'] ** 2).sum()
gain_ATM1M = 1 - SSE_mv/SSE_bs

# %%
gain_ATM1M
# Out:
# -inf

# %%
np.isinf(df1M_ATM_regression_noinf_new_err).sum()
# Out:
# date_x                 0
# date_prev              0
# expiry                 0
# strike                 0
# dte                    0
# c_delta                0
# c_vega                 0
# c_iv                   0
# c_price                0
# c_price_prev           0
# underlying             0
# underlying_prev        0
# S_diff                 0
# V_diff                 0
# 1D_call_change         0
# 1D_stock_change        0
# LHS                    0
# RHS1                   0
# RHS2                   0
# c_mv_delta         43164
# diff_delta         43164
# E_chg_iv           43164
# mv_error           43164
# bs_error               0
# dtype: int64

# %%
df1M_ATM_regression_noinf_new_err = df1M_ATM_regression_noinf_new_err.replace([np.inf, -np.inf, np.nan]).dropna(axis = 1)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/3127814221.py:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df1M_ATM_regression_noinf_new_err = df1M_ATM_regression_noinf_new_err.replace([np.inf, -np.inf, np.nan]).dropna(axis = 1)

# %%
np.isinf(df1M_ATM_regression_noinf_new_err).sum()
# Out:
# date_x             0
# date_prev          0
# expiry             0
# strike             0
# dte                0
# c_delta            0
# c_vega             0
# c_iv               0
# c_price            0
# c_price_prev       0
# underlying         0
# underlying_prev    0
# S_diff             0
# V_diff             0
# 1D_call_change     0
# 1D_stock_change    0
# LHS                0
# RHS1               0
# RHS2               0
# c_mv_delta         0
# diff_delta         0
# E_chg_iv           0
# mv_error           0
# bs_error           0
# dtype: int64

# %%
SSE_mv = (df1M_ATM_regression_noinf_new_err['mv_error'] ** 2).sum()
SSE_bs = (df1M_ATM_regression_noinf_new_err['bs_error'] ** 2).sum()
gain_ATM1M = 1 - SSE_mv/SSE_bs
gain_ATM1M
# Out:
# -6443371.274713938

# %% [markdown]
# ## Rolling Daily

# %%
def rolling_quadratic_regression(df1, window_size_days=1095):  # ~3 years (365 * 3)
    min_date = df1['date'].min()
    max_date = df1['date'].max()
    window_size = pd.Timedelta(days=window_size_days)
    
    results = []

    # Start rolling from the first date after the initial 3 years
    start_date = min_date + window_size
    while start_date <= max_date:
        end_date = start_date
        window_start_date = start_date - window_size

        # Select data within the 3-year window
        window_data = df1[(df1['date'] > window_start_date) & (df1['date'] <= end_date)]
        
        if len(window_data) > 1:  # At least two data points needed for regression
            y = window_data['LHS']
            X = window_data[['RHS1', 'RHS2']]
            X = sm.add_constant(X)

            # Fit the quadratic regression model
            model = sm.OLS(y, X).fit()

            # Store the coefficients for the current date
            results.append({
                'date': end_date,
                'a': model.params['const'],
                'b': model.params['RHS1'],
                'c': model.params['RHS2']
            })
        
        # Move forward by one day
        start_date = start_date + pd.DateOffset(days=1)

    return pd.DataFrame(results)

df1M_ATM_calibrating = df1M_ATM_regression_noinf
df1M_ATM_calibrating = df1M_ATM_calibrating.rename(columns = {'date_x':'date'})

df1M_ATM_calibrating.head()

df1M_ATM_calibrated = rolling_quadratic_regression(df1M_ATM_calibrating)

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated['date'], df1M_ATM_calibrated['a'], label = 'a')
plt.plot(df1M_ATM_calibrated['date'], df1M_ATM_calibrated['b'], label = 'b')
plt.plot(df1M_ATM_calibrated['date'], df1M_ATM_calibrated['c'], label = 'c')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Plot of a, b, c')
plt.legend()

plt.grid(True)
plt.show()

# %%
df1M_ATM_calibrated_abc = df1M_ATM_regression_noinf_new.merge(df1M_ATM_calibrated, left_on = ['date_x'], right_on = ['date'], how = 'left')

def calibration_apply(df1):
    df1 = df1[~df1['a'].isna()]
    df1['c_mv_delta_calibrated'] = df1['a'] + df1['b'] * df1['c_delta'] + df1['c'] * df1['c_delta'] ** 2
    df1['diff_delta_calibrated'] = df1['c_mv_delta_calibrated'] - df1['c_delta']
    df1['E_chg_iv_calibrate'] = (df1['a'] + df1['b'] * df1['c_delta'] + df1['c'] * df1['c_delta'] ** 2)/np.sqrt(df1['dte']) * (df1['1D_stock_change']/df1['underlying'])
    df1['mv_error_calibrate'] = df1['1D_call_change'] - df1['1D_stock_change'] * df1['c_delta'] - (df1['c_vega']/np.sqrt(df1['dte'])) * (df1['1D_stock_change']/df1['underlying']) * (df1['a'] + df1['b'] * df1['c_delta'] + df1['c'] * df1['c_delta'] ** 2)
    df1['bs_error_calibrate'] = df1['1D_call_change'] - df1['c_delta'] * df1['1D_stock_change']
    df1 = df1.replace([np.inf, -np.inf, np.nan]).dropna(axis = 1)
    return df1

# %%
df1M_ATM_calibrated_abc_new = calibration_apply(df1M_ATM_calibrated_abc)

df1M_ATM_calibrated_abc_new = df1M_ATM_calibrated_abc_new[~(df1M_ATM_calibrated_abc_new['a'].isna())]

df1M_ATM_calibrated_abc_new = df1M_ATM_calibrated_abc_new[np.isfinite(df1M_ATM_calibrated_abc_new).all(1)]

df1M_ATM_calibrated_abc_new['mv_error_calibrate'] = df1M_ATM_calibrated_abc_new['mv_error_calibrate'].replace([np.inf, -np.inf, np.nan]).dropna()

SSE_mv_calibrated = (df1M_ATM_calibrated_abc_new['mv_error_calibrate'] ** 2).sum()
SSE_bs_calibrated = (df1M_ATM_calibrated_abc_new['bs_error_calibrate'] ** 2).sum()
gain_ATM1M_calibrated = 1 - SSE_mv_calibrated/SSE_bs_calibrated

gain_ATM1M_calibrated
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1530194868.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['c_mv_delta_calibrated'] = df1['a'] + df1['b'] * df1['c_delta'] + df1['c'] * df1['c_delta'] ** 2
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1530194868.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['diff_delta_calibrated'] = df1['c_mv_delta_calibrated'] - df1['c_delta']
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1530194868.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['E_chg_iv_calibrate'] = (df1['a'] + df1['b'] * df1['c_delta'] + df1['c'] * df1['c_delta'] ** 2)/np.sqrt(df1['dte']) * (df1['1D_stock_change']/df1['underlying'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1530194868.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['mv_error_calibrate'] = df1['1D_call_change'] - df1['1D_stock_change'] * df1['c_delta'] - (df1['c_vega']/np.sqrt(df1['dte'])) * (df1['1D_stock_change']/df1['underlying']) * (df1['a'] + df1['b'] * df1['c_delta'] + df1['c'] * df1['c_delta'] ** 2)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1530194868.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['bs_error_calibrate'] = df1['1D_call_change'] - df1['c_delta'] * df1['1D_stock_change']
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1530194868.py:10: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df1 = df1.replace([np.inf, -np.inf, np.nan]).dropna(axis = 1)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2575023266.py:7: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df1M_ATM_calibrated_abc_new['mv_error_calibrate'] = df1M_ATM_calibrated_abc_new['mv_error_calibrate'].replace([np.inf, -np.inf, np.nan]).dropna()
# -693438.2384802625

# %%
np.isinf(df1M_ATM_calibrated_abc_new).sum()
# Out:
# date_x                   0
# date_prev                0
# expiry                   0
# strike                   0
# dte                      0
# c_delta                  0
# c_vega                   0
# c_iv                     0
# c_price                  0
# c_price_prev             0
# underlying               0
# underlying_prev          0
# S_diff                   0
# V_diff                   0
# 1D_call_change           0
# 1D_stock_change          0
# LHS                      0
# RHS1                     0
# RHS2                     0
# c_mv_delta               0
# diff_delta               0
# E_chg_iv                 0
# mv_error                 0
# bs_error                 0
# date                     0
# a                        0
# b                        0
# c                        0
# c_mv_delta_calibrated    0
# diff_delta_calibrated    0
# E_chg_iv_calibrate       0
# mv_error_calibrate       0
# bs_error_calibrate       0
# dtype: int64

# %%
df1M_ATM_calibrated_abc_new
# Out:
#             date_x  date_prev     expiry  strike   dte  c_delta   c_vega  \
# 27991   2013-01-04 2013-01-03 2013-01-11  1425.0   7.0  0.96417   14.793
# 27992   2013-01-04 2013-01-03 2013-01-11  1430.0   7.0  0.92366   28.254
# 27993   2013-01-04 2013-01-03 2013-01-11  1435.0   7.0  0.88749   38.339
# 27994   2013-01-04 2013-01-03 2013-01-11  1440.0   7.0  0.83950   49.596
# 27995   2013-01-04 2013-01-03 2013-01-11  1445.0   7.0  0.78751   59.957
# ...            ...        ...        ...     ...   ...      ...      ...
# 1466422 2023-12-29 2023-12-28 2024-01-26  4735.0  28.0  0.65079  495.382
# 1466423 2023-12-29 2023-12-28 2024-01-26  4740.0  28.0  0.63389  503.279
# 1466424 2023-12-29 2023-12-28 2024-01-26  4745.0  28.0  0.62611  506.642
# 1466425 2023-12-29 2023-12-28 2024-01-26  4750.0  28.0  0.61357  511.687
# 1466426 2023-12-29 2023-12-28 2024-01-26  4755.0  28.0  0.60206  516.237
#
#             c_iv     c_price  c_price_prev  ...   bs_error       date  \
# 27991    0.14574   37.470277     43.160223  ...  12.468062 2013-01-04
# 27992    0.14376   33.165373     38.734337  ...  12.062293 2013-01-04
# 27993    0.13852   28.959903     34.244352  ...  11.523503 2013-01-04
# 27994    0.13443   25.116610     29.949245  ...  10.734319 2013-01-04
# 27995    0.12906   21.218431     25.716643  ...  10.034408 2013-01-04
# ...          ...         ...           ...  ...        ...        ...
# 1466422  0.11048  116.282864    106.427609  ...   2.267044 2023-12-29
# 1466423  0.11401  113.081372    105.358607  ...   0.331608 2023-12-29
# 1466424  0.10931  109.809076     99.481632  ...   3.027001 2023-12-29
# 1466425  0.10822  106.288686     95.778029  ...   3.356432 2023-12-29
# 1466426  0.10752  102.228292     92.354827  ...   2.853446 2023-12-29
#
#                      a              b              c  c_mv_delta_calibrated  \
# 27991   -139763.247008  360531.711922 -228659.836230           -4717.009650
# 27992   -139763.247008  360531.711922 -228659.836230           -1835.161196
# 27993   -139763.247008  360531.711922 -228659.836230             103.751564
# 27994   -139763.247008  360531.711922 -228659.836230            1752.761804
# 27995   -139763.247008  360531.711922 -228659.836230            2350.653470
# ...                ...            ...            ...                    ...
# 1466422   29877.106007  -78627.663003   50918.940272             272.586997
# 1466423   29877.106007  -78627.663003   50918.940272             495.888705
# 1466424   29877.106007  -78627.663003   50918.940272             608.463735
# 1466425   29877.106007  -78627.663003   50918.940272             802.889803
# 1466426   29877.106007  -78627.663003   50918.940272             995.441417
#
#          diff_delta_calibrated  E_chg_iv_calibrate  mv_error_calibrate  \
# 27991             -4717.973820            8.590075         -114.604914
# 27992             -1836.084856            3.341984          -82.362129
# 27993               102.864074           -0.188940           18.767289
# 27994              1751.922304           -3.191928          169.041177
# 27995              2349.865960           -4.280739          266.694699
# ...                        ...                 ...                 ...
# 1466422             271.936207            0.125559          -59.932780
# 1466423             495.254815            0.228417         -114.625762
# 1466424             607.837625            0.280271         -138.970167
# 1466425             802.276233            0.369828         -185.879727
# 1466426             994.839357            0.458521         -233.852208
#
#          bs_error_calibrate
# 27991             12.468062
# 27992             12.062293
# 27993             11.523503
# 27994             10.734319
# 27995             10.034408
# ...                     ...
# 1466422            2.267044
# 1466423            0.331608
# 1466424            3.027001
# 1466425            3.356432
# 1466426            2.853446
#
# [1438436 rows x 33 columns]

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_abc_new['c_delta'], df1M_ATM_calibrated_abc_new['c_mv_delta_calibrated'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS (Calibrated by Rolling Estimation of Daily Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# the fitting line
x_fit = np.linspace(df1M_ATM_calibrated_abc_new['RHS1'].min(), df1M_ATM_calibrated_abc_new['RHS1'].max(), 100)
X_fit = sm.add_constant(np.column_stack((x_fit, x_fit**2)))
y_fit = model.predict(X_fit)

#plot the delta_bs vs delta_mv line and fitting line
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_abc_new['c_delta'], df1M_ATM_calibrated_abc_new['c_mv_delta_calibrated'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')


plt.plot(x_fit, y_fit, label = 'Quadratic Fit', color = 'red')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS (Calibrated by Rolling Estimation of Daily Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# plot expected changes in implied vol wrt delta_bs
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_abc_new['E_chg_iv'], df1M_ATM_calibrated_abc_new['c_delta'],label = 'Expected Change in IV vs BS Delta', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('BS Delta')
plt.title('Plot of Expected Change in IV vs BS Delta (Calibrated by Rolling Estimation of Daily Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# plot expected changes in implied vol wrt delta_mv
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_abc_new['E_chg_iv'], df1M_ATM_calibrated_abc_new['c_mv_delta_calibrated'],label = 'Expected Change in IV vs MV Delta ', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('MV Delta')
plt.title('Plot of Expected Change in IV vs MV Delta (Calibrated by Rolling Estimation of Daily Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ## Rolling Monthly

# %%
from pandas.tseries.offsets import MonthEnd

def rolling_quadratic_regression_monthly(df1, window_size_days=1095):  # ~3 years (365 * 3)
    min_date = df1['date'].min()
    max_date = df1['date'].max()
    window_size = pd.Timedelta(days=window_size_days)
    
    results = []

    # Start rolling from the first date after the initial 3 years
    start_date = min_date + window_size
    while start_date <= max_date:
        end_date = start_date
        window_start_date = start_date - window_size

        # Select data within the 3-year window
        window_data = df1[(df1['date'] > window_start_date) & (df1['date'] <= end_date)]
        
        if len(window_data) > 1:  # At least two data points needed for regression
            y = window_data['LHS']
            X = window_data[['RHS1', 'RHS2']]
            X = sm.add_constant(X)

            # Fit the quadratic regression model
            model = sm.OLS(y, X).fit()

            # Apply the coefficient to the next month
            next_month_start = end_date + pd.DateOffset(days=1)
            next_month_end = next_month_start + MonthEnd(1)

            days_in_next_month = pd.date_range(next_month_start, next_month_end)

            # Store the coefficients for the current date
            results.append({
                'date': end_date,
                'a': model.params['const'],
                'b': model.params['RHS1'],
                'c': model.params['RHS2']
            })
        
        # Move forward by one day
        start_date = start_date + pd.DateOffset(months=1)

    return pd.DataFrame(results)


df1M_ATM_calibrated_monthly = rolling_quadratic_regression_monthly(df1M_ATM_calibrating)

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_monthly['date'], df1M_ATM_calibrated_monthly['a'], label = 'a')
plt.plot(df1M_ATM_calibrated_monthly['date'], df1M_ATM_calibrated_monthly['b'], label = 'b')
plt.plot(df1M_ATM_calibrated_monthly['date'], df1M_ATM_calibrated_monthly['c'], label = 'c')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Plot of a, b, c')
plt.legend()

plt.grid(True)
plt.show()

# %%
df1M_ATM_calibrated_monthly = df1M_ATM_calibrated_monthly[df1M_ATM_calibrated_monthly['date'] > df1M_ATM_calibrated_monthly['date'].min() + pd.DateOffset(years=3)]

df1M_ATM_calibrated_monthly_abc = df1M_ATM_regression_noinf_new.merge(df1M_ATM_calibrated_monthly, left_on = ['date_x'], right_on = ['date'], how = 'left')

df1M_ATM_calibrated_monthly_abc['a'] = df1M_ATM_calibrated_monthly_abc['a'].fillna(method = 'ffill')
df1M_ATM_calibrated_monthly_abc['b'] = df1M_ATM_calibrated_monthly_abc['b'].fillna(method = 'ffill')
df1M_ATM_calibrated_monthly_abc['c'] = df1M_ATM_calibrated_monthly_abc['c'].fillna(method = 'ffill')

df1M_ATM_calibrated_monthly_abc = df1M_ATM_calibrated_monthly_abc[~df1M_ATM_calibrated_monthly_abc['a'].isna()]

df1M_ATM_calibrated_monthly_abc_new = calibration_apply(df1M_ATM_calibrated_monthly_abc)

SSE_mv_calibrated_month = (df1M_ATM_calibrated_monthly_abc_new['mv_error_calibrate'] ** 2).sum()
SSE_bs_calibrated_month = (df1M_ATM_calibrated_monthly_abc_new['bs_error_calibrate'] ** 2).sum()
gain_ATM1M_calibrated_month = 1 - SSE_mv_calibrated_month/SSE_bs_calibrated_month

gain_ATM1M_calibrated_month
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2190657408.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1M_ATM_calibrated_monthly_abc['a'] = df1M_ATM_calibrated_monthly_abc['a'].fillna(method = 'ffill')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2190657408.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1M_ATM_calibrated_monthly_abc['b'] = df1M_ATM_calibrated_monthly_abc['b'].fillna(method = 'ffill')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/2190657408.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1M_ATM_calibrated_monthly_abc['c'] = df1M_ATM_calibrated_monthly_abc['c'].fillna(method = 'ffill')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_17852/1530194868.py:10: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df1 = df1.replace([np.inf, -np.inf, np.nan]).dropna(axis = 1)
# -984861.1660994797

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_monthly_abc_new['c_delta'], df1M_ATM_calibrated_monthly_abc_new['c_mv_delta_calibrated'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS (Calibrated by Rolling Estimation of Monthly Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# the fitting line
x_fit = np.linspace(df1M_ATM_calibrated_monthly_abc_new['RHS1'].min(), df1M_ATM_calibrated_monthly_abc_new['RHS1'].max(), 100)
X_fit = sm.add_constant(np.column_stack((x_fit, x_fit**2)))
y_fit = model.predict(X_fit)

#plot the delta_bs vs delta_mv line and fitting line
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_monthly_abc_new['c_delta'], df1M_ATM_calibrated_monthly_abc_new['c_mv_delta_calibrated'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')


plt.plot(x_fit, y_fit, label = 'Quadratic Fit', color = 'red')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS (Calibrated by Rolling Estimation of Monthly Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# plot expected changes in implied vol wrt delta_bs
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_monthly_abc_new['E_chg_iv'], df1M_ATM_calibrated_monthly_abc_new['c_delta'],label = 'Expected Change in IV vs BS Delta', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('BS Delta')
plt.title('Plot of Expected Change in IV vs BS Delta (Calibrated by Rolling Estimation of Monthly Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# plot expected changes in implied vol wrt delta_mv
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_monthly_abc_new['E_chg_iv'], df1M_ATM_calibrated_monthly_abc_new['c_mv_delta_calibrated'],label = 'Expected Change in IV vs MV Delta ', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('MV Delta')
plt.title('Plot of Expected Change in IV vs MV Delta (Calibrated by Rolling Estimation of Monthly Frequency)')
plt.legend()

plt.grid(True)
plt.show()
