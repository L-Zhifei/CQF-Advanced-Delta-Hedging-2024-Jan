# %%
# %pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import scipy.stats as stats

# %%
import os
os.getcwd()
# Out:
# '/Users/zhifei_li/Desktop/Knowledge/Investment Research/CQF/Courses/Final Project/Advanced Hedging with Greeks/Workings'

# %%
### Set working directory
dir_path = "/Users/zhifei_li/Desktop/Knowledge/Investment Research/CQF/Courses/Final Project/Advanced Hedging with Greeks/Workings"
os.chdir(dir_path)

# %% [markdown]
# # 0.1. Data Import

# %% [markdown]
# ## SPX Data

# %%
spx_path = "/Data/Index/SPX Index"

# %%
import os

# %%
def combine_year_files(year_folder_path, year):
    # Initialize an empty list to store DataFrames
    dataframes = []

    # Iterate over each month (01 to 12)
    for month in range(1, 13):
        file_name = f"spx_eod_{year}{month:02d}.txt"
        file_path = os.path.join(year_folder_path, file_name)
        
        if os.path.exists(file_path):
            # Read the data file into a DataFrame
            df = pd.read_csv(file_path, delimiter=',')  
            dataframes.append(df)
        else:
            print(f"File {file_path} does not exist.")

    # Concatenate all DataFrames into one
    if dataframes:
        combined_df = pd.concat(dataframes, ignore_index=True)
        return combined_df
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no files were read

# Example usage
year_folder_path = dir_path + spx_path + '/spx_eod_2010'  # Replace with your specific year folder path
year = 2010  # Specify the year
df_2010 = combine_year_files(year_folder_path, year)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')

# %%
year_folder_path = dir_path + spx_path + '/spx_eod_2011'
year = 2011  # Specify the year
df_2011 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2012'
year = 2012  # Specify the year
df_2012 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2013'
year = 2013  # Specify the year
df_2013 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2014'
year = 2014  # Specify the year
df_2014 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2015'
year = 2015  # Specify the year
df_2015 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2016'
year = 2016  # Specify the year
df_2016 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2017'
year = 2017  # Specify the year
df_2017 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2018'
year = 2018  # Specify the year
df_2018 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2019'
year = 2019  # Specify the year
df_2019 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2020'
year = 2020  # Specify the year
df_2020 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2021'
year = 2021  # Specify the year
df_2021 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2022'
year = 2022  # Specify the year
df_2022 = combine_year_files(year_folder_path, year)

year_folder_path = dir_path + spx_path + '/spx_eod_2023'
year = 2023  # Specify the year
df_2023 = combine_year_files(year_folder_path, year)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2799361245.py:12: DtypeWarning: Columns (8,9,10,11,12,15,17,18,20,21,23,24,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=',')

# %%
df_201023 = pd.concat([df_2010,df_2011,df_2012,df_2013,df_2014,df_2015,df_2016,df_2017,df_2018,df_2019,df_2020,df_2021,df_2022,df_2023])

# %%
len(df_201023)
# Out:
# 15556477

# %% [markdown]
# ## SPX Index Data in full

# %%
df_201023.head()
# Out:
#    [QUOTE_UNIXTIME]   [QUOTE_READTIME]  [QUOTE_DATE]   [QUOTE_TIME_HOURS]  \
# 0        1262638800   2010-01-04 16:00    2010-01-04                 16.0
# 1        1262638800   2010-01-04 16:00    2010-01-04                 16.0
# 2        1262638800   2010-01-04 16:00    2010-01-04                 16.0
# 3        1262638800   2010-01-04 16:00    2010-01-04                 16.0
# 4        1262638800   2010-01-04 16:00    2010-01-04                 16.0
#
#     [UNDERLYING_LAST]  [EXPIRE_DATE]   [EXPIRE_UNIX]   [DTE]  [C_DELTA]  \
# 0             1132.99     2010-01-07      1262898000     3.0   1.000000
# 1             1132.99     2010-01-07      1262898000     3.0   1.000000
# 2             1132.99     2010-01-07      1262898000     3.0   1.000000
# 3             1132.99     2010-01-07      1262898000     3.0   1.000000
# 4             1132.99     2010-01-07      1262898000     3.0   1.000000
#
#    [C_GAMMA]  ...   [P_LAST]   [P_DELTA]  [P_GAMMA]   [P_VEGA]   [P_THETA]  \
# 0   0.000000  ...   0.050000   -0.000770   0.000040   0.004390   -0.021160
# 1   0.000000  ...   0.050000   -0.002030   0.000060   0.009110   -0.040560
# 2   0.000000  ...   0.100000   -0.003690   0.000220   0.013020   -0.058980
# 3   0.000000  ...   0.150000   -0.008940   0.000380   0.027860   -0.127580
# 4   0.000000  ...   0.200000   -0.012510   0.000660   0.038570   -0.156920
#
#       [P_RHO]     [P_IV]   [P_VOLUME]  [STRIKE_DISTANCE]  \
# 0   -0.000490   0.640130   550.000000              208.0
# 1    0.000000   0.598590                           183.0
# 2   -0.000710   0.538850                           158.0
# 3   -0.000860   0.502730                           133.0
# 4   -0.001470   0.427250   720.000000              108.0
#
#     [STRIKE_DISTANCE_PCT]
# 0                   0.184
# 1                   0.162
# 2                   0.139
# 3                   0.117
# 4                   0.095
#
# [5 rows x 33 columns]

# %%
df_201023.columns.values
# Out:
# array(['[QUOTE_UNIXTIME]', ' [QUOTE_READTIME]', ' [QUOTE_DATE]',
#        ' [QUOTE_TIME_HOURS]', ' [UNDERLYING_LAST]', ' [EXPIRE_DATE]',
#        ' [EXPIRE_UNIX]', ' [DTE]', ' [C_DELTA]', ' [C_GAMMA]',
#        ' [C_VEGA]', ' [C_THETA]', ' [C_RHO]', ' [C_IV]', ' [C_VOLUME]',
#        ' [C_LAST]', ' [C_SIZE]', ' [C_BID]', ' [C_ASK]', ' [STRIKE]',
#        ' [P_BID]', ' [P_ASK]', ' [P_SIZE]', ' [P_LAST]', ' [P_DELTA]',
#        ' [P_GAMMA]', ' [P_VEGA]', ' [P_THETA]', ' [P_RHO]', ' [P_IV]',
#        ' [P_VOLUME]', ' [STRIKE_DISTANCE]', ' [STRIKE_DISTANCE_PCT]'],
#       dtype=object)

# %%
df_201023.columns = ['unixtime','time','date','hours','underlying','expiry','expire_unit','dte','c_delta','c_gamma','c_vega','c_theta','c_rho','c_iv','c_volume','c_last','c_size','c_bid','c_ask','strike',
                 'p_bid','p_ask','p_size','p_last','p_delta','p_gamma','p_vega','p_theta','p_rho','p_iv','p_volume','strike_distance','strike_distance_pct']

# %%
unique_strik_df_201023 = df_201023['strike'].unique()

# %%
unique_strik_df_201023.shape
# Out:
# (1029,)

# %% [markdown]
# # 0.2. Bucketing

# %%
df_201023['c_delta'] = df_201023['c_delta'].apply(pd.to_numeric, errors='coerce')

# %%
#bucketing by moneyness
def moneyness_bucketing(value):
    if 0.45 <= abs(value) <= 0.55:
        return 'ATM'
    elif 0 <= abs(value) <= 0.4:
        return 'OTM'
    elif 0.6 <= abs(value) <= 1:
        return 'ITM'
    else:
        return None

df_201023['moneyness_bucket'] = df_201023['c_delta'].apply(moneyness_bucketing)

# %%
# bucketing by maturities
def days_to_maturity_bucketing(value):
    if 0<=value<=30:
        return '1M'
    elif 31<=value<=60:
        return '2M'
    elif 61<=value<=91:
        return '3M'
    elif 92<=value<=122:
        return '4M'
    elif 123<=value<=182:
        return '6M'
    elif 183<=value<=365:
        return '12M'
    elif value >= 366:
        return '12MM'
    else:
        return None

df_201023['maturity_bucket'] = df_201023['dte'].apply(days_to_maturity_bucketing)

# %%
df_201023.head()
# Out:
#      unixtime               time         date  hours  underlying       expiry  \
# 0  1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99   2010-01-07
# 1  1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99   2010-01-07
# 2  1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99   2010-01-07
# 3  1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99   2010-01-07
# 4  1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99   2010-01-07
#
#    expire_unit  dte  c_delta    c_gamma  ...    p_gamma     p_vega  \
# 0   1262898000  3.0      1.0   0.000000  ...   0.000040   0.004390
# 1   1262898000  3.0      1.0   0.000000  ...   0.000060   0.009110
# 2   1262898000  3.0      1.0   0.000000  ...   0.000220   0.013020
# 3   1262898000  3.0      1.0   0.000000  ...   0.000380   0.027860
# 4   1262898000  3.0      1.0   0.000000  ...   0.000660   0.038570
#
#       p_theta       p_rho       p_iv     p_volume strike_distance  \
# 0   -0.021160   -0.000490   0.640130   550.000000           208.0
# 1   -0.040560    0.000000   0.598590                        183.0
# 2   -0.058980   -0.000710   0.538850                        158.0
# 3   -0.127580   -0.000860   0.502730                        133.0
# 4   -0.156920   -0.001470   0.427250   720.000000           108.0
#
#   strike_distance_pct moneyness_bucket  maturity_bucket
# 0               0.184              ITM               1M
# 1               0.162              ITM               1M
# 2               0.139              ITM               1M
# 3               0.117              ITM               1M
# 4               0.095              ITM               1M
#
# [5 rows x 35 columns]

# %%
df_201023.isna().sum()
# Out:
# unixtime                    0
# time                        0
# date                        0
# hours                       0
# underlying                  0
# expiry                      0
# expire_unit                 0
# dte                         0
# c_delta                   534
# c_gamma                     0
# c_vega                      0
# c_theta                     0
# c_rho                       0
# c_iv                        0
# c_volume                    0
# c_last                      0
# c_size                      0
# c_bid                       0
# c_ask                       0
# strike                      0
# p_bid                       0
# p_ask                       0
# p_size                      0
# p_last                      0
# p_delta                     0
# p_gamma                     0
# p_vega                      0
# p_theta                     0
# p_rho                       0
# p_iv                        0
# p_volume                    0
# strike_distance             0
# strike_distance_pct         0
# moneyness_bucket       616786
# maturity_bucket        101625
# dtype: int64

# %%
df_201023[df_201023['moneyness_bucket'].isna()]
# Out:
#            unixtime               time         date  hours  underlying  \
# 129      1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99
# 132      1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99
# 292      1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99
# 293      1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99
# 298      1262638800   2010-01-04 16:00   2010-01-04   16.0     1132.99
# ...             ...                ...          ...    ...         ...
# 2009065  1703883600   2023-12-29 16:00   2023-12-29   16.0     4772.17
# 2009066  1703883600   2023-12-29 16:00   2023-12-29   16.0     4772.17
# 2009067  1703883600   2023-12-29 16:00   2023-12-29   16.0     4772.17
# 2009073  1703883600   2023-12-29 16:00   2023-12-29   16.0     4772.17
# 2009074  1703883600   2023-12-29 16:00   2023-12-29   16.0     4772.17
#
#               expiry  expire_unit     dte  c_delta    c_gamma  ...    p_gamma  \
# 129       2010-01-14   1263502800    10.0  0.58839   0.011950  ...   0.012100
# 132       2010-01-14   1263502800    10.0  0.40086   0.012590  ...   0.013180
# 292       2010-02-18   1266526800    45.0  0.59339   0.005330  ...   0.005240
# 293       2010-02-18   1266526800    45.0  0.56734   0.005400  ...   0.005420
# 298       2010-02-18   1266526800    45.0  0.42435   0.005720  ...   0.005780
# ...              ...          ...     ...      ...        ...  ...        ...
# 2009065   2029-12-21   1892581200  2184.0  0.57589    0.00013  ...    0.00036
# 2009066   2029-12-21   1892581200  2184.0  0.56424    0.00013  ...     0.0004
# 2009067   2029-12-21   1892581200  2184.0  0.55204    0.00007  ...    0.00041
# 2009073   2029-12-21   1892581200  2184.0  0.43376    0.00016  ...        0.0
# 2009074   2029-12-21   1892581200  2184.0  0.40602    0.00015  ...        0.0
#
#             p_vega     p_theta       p_rho       p_iv     p_volume  \
# 129       0.764450   -0.630970   -0.143770   0.163730
# 132       0.755020   -0.590090   -0.211400   0.148310    45.000000
# 292       1.557070   -0.343420   -0.610140   0.184290   294.000000
# 293       1.577770   -0.345300   -0.649800   0.181600    83.000000
# 298       1.567850   -0.330330   -0.868610   0.167770     1.000000
# ...            ...         ...         ...        ...          ...
# 2009065   37.07644    -0.05115   -64.61351   0.174590
# 2009066   36.46357     -0.0457     -63.349   0.167670
# 2009067   35.19295    -0.03984   -60.73328   0.161020
# 2009073        0.0         0.0         0.0
# 2009074        0.0         0.0         0.0
#
#         strike_distance strike_distance_pct moneyness_bucket  maturity_bucket
# 129                 8.0               0.007             None               1M
# 132                 7.0               0.006             None               1M
# 292                18.0               0.016             None               2M
# 293                13.0               0.011             None               2M
# 298                12.0               0.011             None               2M
# ...                 ...                 ...              ...              ...
# 2009065           327.8               0.069             None             12MM
# 2009066           427.8               0.090             None             12MM
# 2009067           527.8               0.111             None             12MM
# 2009073          1427.8               0.299             None             12MM
# 2009074          1627.8               0.341             None             12MM
#
# [616786 rows x 35 columns]

# %%
# qqq_2012to2023_K210 = qqq_2012to2023[qqq_2012to2023['strike'] == 210]

# %%
#len(qqq_2012to2023_K210)

# %%
df_201023_call = df_201023[['date','underlying','expiry','dte','c_delta','c_gamma','c_vega','c_theta','c_rho','c_iv','c_volume','c_last','c_size','c_bid','c_ask','strike','moneyness_bucket','maturity_bucket']]

# %% [markdown]
# ### Remove the null IV or replace with previous IV

# %% [markdown]
# #### Remove null IV

# %%
df_201023_call_nn = df_201023_call[df_201023_call['c_iv'] != ' ']
#might take 17.1s

# %% [markdown]
# # Initial Attempt on Bucket of 6M and ATM

# %% [markdown]
# # CHANGE BUCKET HERE

# %%
df1M_ATM = df_201023_call_nn[(df_201023_call_nn['moneyness_bucket'] == "ATM")&(df_201023_call_nn['maturity_bucket'] == '6M')]

# %%
len(df1M_ATM)
# Out:
# 78375

# %%
#check for the nulls in all columns within this bucket
df1M_ATM.isnull().sum()
# Out:
# date                0
# underlying          0
# expiry              0
# dte                 0
# c_delta             0
# c_gamma             0
# c_vega              0
# c_theta             0
# c_rho               0
# c_iv                0
# c_volume            0
# c_last              0
# c_size              0
# c_bid               0
# c_ask               0
# strike              0
# moneyness_bucket    0
# maturity_bucket     0
# dtype: int64

# %%
df_201023_call_nn['c_iv'] = df_201023_call_nn['c_iv'].apply(pd.to_numeric, errors='coerce')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/1875108132.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['c_iv'] = df_201023_call_nn['c_iv'].apply(pd.to_numeric, errors='coerce')

# %%
# some IVs are not null but empty, like " "
#check for the nulls in all columns within this bucket
df_201023_call_nn.isnull().sum()
# Out:
# date                     0
# underlying               0
# expiry                   0
# dte                      0
# c_delta                  0
# c_gamma                  0
# c_vega                   0
# c_theta                  0
# c_rho                    0
# c_iv                     0
# c_volume                 0
# c_last                   0
# c_size                   0
# c_bid                    0
# c_ask                    0
# strike                   0
# moneyness_bucket    616252
# maturity_bucket      79922
# dtype: int64

# %%
df_201023_call_nn['1m_c_iv'] = np.nan
df_201023_call_nn['3m_c_iv'] = np.nan
df_201023_call_nn['6m_c_iv'] = np.nan
df_201023_call_nn['9m_c_iv'] = np.nan
df_201023_call_nn['12m_c_iv'] = np.nan
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/508980085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['1m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/508980085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['3m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/508980085.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['6m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/508980085.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['9m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/508980085.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['12m_c_iv'] = np.nan

# %%
df_201023_call_nn.isnull().sum()
# Out:
# date                       0
# underlying                 0
# expiry                     0
# dte                        0
# c_delta                    0
# c_gamma                    0
# c_vega                     0
# c_theta                    0
# c_rho                      0
# c_iv                       0
# c_volume                   0
# c_last                     0
# c_size                     0
# c_bid                      0
# c_ask                      0
# strike                     0
# moneyness_bucket      616252
# maturity_bucket        79922
# 1m_c_iv             11900876
# 3m_c_iv             11900876
# 6m_c_iv             11900876
# 9m_c_iv             11900876
# 12m_c_iv            11900876
# dtype: int64

# %% [markdown]
# # 1. Get the Term Structure of IV for 1M, 3M, 6M, 9M and 12M expiry

# %%
df_201023_call_nn.dtypes
# Out:
# date                 object
# underlying          float64
# expiry               object
# dte                 float64
# c_delta             float64
# c_gamma              object
# c_vega               object
# c_theta              object
# c_rho                object
# c_iv                float64
# c_volume             object
# c_last               object
# c_size               object
# c_bid                object
# c_ask                object
# strike              float64
# moneyness_bucket     object
# maturity_bucket      object
# 1m_c_iv             float64
# 3m_c_iv             float64
# 6m_c_iv             float64
# 9m_c_iv             float64
# 12m_c_iv            float64
# dtype: object

# %%
df_201023_call_nn['date'] = pd.to_datetime(df_201023_call_nn['date'])
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2378075591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['date'] = pd.to_datetime(df_201023_call_nn['date'])

# %%
df_201023_call_nn['after_1M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 1)
df_201023_call_nn['after_3M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 3)
df_201023_call_nn['after_6M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 6)
df_201023_call_nn['after_9M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 9)
df_201023_call_nn['after_12M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 12)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3939291843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_1M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 1)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3939291843.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_3M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 3)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3939291843.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_6M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 6)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3939291843.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_9M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 9)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3939291843.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_12M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 12)

# %%
df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_1M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_3M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_6M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_9M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_12M'], df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/4158665109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_1M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/4158665109.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_3M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/4158665109.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_6M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/4158665109.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_9M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/4158665109.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_12M'], df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn.dtypes
# Out:
# date                datetime64[ns]
# underlying                 float64
# expiry                      object
# dte                        float64
# c_delta                    float64
# c_gamma                     object
# c_vega                      object
# c_theta                     object
# c_rho                       object
# c_iv                       float64
# c_volume                    object
# c_last                      object
# c_size                      object
# c_bid                       object
# c_ask                       object
# strike                     float64
# moneyness_bucket            object
# maturity_bucket             object
# 1m_c_iv                    float64
# 3m_c_iv                    float64
# 6m_c_iv                    float64
# 9m_c_iv                    float64
# 12m_c_iv                   float64
# after_1M            datetime64[ns]
# after_3M            datetime64[ns]
# after_6M            datetime64[ns]
# after_9M            datetime64[ns]
# after_12M           datetime64[ns]
# dtype: object

# %%
df_201023_call_nn['expiry'] = pd.to_datetime(df_201023_call_nn['expiry'])
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3893983512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['expiry'] = pd.to_datetime(df_201023_call_nn['expiry'])

# %%
df_201023_call_nn['c_vega'] = df_201023_call_nn['c_vega'].apply(pd.to_numeric, errors='coerce')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3475713582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['c_vega'] = df_201023_call_nn['c_vega'].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# sometimes there is no IV data on the exact expiry date, so we can remove them or find the nearest as it is. Let's try the second approach first.
# ## Approach1: Find the nearest IV if no IV at certain maturity date exists

# %%
# lots of dates there is not expiry date exactly equals the after_1M, 3M, 6M, 9M and 12M, so we fill in with the nearest expiry to these after_XM dates
df_201023_call_nn['diff_1M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_1M']).dt.days.abs()
min_diff_idx_1M = df_201023_call_nn.groupby('date')['diff_1M'].idxmin()
df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_1M), df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3919769646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['diff_1M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_1M']).dt.days.abs()
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3919769646.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_1M), df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn['diff_3M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_3M']).dt.days.abs()
min_diff_idx_3M = df_201023_call_nn.groupby('date')['diff_3M'].idxmin()
df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_3M), df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/1324646977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['diff_3M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_3M']).dt.days.abs()
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/1324646977.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_3M), df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn['diff_6M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_6M']).dt.days.abs()
min_diff_idx_6M = df_201023_call_nn.groupby('date')['diff_6M'].idxmin()
df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_6M), df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/228897655.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['diff_6M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_6M']).dt.days.abs()
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/228897655.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_6M), df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn['diff_9M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_9M']).dt.days.abs()
min_diff_idx_9M = df_201023_call_nn.groupby('date')['diff_9M'].idxmin()
df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_9M), df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3914460780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['diff_9M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_9M']).dt.days.abs()
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3914460780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_9M), df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn['diff_12M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_12M']).dt.days.abs()
min_diff_idx_12M = df_201023_call_nn.groupby('date')['diff_12M'].idxmin()
df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_12M), df_201023_call_nn['c_iv'], np.nan)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2006450873.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['diff_12M'] = (df_201023_call_nn['expiry'] - df_201023_call_nn['after_12M']).dt.days.abs()
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2006450873.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn.index.isin(min_diff_idx_12M), df_201023_call_nn['c_iv'], np.nan)

# %%
df_201023_call_nn[df_201023_call_nn['date'] == '2023-01-03']['1m_c_iv']
# Out:
# Series([], Name: 1m_c_iv, dtype: float64)

# %%
def grouped_bfill(group):
    group['1m_c_iv'] = group['1m_c_iv'].fillna(method = "bfill")
    group['3m_c_iv'] = group['3m_c_iv'].fillna(method = "bfill")
    group['6m_c_iv'] = group['6m_c_iv'].fillna(method = "bfill")
    group['9m_c_iv'] = group['9m_c_iv'].fillna(method = "bfill")
    group['12m_c_iv'] = group['12m_c_iv'].fillna(method = "bfill")
    return group

# %%
df_201023_call_nn = df_201023_call_nn.groupby('date').apply(grouped_bfill)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/1538367704.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   group['1m_c_iv'] = group['1m_c_iv'].fillna(method = "bfill")
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/1538367704.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   group['3m_c_iv'] = group['3m_c_iv'].fillna(method = "bfill")
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/1538367704.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   group['6m_c_iv'] = group['6m_c_iv'].fillna(method = "bfill")
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/1538367704.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   group['9m_c_iv'] = group['9m_c_iv'].fillna(method = "bfill")
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/1538367704.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   group['12m_c_iv'] = group['12m_c_iv'].fillna(method = "bfill")
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2635986667.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_201023_call_nn = df_201023_call_nn.groupby('date').apply(grouped_bfill)

# %%
# drop the after_XM
df_201023_call_nn = df_201023_call_nn.drop(columns = ['after_1M','after_3M','after_6M','after_9M','after_12M','diff_1M','diff_3M','diff_6M','diff_9M','diff_12M'])

# %%
df_201023_call_nn_nearest = df_201023_call_nn

# %%
df_201023_call_nn_nearest.isna().sum()
# Out:
# date                      0
# underlying                0
# expiry                    0
# dte                       0
# c_delta                   0
# c_gamma                   0
# c_vega                    0
# c_theta                   0
# c_rho                     0
# c_iv                      0
# c_volume                  0
# c_last                    0
# c_size                    0
# c_bid                     0
# c_ask                     0
# strike                    0
# moneyness_bucket     616252
# maturity_bucket       79922
# 1m_c_iv             2017393
# 3m_c_iv             1723430
# 6m_c_iv             1268160
# 9m_c_iv             1022602
# 12m_c_iv             752372
# dtype: int64

# %%
#iv term structure
df_201023_call_nn_nearest_iv_ts = df_201023_call_nn_nearest.drop_duplicates(subset = ['date'], keep = 'first')

# %%
df_201023_call_nn_nearest_iv_ts
# Out:
#                          date  underlying     expiry  dte  c_delta    c_gamma  \
# date
# 2010-01-04 6       2010-01-04     1132.99 2010-01-07  3.0  0.96734   0.002540
# 2010-01-05 945     2010-01-05     1136.40 2010-01-07  2.0  0.75900   0.020560
# 2010-01-06 1882    2010-01-06     1136.99 2010-01-07  1.0  0.79670   0.020920
# 2010-01-07 2825    2010-01-07     1141.48 2010-01-07  0.0  0.91761   0.013420
# 2010-01-08 3767    2010-01-08     1144.70 2010-01-14  6.0  1.00000   0.000000
# ...                       ...         ...        ...  ...      ...        ...
# 2023-12-22 1963713 2023-12-22     4755.11 2023-12-22  0.0  1.00000        0.0
# 2023-12-26 1972767 2023-12-26     4774.94 2023-12-26  0.0  0.99808        0.0
# 2023-12-27 1982011 2023-12-27     4782.50 2023-12-27  0.0  0.05014    0.08597
# 2023-12-28 1990970 2023-12-28     4783.83 2023-12-28  0.0  0.99940        0.0
# 2023-12-29 2000050 2023-12-29     4772.17 2023-12-29  0.0  0.99963        0.0
#
#                      c_vega     c_theta      c_rho      c_iv  ...  \
# date                                                          ...
# 2010-01-04 6        0.07711   -0.109830   0.023630   0.29808  ...
# 2010-01-05 945      0.31971   -0.736550   0.056430   0.15651  ...
# 2010-01-06 1882     0.23676   -0.873410   0.038210   0.17280  ...
# 2010-01-07 2825     0.08995   -0.320540   0.016590   0.20482  ...
# 2010-01-08 3767     0.00000    0.000000   0.000000  -0.00023  ...
# ...                     ...         ...        ...       ...  ...
# 2023-12-22 1963713  0.00000     -0.4818    0.08785   0.00008  ...
# 2023-12-26 1972767  0.01086    -1.46029    0.02345  11.50847  ...
# 2023-12-27 1982011  0.22042    -0.02463      0.005   0.00549  ...
# 2023-12-28 1990970  0.00756    -0.86962    0.02345  10.87366  ...
# 2023-12-29 2000050  0.00479    -0.47978    0.03757   6.72564  ...
#
#                           c_bid        c_ask  strike moneyness_bucket  \
# date
# 2010-01-04 6          57.190000    59.000000  1075.0              ITM
# 2010-01-05 945        12.590000    13.900000  1125.0              ITM
# 2010-01-06 1882       12.090000    14.510000  1125.0              ITM
# 2010-01-07 2825       15.500000    18.100000  1125.0              ITM
# 2010-01-08 3767      593.500000   595.910000   550.0              ITM
# ...                         ...          ...     ...              ...
# 2023-12-22 1963713        369.1        371.6  4385.0              ITM
# 2023-12-26 1972767       3575.2       3577.6  1200.0              ITM
# 2023-12-27 1982011          0.0         0.05  4785.0              OTM
# 2023-12-28 1990970       3584.3       3585.1  1200.0              ITM
# 2023-12-29 2000050       2869.6       2875.7  1900.0              ITM
#
#                    maturity_bucket  1m_c_iv  3m_c_iv  6m_c_iv  9m_c_iv  \
# date
# 2010-01-04 6                    1M  0.16969  0.28876  0.27779  0.27541
# 2010-01-05 945                  1M  0.23767  0.26365  0.26165  0.22220
# 2010-01-06 1882                 1M  0.19795  0.14768  0.14885  0.26217
# 2010-01-07 2825                 1M  0.24470  0.24326  0.18279  0.23415
# 2010-01-08 3767                 1M  0.23196  0.14736 -0.00008  0.18271
# ...                            ...      ...      ...      ...      ...
# 2023-12-22 1963713              1M  1.83818  0.12021  0.43725  0.28586
# 2023-12-26 1972767              1M  0.10445  0.21300  0.20769  0.10305
# 2023-12-27 1982011              1M  0.23864  0.12175 -0.00031  0.31331
# 2023-12-28 1990970              1M  0.00014  0.09874  0.53267  0.09373
# 2023-12-29 2000050              1M  1.88043  1.12276  0.10290  1.14090
#
#                     12m_c_iv
# date
# 2010-01-04 6         0.26812
# 2010-01-05 945       0.41198
# 2010-01-06 1882      0.25994
# 2010-01-07 2825      0.15733
# 2010-01-08 3767      0.51525
# ...                      ...
# 2023-12-22 1963713   0.11469
# 2023-12-26 1972767   0.11731
# 2023-12-27 1982011   0.84911
# 2023-12-28 1990970   0.14312
# 2023-12-29 2000050   0.17091
#
# [3499 rows x 23 columns]

# %%
# drop index
df_201023_call_nn_nearest_iv_ts['date_ts'] = df_201023_call_nn_nearest_iv_ts['date']
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2685722844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn_nearest_iv_ts['date_ts'] = df_201023_call_nn_nearest_iv_ts['date']

# %%
# debug for all to check no null in these iv

# %%
df_201023_call_nn_nearest_iv_ts = df_201023_call_nn_nearest_iv_ts[['date_ts','underlying','strike','1m_c_iv','3m_c_iv','6m_c_iv','9m_c_iv','12m_c_iv']]

# %%
df_201023_call_nn_nearest_iv_ts = df_201023_call_nn_nearest_iv_ts.reset_index()

# %%
df_201023_call_nn_nearest_iv_ts
# Out:
#            date  level_1    date_ts  underlying  strike  1m_c_iv  3m_c_iv  \
# 0    2010-01-04        6 2010-01-04     1132.99  1075.0  0.16969  0.28876
# 1    2010-01-05      945 2010-01-05     1136.40  1125.0  0.23767  0.26365
# 2    2010-01-06     1882 2010-01-06     1136.99  1125.0  0.19795  0.14768
# 3    2010-01-07     2825 2010-01-07     1141.48  1125.0  0.24470  0.24326
# 4    2010-01-08     3767 2010-01-08     1144.70   550.0  0.23196  0.14736
# ...         ...      ...        ...         ...     ...      ...      ...
# 3494 2023-12-22  1963713 2023-12-22     4755.11  4385.0  1.83818  0.12021
# 3495 2023-12-26  1972767 2023-12-26     4774.94  1200.0  0.10445  0.21300
# 3496 2023-12-27  1982011 2023-12-27     4782.50  4785.0  0.23864  0.12175
# 3497 2023-12-28  1990970 2023-12-28     4783.83  1200.0  0.00014  0.09874
# 3498 2023-12-29  2000050 2023-12-29     4772.17  1900.0  1.88043  1.12276
#
#       6m_c_iv  9m_c_iv  12m_c_iv
# 0     0.27779  0.27541   0.26812
# 1     0.26165  0.22220   0.41198
# 2     0.14885  0.26217   0.25994
# 3     0.18279  0.23415   0.15733
# 4    -0.00008  0.18271   0.51525
# ...       ...      ...       ...
# 3494  0.43725  0.28586   0.11469
# 3495  0.20769  0.10305   0.11731
# 3496 -0.00031  0.31331   0.84911
# 3497  0.53267  0.09373   0.14312
# 3498  0.10290  1.14090   0.17091
#
# [3499 rows x 10 columns]

# %%
iv_cols = ['1m_c_iv', '3m_c_iv', '6m_c_iv', '9m_c_iv', '12m_c_iv']
df_201023_call_nn_nearest_iv_ts[iv_cols] = df_201023_call_nn_nearest_iv_ts[iv_cols].apply(pd.to_numeric, errors='coerce')

# %%
# plot the term structure in the diagram
groups = df_201023_call_nn_nearest_iv_ts


plt.figure(figsize=(14, 8))
plt.plot(groups['date_ts'], groups['1m_c_iv'], marker='', linestyle='-', label='1M IV')
plt.plot(groups['date_ts'], groups['3m_c_iv'], marker='', linestyle='-', label='3M IV')
plt.plot(groups['date_ts'], groups['6m_c_iv'], marker='', linestyle='-', label='6M IV')
plt.plot(groups['date_ts'], groups['9m_c_iv'], marker='', linestyle='-', label='9M IV')
plt.plot(groups['date_ts'], groups['12m_c_iv'], marker='', linestyle='-', label='12M IV')
plt.title(f'IV for S&P Call Option over Time of different maturities 1M, 3M, 6M, 9M, 12M')
plt.xlabel('date')
plt.ylabel('IV')
plt.legend()
plt.grid(True)
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %%
# plot the term structure in the diagram
groups = df_201023_call_nn_nearest_iv_ts

plt.figure(figsize=(14, 8))
plt.plot(groups['date_ts'], groups['1m_c_iv'], marker='o', linestyle='-', label='1M IV')
plt.plot(groups['date_ts'], groups['3m_c_iv'], marker='s', linestyle='-', label='3M IV')
plt.plot(groups['date_ts'], groups['6m_c_iv'], marker='^', linestyle='-', label='6M IV')
plt.plot(groups['date_ts'], groups['9m_c_iv'], marker='d', linestyle='-', label='9M IV')
plt.plot(groups['date_ts'], groups['12m_c_iv'], marker='x', linestyle='-', label='12M IV')
plt.title(f'IV for QQQ ETF Call Option over Time of different maturities 1M, 3M, 6M, 9M, 12M of different moneyness, at K = 210')
plt.xlabel('date')
plt.ylabel('IV')
plt.legend()
plt.grid(True)
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Approach 2: remove the null

# %%
df_201023_call_nn = df_201023_call[df_201023_call['c_iv'] != ' ']

df_201023_call_nn['c_iv'] = df_201023_call_nn['c_iv'].apply(pd.to_numeric, errors='coerce')

df_201023_call_nn['1m_c_iv'] = np.nan
df_201023_call_nn['3m_c_iv'] = np.nan
df_201023_call_nn['6m_c_iv'] = np.nan
df_201023_call_nn['9m_c_iv'] = np.nan
df_201023_call_nn['12m_c_iv'] = np.nan

df_201023_call_nn['date'] = pd.to_datetime(df_201023_call_nn['date'])
df_201023_call_nn['expiry'] = pd.to_datetime(df_201023_call_nn['expiry'])

df_201023_call_nn['after_1M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 1)
df_201023_call_nn['after_3M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 3)
df_201023_call_nn['after_6M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 6)
df_201023_call_nn['after_9M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 9)
df_201023_call_nn['after_12M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 12)

df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_1M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_3M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_6M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_9M'], df_201023_call_nn['c_iv'], np.nan)
df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_12M'], df_201023_call_nn['c_iv'], np.nan)

df_201023_call_nn['c_vega'] = df_201023_call_nn['c_vega'].apply(pd.to_numeric, errors='coerce')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['c_iv'] = df_201023_call_nn['c_iv'].apply(pd.to_numeric, errors='coerce')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['1m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['3m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['6m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['9m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['12m_c_iv'] = np.nan
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['date'] = pd.to_datetime(df_201023_call_nn['date'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['expiry'] = pd.to_datetime(df_201023_call_nn['expiry'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_1M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 1)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_3M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 3)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_6M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 6)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_9M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 9)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['after_12M'] = df_201023_call_nn['date'] + pd.DateOffset(months  = 12)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['1m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_1M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['3m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_3M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['6m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_6M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['9m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_9M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['12m_c_iv'] = np.where(df_201023_call_nn['expiry'] == df_201023_call_nn['after_12M'], df_201023_call_nn['c_iv'], np.nan)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2229713605.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_201023_call_nn['c_vega'] = df_201023_call_nn['c_vega'].apply(pd.to_numeric, errors='coerce')

# %%
df_201023_call_nn.isna().sum()
# Out:
# date                       0
# underlying                 0
# expiry                     0
# dte                        0
# c_delta                    0
# c_gamma                    0
# c_vega                     0
# c_theta                    0
# c_rho                      0
# c_iv                       0
# c_volume                   0
# c_last                     0
# c_size                     0
# c_bid                      0
# c_ask                      0
# strike                     0
# moneyness_bucket      616252
# maturity_bucket        79922
# 1m_c_iv             11775199
# 3m_c_iv             11858735
# 6m_c_iv             11891968
# 9m_c_iv             11891352
# 12m_c_iv            11892870
# after_1M                   0
# after_3M                   0
# after_6M                   0
# after_9M                   0
# after_12M                  0
# dtype: int64

# %%
len(df_201023_call_nn)
# Out:
# 11900876

# %%
no1M = ~(df_201023_call_nn['1m_c_iv'].isna())
no3M = ~(df_201023_call_nn['3m_c_iv'].isna())
no6M = ~(df_201023_call_nn['6m_c_iv'].isna())
no9M = ~(df_201023_call_nn['9m_c_iv'].isna())
no12M = ~(df_201023_call_nn['12m_c_iv'].isna())

df_201023_call_nn_nonull = df_201023_call_nn[no1M&no3M&no6M&no9M&no12M]

# %%
def grouped_bfill(group):
    group['1m_c_iv'] = group['1m_c_iv'].fillna(method = "bfill")
    group['3m_c_iv'] = group['3m_c_iv'].fillna(method = "bfill")
    group['6m_c_iv'] = group['6m_c_iv'].fillna(method = "bfill")
    group['9m_c_iv'] = group['9m_c_iv'].fillna(method = "bfill")
    group['12m_c_iv'] = group['12m_c_iv'].fillna(method = "bfill")
    return group

# %%
df_201023_call_nn_nonull = df_201023_call_nn_nonull.groupby('date').apply(grouped_bfill)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3519310890.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_201023_call_nn_nonull = df_201023_call_nn_nonull.groupby('date').apply(grouped_bfill)

# %%
df_201023_call_nn_nonull_iv_ts = df_201023_call_nn_nonull.drop_duplicates(subset = ['date'], keep = 'first')

df_201023_call_nn_nonull_iv_ts['date_ts'] = df_201023_call_nn_nonull_iv_ts['date']
df_201023_call_nn_nonull_iv_ts = df_201023_call_nn_nonull_iv_ts[['date_ts','underlying','strike','1m_c_iv','3m_c_iv','6m_c_iv','9m_c_iv','12m_c_iv']]
df_201023_call_nn_nonull_iv_ts = df_201023_call_nn_nonull_iv_ts.reset_index()

iv_cols = ['1m_c_iv', '3m_c_iv', '6m_c_iv', '9m_c_iv', '12m_c_iv']
df_201023_call_nn_nonull_iv_ts[iv_cols] = df_201023_call_nn_nonull_iv_ts[iv_cols].apply(pd.to_numeric, errors='coerce')

# %%
df_201023_call_nn_nonull_iv_ts
# Out:
# Empty DataFrame
# Columns: [date, date_ts, underlying, strike, 1m_c_iv, 3m_c_iv, 6m_c_iv, 9m_c_iv, 12m_c_iv]
# Index: []

# %%
# # plot the term structure in the diagram
# groups = df1M_ATM_noull_iv_ts


# plt.figure(figsize=(14, 8))
# plt.plot(groups['date_ts'], groups['1m_c_iv'], marker='', linestyle='-', label='1M IV')
# plt.plot(groups['date_ts'], groups['3m_c_iv'], marker='', linestyle='-', label='3M IV')
# plt.plot(groups['date_ts'], groups['6m_c_iv'], marker='', linestyle='-', label='6M IV')
# plt.plot(groups['date_ts'], groups['9m_c_iv'], marker='', linestyle='-', label='9M IV')
# plt.plot(groups['date_ts'], groups['12m_c_iv'], marker='', linestyle='-', label='12M IV')
# plt.title(f'IV for QQQ ETF Call Option over Time of different maturities 1M, 3M, 6M, 9M, 12M of different moneyness, at K = 210')
# plt.xlabel('date')
# plt.ylabel('IV')
# plt.legend()
# plt.grid(True)
# plt.xticks(rotation = 45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Using the 6M ATM Bucket

# %% [markdown]
# ### 2.0 Calculate the Option Price by BSM risk-neutral method

# %% [markdown]
# $c_t = S_t N(d_1) - K e^{(-r (T - t))} N (d_2)$

# %%
# import the risk free data: the three-month treasury bill rate

rf_rate = pd.read_csv(dir_path + "/Data" + "/3M_risk_free.csv")

# %%
rf_rate
# Out:
#             DATE DGS3MO
# 0     2009-12-01   0.06
# 1     2009-12-02   0.05
# 2     2009-12-03   0.06
# 3     2009-12-04   0.06
# 4     2009-12-07   0.04
# ...          ...    ...
# 3826  2024-07-31   5.41
# 3827  2024-08-01   5.37
# 3828  2024-08-02   5.29
# 3829  2024-08-05   5.35
# 3830  2024-08-06   5.34
#
# [3831 rows x 2 columns]

# %%
rf_rate.dtypes
# Out:
# DATE      object
# DGS3MO    object
# dtype: object

# %%
rf_rate['DATE'] = pd.to_datetime(rf_rate['DATE'])

# %%
rf_rate[rf_rate['DGS3MO'].isna()]
# Out:
# Empty DataFrame
# Columns: [DATE, DGS3MO]
# Index: []

# %%
# check for 10-09
rf_rate[rf_rate['DATE'] == '2017-10-09']
# Out:
#            DATE DGS3MO
# 2049 2017-10-09      .

# %%
rf_rate[rf_rate['DGS3MO'] == '.']
#
# Out:
#            DATE DGS3MO
# 18   2009-12-25      .
# 23   2010-01-01      .
# 34   2010-01-18      .
# 54   2010-02-15      .
# 129  2010-05-31      .
# ...         ...    ...
# 3709 2024-02-19      .
# 3738 2024-03-29      .
# 3779 2024-05-27      .
# 3796 2024-06-19      .
# 3807 2024-07-04      .
#
# [157 rows x 2 columns]

# %%
date_no_rate = rf_rate.loc[rf_rate['DGS3MO'] == '.', 'DATE']
date_no_rate.unique()
# Out:
# <DatetimeArray>
# ['2009-12-25 00:00:00', '2010-01-01 00:00:00', '2010-01-18 00:00:00',
#  '2010-02-15 00:00:00', '2010-05-31 00:00:00', '2010-07-05 00:00:00',
#  '2010-09-06 00:00:00', '2010-10-11 00:00:00', '2010-11-11 00:00:00',
#  '2010-11-25 00:00:00',
#  ...
#  '2023-10-09 00:00:00', '2023-11-23 00:00:00', '2023-12-25 00:00:00',
#  '2024-01-01 00:00:00', '2024-01-15 00:00:00', '2024-02-19 00:00:00',
#  '2024-03-29 00:00:00', '2024-05-27 00:00:00', '2024-06-19 00:00:00',
#  '2024-07-04 00:00:00']
# Length: 157, dtype: datetime64[ns]

# %% [markdown]
# Some of these days are holidays so can be filled with previous day rate

# %%
rf_rate['DGS3MO'] = np.where(rf_rate['DGS3MO']=='.', np.nan, rf_rate['DGS3MO'])

# %%
rf_rate['DGS3MO'][rf_rate['DGS3MO'].isna()]
# Out:
# 18      NaN
# 23      NaN
# 34      NaN
# 54      NaN
# 129     NaN
#        ...
# 3709    NaN
# 3738    NaN
# 3779    NaN
# 3796    NaN
# 3807    NaN
# Name: DGS3MO, Length: 157, dtype: object

# %%
rf_rate['DGS3MO'] = rf_rate['DGS3MO'].fillna(method = "ffill")
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/1211909483.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rf_rate['DGS3MO'] = rf_rate['DGS3MO'].fillna(method = "ffill")

# %%
# roughly check for other non-numeric values
rf_rate['DGS3MO'].unique()
# Out:
# array(['0.06', '0.05', '0.04', '0.03', '0.02', '0.08', '0.07', '0.11',
#        '0.10', '0.09', '0.12', '0.13', '0.14', '0.15', '0.16', '0.17',
#        '0.18', '0.01', '0.00', '0.19', '0.22', '0.21', '0.23', '0.29',
#        '0.27', '0.26', '0.24', '0.25', '0.20', '0.28', '0.31', '0.32',
#        '0.35', '0.33', '0.34', '0.30', '0.36', '0.37', '0.38', '0.41',
#        '0.43', '0.45', '0.48', '0.55', '0.51', '0.47', '0.44', '0.46',
#        '0.49', '0.52', '0.54', '0.53', '0.50', '0.63', '0.67', '0.71',
#        '0.74', '0.76', '0.73', '0.75', '0.79', '0.78', '0.77', '0.80',
#        '0.82', '0.81', '0.83', '0.85', '0.86', '0.90', '0.91', '0.89',
#        '0.88', '0.93', '0.92', '0.94', '0.98', '0.96', '0.97', '1.00',
#        '1.01', '1.02', '1.03', '0.99', '1.04', '1.06', '1.05', '1.07',
#        '1.11', '1.15', '1.16', '1.17', '1.18', '1.13', '1.08', '1.10',
#        '1.09', '1.12', '1.19', '1.22', '1.23', '1.24', '1.26', '1.25',
#        '1.27', '1.29', '1.30', '1.28', '1.33', '1.34', '1.32', '1.31',
#        '1.38', '1.37', '1.35', '1.47', '1.44', '1.39', '1.41', '1.45',
#        '1.42', '1.43', '1.46', '1.48', '1.51', '1.52', '1.55', '1.62',
#        '1.59', '1.58', '1.66', '1.64', '1.63', '1.65', '1.70', '1.68',
#        '1.67', '1.71', '1.73', '1.76', '1.77', '1.78', '1.80', '1.81',
#        '1.74', '1.72', '1.79', '1.75', '1.82', '1.87', '1.85', '1.84',
#        '1.86', '1.88', '1.90', '1.92', '1.93', '1.91', '1.94', '1.95',
#        '1.98', '1.96', '1.97', '1.99', '2.01', '2.02', '2.00', '2.04',
#        '2.03', '2.05', '2.06', '2.08', '2.07', '2.09', '2.12', '2.13',
#        '2.11', '2.14', '2.15', '2.16', '2.17', '2.18', '2.22', '2.21',
#        '2.20', '2.19', '2.23', '2.25', '2.27', '2.28', '2.31', '2.30',
#        '2.32', '2.34', '2.33', '2.36', '2.35', '2.37', '2.38', '2.39',
#        '2.41', '2.40', '2.42', '2.43', '2.45', '2.44', '2.46', '2.47',
#        '2.48', '2.49', '2.29', '2.24', '2.26', '2.10', '1.89', '1.83',
#        '1.69', '1.54', '1.53', '1.56', '1.57', '1.61', '1.60', '0.95',
#        '0.72', '0.62', '0.42', '0.40', '0.39', '0.59', '0.66', '0.65',
#        '0.68', '0.70', '1.21', '2.50', '2.52', '2.51', '2.62', '2.55',
#        '2.56', '2.58', '2.65', '2.67', '2.63', '2.72', '2.70', '2.68',
#        '2.71', '2.74', '2.82', '2.80', '2.88', '2.89', '2.97', '2.96',
#        '2.94', '3.04', '3.07', '3.06', '3.08', '3.17', '3.28', '3.24',
#        '3.22', '3.20', '3.37', '3.35', '3.31', '3.29', '3.39', '3.40',
#        '3.36', '3.33', '3.46', '3.45', '3.67', '3.70', '3.79', '3.81',
#        '3.97', '4.04', '4.07', '4.09', '4.16', '4.14', '4.11', '4.13',
#        '4.18', '4.22', '4.23', '4.25', '4.21', '4.29', '4.28', '4.34',
#        '4.31', '4.32', '4.41', '4.40', '4.38', '4.37', '4.33', '4.36',
#        '4.35', '4.46', '4.45', '4.42', '4.53', '4.55', '4.66', '4.67',
#        '4.70', '4.73', '4.72', '4.71', '4.69', '4.77', '4.79', '4.81',
#        '4.80', '4.84', '4.86', '4.89', '4.88', '4.90', '4.91', '4.93',
#        '5.04', '5.06', '5.05', '5.01', '4.87', '4.75', '4.74', '4.52',
#        '4.78', '4.97', '4.85', '4.95', '5.08', '5.02', '5.10', '5.14',
#        '5.21', '5.20', '5.16', '5.12', '5.18', '5.27', '5.24', '5.26',
#        '5.31', '5.29', '5.25', '5.23', '5.40', '5.34', '5.37', '5.38',
#        '5.55', '5.52', '5.50', '5.46', '5.44', '5.42', '5.36', '5.33',
#        '5.39', '5.41', '5.43', '5.48', '5.49', '5.47', '5.51', '5.54',
#        '5.53', '5.56', '5.57', '5.58', '5.61', '5.62', '5.63', '5.60',
#        '5.59', '5.45', '5.5', '5.4', '5.35'], dtype=object)

# %% [markdown]
# ## CHANGE BUCKET AGAIN HERE

# %%
df_201023_call_nn = df_201023_call[df_201023_call['c_iv'] != ' ']
df1M_ATM = df_201023_call_nn[(df_201023_call_nn['moneyness_bucket'] == "ATM")&(df_201023_call_nn['maturity_bucket'] == '6M')]

# %%
df1M_ATM.dtypes
# Out:
# date                 object
# underlying          float64
# expiry               object
# dte                 float64
# c_delta             float64
# c_gamma              object
# c_vega               object
# c_theta              object
# c_rho                object
# c_iv                 object
# c_volume             object
# c_last               object
# c_size               object
# c_bid                object
# c_ask                object
# strike              float64
# moneyness_bucket     object
# maturity_bucket      object
# dtype: object

# %%
df1M_ATM['date'] = pd.to_datetime(df1M_ATM['date'])
df1M_ATM['expiry'] = pd.to_datetime(df1M_ATM['expiry'])
df1M_ATM['c_vega'] = df1M_ATM['c_vega'].apply(pd.to_numeric, errors='coerce')
df1M_ATM['c_iv'] = df1M_ATM['c_iv'].apply(pd.to_numeric, errors='coerce')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3390608471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['date'] = pd.to_datetime(df1M_ATM['date'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3390608471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['expiry'] = pd.to_datetime(df1M_ATM['expiry'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3390608471.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['c_vega'] = df1M_ATM['c_vega'].apply(pd.to_numeric, errors='coerce')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3390608471.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['c_iv'] = df1M_ATM['c_iv'].apply(pd.to_numeric, errors='coerce')

# %%
df1M_ATM.dtypes
# Out:
# date                datetime64[ns]
# underlying                 float64
# expiry              datetime64[ns]
# dte                        float64
# c_delta                    float64
# c_gamma                     object
# c_vega                     float64
# c_theta                     object
# c_rho                       object
# c_iv                       float64
# c_volume                    object
# c_last                      object
# c_size                      object
# c_bid                       object
# c_ask                       object
# strike                     float64
# moneyness_bucket            object
# maturity_bucket             object
# dtype: object

# %%
df1M_ATM['date_rate'] = df1M_ATM['date']
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2246093883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['date_rate'] = df1M_ATM['date']

# %%
df1M_ATM[df1M_ATM['c_iv'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate]
# Index: []

# %%
len(rf_rate)
# Out:
# 3831

# %%
len(df1M_ATM)
# Out:
# 78375

# %%
#convert rf_rate to numeric
rf_rate['DGS3MO'] = rf_rate['DGS3MO'].apply(pd.to_numeric, errors='coerce')

# %%
# fill NA for those missing c_iv (due to holidays)
df1M_ATM['c_iv'] = np.where(df1M_ATM['c_iv'] == ' ', np.nan, df1M_ATM['c_iv'])
df1M_ATM['c_iv'] = df1M_ATM['c_iv'].fillna(method = 'ffill')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3529903446.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['c_iv'] = np.where(df1M_ATM['c_iv'] == ' ', np.nan, df1M_ATM['c_iv'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3529903446.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1M_ATM['c_iv'] = df1M_ATM['c_iv'].fillna(method = 'ffill')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3529903446.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1M_ATM['c_iv'] = df1M_ATM['c_iv'].fillna(method = 'ffill')

# %%
# left merge the risk free interest rates
df1M_ATM_rate = df1M_ATM.merge(rf_rate, left_on = 'date_rate', right_on = 'DATE', how = 'left')

# %%
len(df1M_ATM_rate)
# Out:
# 78375

# %%
df1M_ATM_rate = df1M_ATM_rate.rename(columns = {'DGS3MO':'rate'})

# %%
df1M_ATM_rate.isna().sum()
# Out:
# date                0
# underlying          0
# expiry              0
# dte                 0
# c_delta             0
# c_gamma             0
# c_vega              0
# c_theta             0
# c_rho               0
# c_iv                0
# c_volume            0
# c_last              0
# c_size              0
# c_bid               0
# c_ask               0
# strike              0
# moneyness_bucket    0
# maturity_bucket     0
# date_rate           0
# DATE                0
# rate                0
# dtype: int64

# %%
df1M_ATM_rate.head()
# Out:
#         date  underlying     expiry     dte  c_delta    c_gamma   c_vega  \
# 0 2010-01-04     1132.99 2010-06-17  163.96  0.52518   0.002550  3.00356
# 1 2010-01-04     1132.99 2010-06-17  163.96  0.51261   0.002560  3.00879
# 2 2010-01-04     1132.99 2010-06-17  163.96  0.45965   0.002530  2.99880
# 3 2010-01-04     1132.99 2010-06-30  176.96  0.46210   0.002470  3.11491
# 4 2010-01-05     1136.40 2010-06-17  162.96  0.53264   0.002520  2.99723
#
#       c_theta      c_rho     c_iv  ...      c_last      c_size       c_bid  \
# 0   -0.166130   2.154480  0.21272  ...   62.500000   201 x 103   61.810000
# 1   -0.165390   2.118630  0.21194  ...   56.600000   201 x 103   59.100000
# 2   -0.161630   1.955050  0.20564  ...   50.550000   201 x 304   49.300000
# 3   -0.156380   2.102860  0.20754  ...   41.800000   201 x 201   51.700000
# 4   -0.163770   2.166030  0.21070  ...   63.000000   103 x 103   62.700000
#
#         c_ask  strike  moneyness_bucket maturity_bucket  date_rate       DATE  \
# 0   65.300000  1125.0               ATM              6M 2010-01-04 2010-01-04
# 1   62.500000  1130.0               ATM              6M 2010-01-04 2010-01-04
# 2   51.510000  1150.0               ATM              6M 2010-01-04 2010-01-04
# 3   54.000000  1150.0               ATM              6M 2010-01-04 2010-01-04
# 4   65.900000  1125.0               ATM              6M 2010-01-05 2010-01-05
#
#    rate
# 0  0.08
# 1  0.08
# 2  0.08
# 3  0.08
# 4  0.07
#
# [5 rows x 21 columns]

# %%
# check for days with no rates
rf_rate[rf_rate['DATE'] == '2010-01-04']
# Out:
#          DATE  DGS3MO
# 24 2010-01-04    0.08

# %%
df1M_ATM_rate['rate'] = df1M_ATM_rate['rate'].fillna(method = 'ffill')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/4229273609.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1M_ATM_rate['rate'] = df1M_ATM_rate['rate'].fillna(method = 'ffill')

# %%
df1M_ATM_rate.isna().sum()
# Out:
# date                0
# underlying          0
# expiry              0
# dte                 0
# c_delta             0
# c_gamma             0
# c_vega              0
# c_theta             0
# c_rho               0
# c_iv                0
# c_volume            0
# c_last              0
# c_size              0
# c_bid               0
# c_ask               0
# strike              0
# moneyness_bucket    0
# maturity_bucket     0
# date_rate           0
# DATE                0
# rate                0
# dtype: int64

# %% [markdown]
# ## Pricing of the call

# %%
pricing = ['underlying','strike','dte','c_iv','rate']
df1M_ATM_rate[pricing].dtypes
# Out:
# underlying    float64
# strike        float64
# dte           float64
# c_iv          float64
# rate          float64
# dtype: object

# %%
df1M_ATM_rate[df1M_ATM_rate['c_iv'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate, DATE, rate]
# Index: []
#
# [0 rows x 21 columns]

# %%
df1M_ATM_rate_converted = df1M_ATM_rate

# %%
df1M_ATM_rate_converted[pricing].dtypes
# Out:
# underlying    float64
# strike        float64
# dte           float64
# c_iv          float64
# rate          float64
# dtype: object

# %%
# be aware of data types and convert all to numeric
df1M_ATM_rate_converted[pricing] = df1M_ATM_rate_converted[pricing].apply(pd.to_numeric, errors = 'coerce')

# %%
df1M_ATM_rate_converted[pricing].dtypes
# Out:
# underlying    float64
# strike        float64
# dte           float64
# c_iv          float64
# rate          float64
# dtype: object

# %%
df1M_ATM_rate_converted[df1M_ATM_rate_converted['c_iv'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate, DATE, rate]
# Index: []
#
# [0 rows x 21 columns]

# %%
list_null_c_iv = df1M_ATM_rate_converted[df1M_ATM_rate_converted['c_iv'].isna()].index.tolist()

# %% [markdown]
# after converting objects to numerics there are some c_iv becoming null

# %%
# get those null c_iv lines from the raw dataset (before conversion)
df1M_ATM_rate_converted.loc[list_null_c_iv]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate, DATE, rate]
# Index: []
#
# [0 rows x 21 columns]

# %%
from scipy.stats import norm

# %%
def option_pricing_call(df):
    S = df['underlying']
    K = df['strike']
    tau = df['dte']/256
    sigma = df['c_iv']
    r = df['rate']/100
    d1 = (np.log(S/K) + (r + (1/2) * sigma**2) * tau)/(sigma * np.sqrt(tau))
    d2 = d1 - sigma * np.sqrt(tau)
    value = S * norm.cdf(d1) - K * np.exp(-r * tau) * norm.cdf(d2)
    return value

# %%
df1M_ATM_rate_converted.dtypes
# Out:
# date                datetime64[ns]
# underlying                 float64
# expiry              datetime64[ns]
# dte                        float64
# c_delta                    float64
# c_gamma                     object
# c_vega                     float64
# c_theta                     object
# c_rho                       object
# c_iv                       float64
# c_volume                    object
# c_last                      object
# c_size                      object
# c_bid                       object
# c_ask                       object
# strike                     float64
# moneyness_bucket            object
# maturity_bucket             object
# date_rate           datetime64[ns]
# DATE                datetime64[ns]
# rate                       float64
# dtype: object

# %%
df1M_ATM_rate_converted['c_price'] = df1M_ATM_rate_converted.apply(lambda row: option_pricing_call(row), axis=1)

# %%
df1M_ATM_rate_converted[df1M_ATM_rate_converted['c_price'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate, DATE, rate, c_price]
# Index: []
#
# [0 rows x 22 columns]

# %%
df1M_ATM_rate_converted[df1M_ATM_rate_converted['c_iv'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, underlying, expiry, dte, c_delta, c_gamma, c_vega, c_theta, c_rho, c_iv, c_volume, c_last, c_size, c_bid, c_ask, strike, moneyness_bucket, maturity_bucket, date_rate, DATE, rate, c_price]
# Index: []
#
# [0 rows x 22 columns]

# %%
# NA price only when dte = 0, therefore price should be 0 as well

# %%
df1M_ATM_rate_converted['c_price'] = df1M_ATM_rate_converted['c_price'].fillna(0)

# %%
# convert c_vega to numerics
df1M_ATM_rate_converted['c_vega'] = df1M_ATM_rate_converted['c_vega'].apply(pd.to_numeric, errors = 'coerce')

# %%
df1M_ATM_rate_converted[['underlying','c_price','c_bid','c_ask','c_last']]
# Out:
#        underlying     c_price       c_bid       c_ask      c_last
# 0         1132.99   80.922980   61.810000   65.300000   62.500000
# 1         1132.99   78.250371   59.100000   62.500000   56.600000
# 2         1132.99   66.915630   49.300000   51.510000   50.550000
# 3         1132.99   70.542546   51.700000   54.000000   41.800000
# 4         1136.40   81.822963   62.700000   65.900000   63.000000
# ...           ...         ...         ...         ...         ...
# 78370     4772.17  209.380376       137.2       138.4       136.7
# 78371     4772.17  270.304452       188.5       190.5      202.33
# 78372     4772.17  253.646214       173.8       175.6      152.01
# 78373     4772.17  237.043574       159.7       161.4      159.66
# 78374     4772.17  221.227091       146.4       147.9      158.77
#
# [78375 rows x 5 columns]

# %% [markdown]
# Differences between our theoretical price and actual bid, ask and last price might be that we didnt include the divident factor $q$, which is unknown.

# %%
df1M_ATM_rate_converted['c_delta'] = df1M_ATM_rate_converted['c_delta'].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# # 3. Fitting Process

# %% [markdown]
# ## 3.1 Qudratic Regression

# %%
# for each bucket, generate the dependent variable which is independent on implied vol
def reg_variables(df):
    df['1D_call_change'] = df['c_price'].pct_change().fillna(0) #from Richard's tutorial the change in option price is a percentage
    df['1D_stock_change'] = df['underlying'].diff().fillna(0)
    df['LHS'] = df['1D_call_change'] - df['c_delta'] * df['1D_stock_change']
    df['vega_term'] = (df['c_vega']/np.sqrt(df['dte']))*(df['1D_stock_change']/df['underlying'])
    df['RHS1'] = df['c_delta']
    df['RHS2'] = df['c_delta'] ** 2
    return df

# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/homebrew/lib/python3.11/site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in /opt/homebrew/lib/python3.11/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/homebrew/lib/python3.11/site-packages (from statsmodels) (1.14.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/homebrew/lib/python3.11/site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /opt/homebrew/lib/python3.11/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /Users/zhifei_li/Library/Python/3.11/lib/python/site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/zhifei_li/Library/Python/3.11/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in /Users/zhifei_li/Library/Python/3.11/lib/python/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

# %% [markdown]
# Test on the method: proves to be right

# %%
df1M_ATM_regression = df1M_ATM_rate_converted[['date','underlying','expiry','dte','c_delta','c_vega','c_iv','strike','c_price']]

# %%
df1M_ATM_regression
# Out:
#             date  underlying     expiry     dte  c_delta    c_vega     c_iv  \
# 0     2010-01-04     1132.99 2010-06-17  163.96  0.52518   3.00356  0.21272
# 1     2010-01-04     1132.99 2010-06-17  163.96  0.51261   3.00879  0.21194
# 2     2010-01-04     1132.99 2010-06-17  163.96  0.45965   2.99880  0.20564
# 3     2010-01-04     1132.99 2010-06-30  176.96  0.46210   3.11491  0.20754
# 4     2010-01-05     1136.40 2010-06-17  162.96  0.53264   2.99723  0.21070
# ...          ...         ...        ...     ...      ...       ...      ...
# 78370 2023-12-29     4772.17 2024-06-21  174.96  0.45615  13.04576  0.12665
# 78371 2023-12-29     4772.17 2024-06-28  181.96  0.53295  13.31232  0.13478
# 78372 2023-12-29     4772.17 2024-06-28  181.96  0.51035  13.35938  0.13254
# 78373 2023-12-29     4772.17 2024-06-28  181.96  0.48871  13.36570  0.13010
# 78374 2023-12-29     4772.17 2024-06-28  181.96  0.46538  13.32839  0.12791
#
#        strike     c_price
# 0      1125.0   80.922980
# 1      1130.0   78.250371
# 2      1150.0   66.915630
# 3      1150.0   70.542546
# 4      1125.0   81.822963
# ...       ...         ...
# 78370  4930.0  209.380376
# 78371  4850.0  270.304452
# 78372  4875.0  253.646214
# 78373  4900.0  237.043574
# 78374  4925.0  221.227091
#
# [78375 rows x 9 columns]

# %% [markdown]
# Lots of dates have more than one observation, so applying .pct.diff() would be wrong

# %%
df1M_ATM_regression_prev = df1M_ATM_regression.copy()

# %%
df1M_ATM_regression_prev
# Out:
#             date  underlying     expiry     dte  c_delta    c_vega     c_iv  \
# 0     2010-01-04     1132.99 2010-06-17  163.96  0.52518   3.00356  0.21272
# 1     2010-01-04     1132.99 2010-06-17  163.96  0.51261   3.00879  0.21194
# 2     2010-01-04     1132.99 2010-06-17  163.96  0.45965   2.99880  0.20564
# 3     2010-01-04     1132.99 2010-06-30  176.96  0.46210   3.11491  0.20754
# 4     2010-01-05     1136.40 2010-06-17  162.96  0.53264   2.99723  0.21070
# ...          ...         ...        ...     ...      ...       ...      ...
# 78370 2023-12-29     4772.17 2024-06-21  174.96  0.45615  13.04576  0.12665
# 78371 2023-12-29     4772.17 2024-06-28  181.96  0.53295  13.31232  0.13478
# 78372 2023-12-29     4772.17 2024-06-28  181.96  0.51035  13.35938  0.13254
# 78373 2023-12-29     4772.17 2024-06-28  181.96  0.48871  13.36570  0.13010
# 78374 2023-12-29     4772.17 2024-06-28  181.96  0.46538  13.32839  0.12791
#
#        strike     c_price
# 0      1125.0   80.922980
# 1      1130.0   78.250371
# 2      1150.0   66.915630
# 3      1150.0   70.542546
# 4      1125.0   81.822963
# ...       ...         ...
# 78370  4930.0  209.380376
# 78371  4850.0  270.304452
# 78372  4875.0  253.646214
# 78373  4900.0  237.043574
# 78374  4925.0  221.227091
#
# [78375 rows x 9 columns]

# %%
df1M_ATM_regression_prev['date_prev'] = df1M_ATM_regression_prev['date'] - pd.Timedelta(days = 1)
df1M_ATM_regression_prev = df1M_ATM_regression_prev.rename(columns = {'underlying':'underlying_prev','c_price':'c_price_prev','strike':'strike_prev','expiry':'expiry_prev'})
df1M_ATM_regression_prev.head()
# Out:
#         date  underlying_prev expiry_prev     dte  c_delta   c_vega     c_iv  \
# 0 2010-01-04          1132.99  2010-06-17  163.96  0.52518  3.00356  0.21272
# 1 2010-01-04          1132.99  2010-06-17  163.96  0.51261  3.00879  0.21194
# 2 2010-01-04          1132.99  2010-06-17  163.96  0.45965  2.99880  0.20564
# 3 2010-01-04          1132.99  2010-06-30  176.96  0.46210  3.11491  0.20754
# 4 2010-01-05          1136.40  2010-06-17  162.96  0.53264  2.99723  0.21070
#
#    strike_prev  c_price_prev  date_prev
# 0       1125.0     80.922980 2010-01-03
# 1       1130.0     78.250371 2010-01-03
# 2       1150.0     66.915630 2010-01-03
# 3       1150.0     70.542546 2010-01-03
# 4       1125.0     81.822963 2010-01-04

# %%
df1M_ATM_regression
# Out:
#             date  underlying     expiry     dte  c_delta    c_vega     c_iv  \
# 0     2010-01-04     1132.99 2010-06-17  163.96  0.52518   3.00356  0.21272
# 1     2010-01-04     1132.99 2010-06-17  163.96  0.51261   3.00879  0.21194
# 2     2010-01-04     1132.99 2010-06-17  163.96  0.45965   2.99880  0.20564
# 3     2010-01-04     1132.99 2010-06-30  176.96  0.46210   3.11491  0.20754
# 4     2010-01-05     1136.40 2010-06-17  162.96  0.53264   2.99723  0.21070
# ...          ...         ...        ...     ...      ...       ...      ...
# 78370 2023-12-29     4772.17 2024-06-21  174.96  0.45615  13.04576  0.12665
# 78371 2023-12-29     4772.17 2024-06-28  181.96  0.53295  13.31232  0.13478
# 78372 2023-12-29     4772.17 2024-06-28  181.96  0.51035  13.35938  0.13254
# 78373 2023-12-29     4772.17 2024-06-28  181.96  0.48871  13.36570  0.13010
# 78374 2023-12-29     4772.17 2024-06-28  181.96  0.46538  13.32839  0.12791
#
#        strike     c_price
# 0      1125.0   80.922980
# 1      1130.0   78.250371
# 2      1150.0   66.915630
# 3      1150.0   70.542546
# 4      1125.0   81.822963
# ...       ...         ...
# 78370  4930.0  209.380376
# 78371  4850.0  270.304452
# 78372  4875.0  253.646214
# 78373  4900.0  237.043574
# 78374  4925.0  221.227091
#
# [78375 rows x 9 columns]

# %%
df1M_ATM_regression_diff = df1M_ATM_regression_prev.merge(df1M_ATM_regression[['date','expiry','strike','underlying','c_price']], left_on = ['date_prev','expiry_prev','strike_prev'], right_on = ['date','expiry','strike'], how = 'left')

# %%
df1M_ATM_regression_diff
# Out:
#           date_x  underlying_prev expiry_prev     dte  c_delta    c_vega  \
# 0     2010-01-04          1132.99  2010-06-17  163.96  0.52518   3.00356
# 1     2010-01-04          1132.99  2010-06-17  163.96  0.51261   3.00879
# 2     2010-01-04          1132.99  2010-06-17  163.96  0.45965   2.99880
# 3     2010-01-04          1132.99  2010-06-30  176.96  0.46210   3.11491
# 4     2010-01-05          1136.40  2010-06-17  162.96  0.53264   2.99723
# ...          ...              ...         ...     ...      ...       ...
# 78370 2023-12-29          4772.17  2024-06-21  174.96  0.45615  13.04576
# 78371 2023-12-29          4772.17  2024-06-28  181.96  0.53295  13.31232
# 78372 2023-12-29          4772.17  2024-06-28  181.96  0.51035  13.35938
# 78373 2023-12-29          4772.17  2024-06-28  181.96  0.48871  13.36570
# 78374 2023-12-29          4772.17  2024-06-28  181.96  0.46538  13.32839
#
#           c_iv  strike_prev  c_price_prev  date_prev     date_y     expiry  \
# 0      0.21272       1125.0     80.922980 2010-01-03        NaT        NaT
# 1      0.21194       1130.0     78.250371 2010-01-03        NaT        NaT
# 2      0.20564       1150.0     66.915630 2010-01-03        NaT        NaT
# 3      0.20754       1150.0     70.542546 2010-01-03        NaT        NaT
# 4      0.21070       1125.0     81.822963 2010-01-04 2010-01-04 2010-06-17
# ...        ...          ...           ...        ...        ...        ...
# 78370  0.12665       4930.0    209.380376 2023-12-28 2023-12-28 2024-06-21
# 78371  0.13478       4850.0    270.304452 2023-12-28        NaT        NaT
# 78372  0.13254       4875.0    253.646214 2023-12-28        NaT        NaT
# 78373  0.13010       4900.0    237.043574 2023-12-28        NaT        NaT
# 78374  0.12791       4925.0    221.227091 2023-12-28        NaT        NaT
#
#        strike  underlying     c_price
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4      1125.0     1132.99   80.922980
# ...       ...         ...         ...
# 78370  4930.0     4783.83  216.846741
# 78371     NaN         NaN         NaN
# 78372     NaN         NaN         NaN
# 78373     NaN         NaN         NaN
# 78374     NaN         NaN         NaN
#
# [78375 rows x 15 columns]

# %%
# drop the null in date_y since they are not provided
df1M_ATM_regression_diff = df1M_ATM_regression_diff[~(df1M_ATM_regression_diff ['date_y'].isna())]

# %%
df1M_ATM_regression_diff.isna().sum()
# Out:
# date_x             0
# underlying_prev    0
# expiry_prev        0
# dte                0
# c_delta            0
# c_vega             0
# c_iv               0
# strike_prev        0
# c_price_prev       0
# date_prev          0
# date_y             0
# expiry             0
# strike             0
# underlying         0
# c_price            0
# dtype: int64

# %%
df1M_ATM_regression_diff
# Out:
#           date_x  underlying_prev expiry_prev     dte  c_delta    c_vega  \
# 4     2010-01-05          1136.40  2010-06-17  162.96  0.53264   2.99723
# 5     2010-01-05          1136.40  2010-06-17  162.96  0.51981   3.00441
# 6     2010-01-05          1136.40  2010-06-17  162.96  0.46705   3.00172
# 7     2010-01-05          1136.40  2010-06-30  175.96  0.46909   3.11834
# 8     2010-01-06          1136.99  2010-06-17  161.96  0.53469   2.98850
# ...          ...              ...         ...     ...      ...       ...
# 78366 2023-12-29          4772.17  2024-06-21  174.96  0.48445  13.10829
# 78367 2023-12-29          4772.17  2024-06-21  174.96  0.47431  13.09454
# 78368 2023-12-29          4772.17  2024-06-21  174.96  0.46574  13.07397
# 78369 2023-12-29          4772.17  2024-06-21  174.96  0.46011  13.06120
# 78370 2023-12-29          4772.17  2024-06-21  174.96  0.45615  13.04576
#
#           c_iv  strike_prev  c_price_prev  date_prev     date_y     expiry  \
# 4      0.21070       1125.0     81.822963 2010-01-04 2010-01-04 2010-06-17
# 5      0.20902       1130.0     78.789793 2010-01-04 2010-01-04 2010-06-17
# 6      0.20307       1150.0     67.434904 2010-01-04 2010-01-04 2010-06-17
# 7      0.20477       1150.0     70.965083 2010-01-04 2010-01-04 2010-06-30
# 8      0.20609       1125.0     80.239608 2010-01-05 2010-01-05 2010-06-17
# ...        ...          ...           ...        ...        ...        ...
# 78366  0.12893       4900.0    227.597337 2023-12-28 2023-12-28 2024-06-21
# 78367  0.12821       4910.0    221.519183 2023-12-28 2023-12-28 2024-06-21
# 78368  0.12739       4920.0    215.352803 2023-12-28 2023-12-28 2024-06-21
# 78369  0.12657       4925.0    211.653428 2023-12-28 2023-12-28 2024-06-21
# 78370  0.12665       4930.0    209.380376 2023-12-28 2023-12-28 2024-06-21
#
#        strike  underlying     c_price
# 4      1125.0     1132.99   80.922980
# 5      1130.0     1132.99   78.250371
# 6      1150.0     1132.99   66.915630
# 7      1150.0     1132.99   70.542546
# 8      1125.0     1136.40   81.822963
# ...       ...         ...         ...
# 78366  4900.0     4783.83  235.030683
# 78367  4910.0     4783.83  229.672226
# 78368  4920.0     4783.83  222.913124
# 78369  4925.0     4783.83  219.377309
# 78370  4930.0     4783.83  216.846741
#
# [43853 rows x 15 columns]

# %%
df1M_ATM_regression_diff_final = df1M_ATM_regression_diff[['date_x','date_prev','expiry','strike','dte','c_delta','c_vega','c_iv','c_price','c_price_prev','underlying','underlying_prev']]

# %%
df1M_ATM_regression_diff_final
# Out:
#           date_x  date_prev     expiry  strike     dte  c_delta    c_vega  \
# 4     2010-01-05 2010-01-04 2010-06-17  1125.0  162.96  0.53264   2.99723
# 5     2010-01-05 2010-01-04 2010-06-17  1130.0  162.96  0.51981   3.00441
# 6     2010-01-05 2010-01-04 2010-06-17  1150.0  162.96  0.46705   3.00172
# 7     2010-01-05 2010-01-04 2010-06-30  1150.0  175.96  0.46909   3.11834
# 8     2010-01-06 2010-01-05 2010-06-17  1125.0  161.96  0.53469   2.98850
# ...          ...        ...        ...     ...     ...      ...       ...
# 78366 2023-12-29 2023-12-28 2024-06-21  4900.0  174.96  0.48445  13.10829
# 78367 2023-12-29 2023-12-28 2024-06-21  4910.0  174.96  0.47431  13.09454
# 78368 2023-12-29 2023-12-28 2024-06-21  4920.0  174.96  0.46574  13.07397
# 78369 2023-12-29 2023-12-28 2024-06-21  4925.0  174.96  0.46011  13.06120
# 78370 2023-12-29 2023-12-28 2024-06-21  4930.0  174.96  0.45615  13.04576
#
#           c_iv     c_price  c_price_prev  underlying  underlying_prev
# 4      0.21070   80.922980     81.822963     1132.99          1136.40
# 5      0.20902   78.250371     78.789793     1132.99          1136.40
# 6      0.20307   66.915630     67.434904     1132.99          1136.40
# 7      0.20477   70.542546     70.965083     1132.99          1136.40
# 8      0.20609   81.822963     80.239608     1136.40          1136.99
# ...        ...         ...           ...         ...              ...
# 78366  0.12893  235.030683    227.597337     4783.83          4772.17
# 78367  0.12821  229.672226    221.519183     4783.83          4772.17
# 78368  0.12739  222.913124    215.352803     4783.83          4772.17
# 78369  0.12657  219.377309    211.653428     4783.83          4772.17
# 78370  0.12665  216.846741    209.380376     4783.83          4772.17
#
# [43853 rows x 12 columns]

# %%
df1M_ATM_regression_diff_final = df1M_ATM_regression_diff_final.rename({'date_x':'date'})

# %% [markdown]
# ### May also try to have V_diff in pct

# %%
df1M_ATM_regression_diff_final['S_diff'] = df1M_ATM_regression_diff_final['underlying'] - df1M_ATM_regression_diff_final['underlying_prev']
df1M_ATM_regression_diff_final['V_diff'] = abs(df1M_ATM_regression_diff_final['c_price'] - df1M_ATM_regression_diff_final['c_price_prev'])
df1M_ATM_regression_diff_final['c_vega'] = df1M_ATM_regression_diff_final['c_vega'] * 100

# %%
df1M_ATM_regression_diff_final
# Out:
#           date_x  date_prev     expiry  strike     dte  c_delta    c_vega  \
# 4     2010-01-05 2010-01-04 2010-06-17  1125.0  162.96  0.53264   299.723
# 5     2010-01-05 2010-01-04 2010-06-17  1130.0  162.96  0.51981   300.441
# 6     2010-01-05 2010-01-04 2010-06-17  1150.0  162.96  0.46705   300.172
# 7     2010-01-05 2010-01-04 2010-06-30  1150.0  175.96  0.46909   311.834
# 8     2010-01-06 2010-01-05 2010-06-17  1125.0  161.96  0.53469   298.850
# ...          ...        ...        ...     ...     ...      ...       ...
# 78366 2023-12-29 2023-12-28 2024-06-21  4900.0  174.96  0.48445  1310.829
# 78367 2023-12-29 2023-12-28 2024-06-21  4910.0  174.96  0.47431  1309.454
# 78368 2023-12-29 2023-12-28 2024-06-21  4920.0  174.96  0.46574  1307.397
# 78369 2023-12-29 2023-12-28 2024-06-21  4925.0  174.96  0.46011  1306.120
# 78370 2023-12-29 2023-12-28 2024-06-21  4930.0  174.96  0.45615  1304.576
#
#           c_iv     c_price  c_price_prev  underlying  underlying_prev  S_diff  \
# 4      0.21070   80.922980     81.822963     1132.99          1136.40   -3.41
# 5      0.20902   78.250371     78.789793     1132.99          1136.40   -3.41
# 6      0.20307   66.915630     67.434904     1132.99          1136.40   -3.41
# 7      0.20477   70.542546     70.965083     1132.99          1136.40   -3.41
# 8      0.20609   81.822963     80.239608     1136.40          1136.99   -0.59
# ...        ...         ...           ...         ...              ...     ...
# 78366  0.12893  235.030683    227.597337     4783.83          4772.17   11.66
# 78367  0.12821  229.672226    221.519183     4783.83          4772.17   11.66
# 78368  0.12739  222.913124    215.352803     4783.83          4772.17   11.66
# 78369  0.12657  219.377309    211.653428     4783.83          4772.17   11.66
# 78370  0.12665  216.846741    209.380376     4783.83          4772.17   11.66
#
#          V_diff
# 4      0.899983
# 5      0.539423
# 6      0.519274
# 7      0.422537
# 8      1.583356
# ...         ...
# 78366  7.433346
# 78367  8.153043
# 78368  7.560321
# 78369  7.723881
# 78370  7.466365
#
# [43853 rows x 14 columns]

# %%
# for each bucket, generate the dependent variable which is independent on implied vol
def reg_variables(df):
    df['1D_call_change'] = df['V_diff'] #from Richard's tutorial the change in option price is a percentage
    df['1D_stock_change'] = df['S_diff']
    df['LHS'] = (df['1D_call_change'] - df['c_delta'] * df['1D_stock_change'])/((df['c_vega']/np.sqrt(df['dte']))*(df['1D_stock_change']/df['underlying']))
    df['RHS1'] = df['c_delta']
    df['RHS2'] = df['c_delta'] ** 2
    return df

# %%
# combine the independent variables RHS1 and RHS2
df1M_ATM_regression = reg_variables(df1M_ATM_regression_diff_final)

# %%
df1M_ATM_regression
# Out:
#           date_x  date_prev     expiry  strike     dte  c_delta    c_vega  \
# 4     2010-01-05 2010-01-04 2010-06-17  1125.0  162.96  0.53264   299.723
# 5     2010-01-05 2010-01-04 2010-06-17  1130.0  162.96  0.51981   300.441
# 6     2010-01-05 2010-01-04 2010-06-17  1150.0  162.96  0.46705   300.172
# 7     2010-01-05 2010-01-04 2010-06-30  1150.0  175.96  0.46909   311.834
# 8     2010-01-06 2010-01-05 2010-06-17  1125.0  161.96  0.53469   298.850
# ...          ...        ...        ...     ...     ...      ...       ...
# 78366 2023-12-29 2023-12-28 2024-06-21  4900.0  174.96  0.48445  1310.829
# 78367 2023-12-29 2023-12-28 2024-06-21  4910.0  174.96  0.47431  1309.454
# 78368 2023-12-29 2023-12-28 2024-06-21  4920.0  174.96  0.46574  1307.397
# 78369 2023-12-29 2023-12-28 2024-06-21  4925.0  174.96  0.46011  1306.120
# 78370 2023-12-29 2023-12-28 2024-06-21  4930.0  174.96  0.45615  1304.576
#
#           c_iv     c_price  c_price_prev  underlying  underlying_prev  S_diff  \
# 4      0.21070   80.922980     81.822963     1132.99          1136.40   -3.41
# 5      0.20902   78.250371     78.789793     1132.99          1136.40   -3.41
# 6      0.20307   66.915630     67.434904     1132.99          1136.40   -3.41
# 7      0.20477   70.542546     70.965083     1132.99          1136.40   -3.41
# 8      0.20609   81.822963     80.239608     1136.40          1136.99   -0.59
# ...        ...         ...           ...         ...              ...     ...
# 78366  0.12893  235.030683    227.597337     4783.83          4772.17   11.66
# 78367  0.12821  229.672226    221.519183     4783.83          4772.17   11.66
# 78368  0.12739  222.913124    215.352803     4783.83          4772.17   11.66
# 78369  0.12657  219.377309    211.653428     4783.83          4772.17   11.66
# 78370  0.12665  216.846741    209.380376     4783.83          4772.17   11.66
#
#          V_diff  1D_call_change  1D_stock_change         LHS     RHS1  \
# 4      0.899983        0.899983            -3.41  -38.438601  0.53264
# 5      0.539423        0.539423            -3.41  -32.638945  0.51981
# 6      0.519274        0.519274            -3.41  -29.841347  0.46705
# 7      0.422537        0.422537            -3.41  -28.580191  0.46909
# 8      1.583356        1.583356            -0.59 -155.745065  0.53469
# ...         ...             ...              ...         ...      ...
# 78366  7.433346        7.433346            11.66    7.388493  0.48445
# 78367  8.153043        8.153043            11.66   10.868921  0.47431
# 78368  7.560321        7.560321            11.66    8.840490  0.46574
# 78369  7.723881        7.723881            11.66    9.801467  0.46011
# 78370  7.466365        7.466365            11.66    8.933916  0.45615
#
#            RHS2
# 4      0.283705
# 5      0.270202
# 6      0.218136
# 7      0.220045
# 8      0.285893
# ...         ...
# 78366  0.234692
# 78367  0.224970
# 78368  0.216914
# 78369  0.211701
# 78370  0.208073
#
# [43853 rows x 19 columns]

# %%
df1M_ATM_regression.isna().sum()
# Out:
# date_x             0
# date_prev          0
# expiry             0
# strike             0
# dte                0
# c_delta            0
# c_vega             0
# c_iv               0
# c_price            0
# c_price_prev       0
# underlying         0
# underlying_prev    0
# S_diff             0
# V_diff             0
# 1D_call_change     0
# 1D_stock_change    0
# LHS                0
# RHS1               0
# RHS2               0
# dtype: int64

# %%
df1M_ATM_regression = df1M_ATM_regression[~(df1M_ATM_regression['LHS'].isna())]

# %%
df1M_ATM_regression.to_csv('df1M_ATM_regression.csv')

# %%
X = df1M_ATM_regression[['RHS1','RHS2']]
X = sm.add_constant(X)
y = df1M_ATM_regression['LHS']

# %%
df1M_ATM_regression.iloc[1061]
# Out:
# date_x             2012-10-30 00:00:00
# date_prev          2012-10-29 00:00:00
# expiry             2013-03-14 00:00:00
# strike                          1425.0
# dte                              135.0
# c_delta                        0.47446
# c_vega                         340.069
# c_iv                           0.22304
# c_price                      85.519275
# c_price_prev                 85.642394
# underlying                     1411.94
# underlying_prev                1411.94
# S_diff                             0.0
# V_diff                        0.123119
# 1D_call_change                0.123119
# 1D_stock_change                    0.0
# LHS                                inf
# RHS1                           0.47446
# RHS2                          0.225112
# Name: 1885, dtype: object

# %%
np.isinf(df1M_ATM_regression).sum()
# Out:
# date_x             0
# date_prev          0
# expiry             0
# strike             0
# dte                0
# c_delta            0
# c_vega             0
# c_iv               0
# c_price            0
# c_price_prev       0
# underlying         0
# underlying_prev    0
# S_diff             0
# V_diff             0
# 1D_call_change     0
# 1D_stock_change    0
# LHS                5
# RHS1               0
# RHS2               0
# dtype: int64

# %%
df1M_ATM_regression_noinf = df1M_ATM_regression.replace([np.inf, -np.inf, np.nan]).dropna(axis = 1)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/2712130517.py:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df1M_ATM_regression_noinf = df1M_ATM_regression.replace([np.inf, -np.inf, np.nan]).dropna(axis = 1)

# %%
np.isinf(df1M_ATM_regression_noinf).sum()
# Out:
# date_x             0
# date_prev          0
# expiry             0
# strike             0
# dte                0
# c_delta            0
# c_vega             0
# c_iv               0
# c_price            0
# c_price_prev       0
# underlying         0
# underlying_prev    0
# S_diff             0
# V_diff             0
# 1D_call_change     0
# 1D_stock_change    0
# LHS                0
# RHS1               0
# RHS2               0
# dtype: int64

# %%
X = df1M_ATM_regression_noinf[['RHS1','RHS2']]
X = sm.add_constant(X)
y = df1M_ATM_regression_noinf['LHS']

# %%
model = sm.OLS(y, X).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    LHS   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     80.77
# Date:                Thu, 15 Aug 2024   Prob (F-statistic):           9.70e-36
# Time:                        20:26:46   Log-Likelihood:            -2.9001e+05
# No. Observations:               43853   AIC:                         5.800e+05
# Df Residuals:                   43850   BIC:                         5.801e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        357.3970    307.281      1.163      0.245    -244.880     959.674
# RHS1       -1079.1668   1229.120     -0.878      0.380   -3488.265    1329.931
# RHS2         672.4402   1226.399      0.548      0.583   -1731.323    3076.204
# ==============================================================================
# Omnibus:                    68012.725   Durbin-Watson:                   0.397
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1069892298.678
# Skew:                           8.598   Prob(JB):                         0.00
# Kurtosis:                     768.009   Cond. No.                     2.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X = df1M_ATM_regression_noinf[['RHS1','RHS2']].values
X = sm.add_constant(X)

y = df1M_ATM_regression_noinf['LHS']

# %%
coef = np.polyfit(df1M_ATM_regression['RHS1'],y,2)

# %%
coef
# Out:
# array([  672.44022031, -1079.16678193,   357.39697713])

# %%
X1 = df1M_ATM_regression_noinf['RHS1']
X2 = df1M_ATM_regression_noinf['RHS2']

y = df1M_ATM_regression_noinf['LHS']

# %%
from scipy.optimize import minimize

# %%
def objective(params):
    a, b, c = params
    y_pred = a + b * X1 + c * X2
    return np.sum((y - y_pred) ** 2)

initial_guess = [1,1,1]

result = minimize(objective, initial_guess, method = 'SLSQP')

a, b, c = result.x

# %%
print(f"a:{a}, b:{b}, c:{c}")
# Out:
# a:302.9801716423594, b:-861.3421266398971, c:455.0904211359307

# %%
def mv_delta(df, a, b, c):
    df['c_mv_delta'] = df['c_delta']  +  (df['c_vega']/(df['underlying'] * np.sqrt(df['dte']))) * (a + b * df['c_delta'] + c * df['c_delta'] ** 2)
    return df

# %%
a = 357.3970
b = -1079.1668 
c = 672.4402
df = df1M_ATM_regression_noinf

# %%
df1M_ATM_regression_noinf_new = mv_delta(df, a, b, c)

# %%
df1M_ATM_regression_noinf_new['diff_delta'] = df1M_ATM_regression_noinf_new['c_mv_delta'] - df1M_ATM_regression_noinf_new['c_delta']

print(len(df1M_ATM_regression_noinf_new[df1M_ATM_regression_noinf_new['diff_delta']>=0]))

print(len(df1M_ATM_regression_noinf_new[df1M_ATM_regression_noinf_new['diff_delta']<0]))
# Out:
# 5603
# 38250

# %%
df1M_ATM_regression_noinf.head()
# Out:
#       date_x  date_prev     expiry  strike     dte  c_delta   c_vega     c_iv  \
# 4 2010-01-05 2010-01-04 2010-06-17  1125.0  162.96  0.53264  299.723  0.21070
# 5 2010-01-05 2010-01-04 2010-06-17  1130.0  162.96  0.51981  300.441  0.20902
# 6 2010-01-05 2010-01-04 2010-06-17  1150.0  162.96  0.46705  300.172  0.20307
# 7 2010-01-05 2010-01-04 2010-06-30  1150.0  175.96  0.46909  311.834  0.20477
# 8 2010-01-06 2010-01-05 2010-06-17  1125.0  161.96  0.53469  298.850  0.20609
#
#      c_price  c_price_prev  ...  1D_call_change  1D_stock_change         LHS  \
# 4  80.922980     81.822963  ...        0.899983            -3.41  -38.438601
# 5  78.250371     78.789793  ...        0.539423            -3.41  -32.638945
# 6  66.915630     67.434904  ...        0.519274            -3.41  -29.841347
# 7  70.542546     70.965083  ...        0.422537            -3.41  -28.580191
# 8  81.822963     80.239608  ...        1.583356            -0.59 -155.745065
#
#       RHS1      RHS2  c_mv_delta  diff_delta  E_chg_iv  mv_error  bs_error
# 4  0.53264  0.283705   -0.019329   -0.551969  0.006280  0.834072  2.716286
# 5  0.51981  0.270202    0.065517   -0.454293  0.005156  0.762837  2.311975
# 6  0.46705  0.218136    0.468199    0.001149 -0.000013  2.115833  2.111915
# 7  0.46909  0.220045    0.451205   -0.017885  0.000196  1.961147  2.022134
# 8  0.53469  0.285893   -0.031023   -0.565713  0.001117  1.565052  1.898823
#
# [5 rows x 24 columns]

# %% [markdown]
# # 4. Calibration by Rolling Windows - the term structure of $a(T,t)$, $b(T,t)$, $c(T,t)$

# %%
df1M_ATM_regression_diff_final_rolling = mv_delta(df, a, b, c)

# %%
def rolling_regression(df, window_size):
    unique_dates = df['date'].unique()
    results = []

    for start_date in unique_dates: # ensure to shift by one day every time
        end_date = start_date + pd.Timedelta(days = window_size - 1)

        window_data = df[(df['date'] >= start_date) & (df['date']<= end_date)]

        if len(window_data) > 1:
            y = window_data['LHS']
            X = window_data[['RHS1','RHS2']]
            X = sm.add_constant(X)

            model = sm.OLS(y, X).fit()
            results.append({
                'start_date': start_date,
                'end_date': end_date,
                'a': model.params['const'],
                'b': model.params['RHS1'],
                'c': model.params['RHS2'],
                'rsquared': model.rsquared,
                'aic': model.aic,
                'bic': model.bic,
                'pvalues': model.pvalues,
                'tvalues': model.tvalues
            })
    return pd.DataFrame(results)

# %%
df1M_ATM_regression_diff_final_rolling = df1M_ATM_regression_diff_final_rolling.rename(columns = {'date_x':'date'})

# %%
rolling_result = rolling_regression(df1M_ATM_regression_diff_final_rolling, 66) #take three months (3*22 days) as the rolling window

# %%
rolling_result
# Out:
#      start_date   end_date            a            b            c  rsquared  \
# 0    2010-01-05 2010-03-11 -2191.502776  8846.541221 -9042.019655  0.026138
# 1    2010-01-06 2010-03-12 -2208.940950  8920.615630 -9121.535465  0.026103
# 2    2010-01-07 2010-03-13  -722.855445  3010.432320 -3222.921719  0.023018
# 3    2010-01-08 2010-03-14  -701.518356  2929.690782 -3142.468224  0.018321
# 4    2010-01-12 2010-03-18  -852.398189  3546.879546 -3771.638583  0.017775
# ...         ...        ...          ...          ...          ...       ...
# 2483 2023-12-21 2024-02-24  -749.302019  3055.370405 -3262.870177  0.063671
# 2484 2023-12-22 2024-02-25  -954.581152  3862.369743 -4049.397190  0.049454
# 2485 2023-12-27 2024-03-01  -751.793196  3090.639208 -3288.970937  0.056996
# 2486 2023-12-28 2024-03-02 -1296.461996  5358.862692 -5615.953334  0.063616
# 2487 2023-12-29 2024-03-03    91.481271  -298.581353   263.190179  0.149511
#
#               aic          bic  \
# 0      559.618407   565.472138
# 1      520.847869   526.461472
# 2      457.688160   463.040729
# 3      420.044330   425.110969
# 4      391.846920   396.679674
# ...           ...          ...
# 2483  1280.236401  1289.039823
# 2484  1146.254685  1154.691238
# 2485   870.848418   878.510048
# 2486   561.489265   567.721877
# 2487   101.418143   104.691271
#
#                                                 pvalues  \
# 0     const    0.457782
# RHS1     0.453378
# RHS2     0...
# 1     const    0.479749
# RHS1     0.474949
# RHS2     0...
# 2     const    0.775476
# RHS1     0.766009
# RHS2     0...
# 3     const    0.800794
# RHS1     0.792329
# RHS2     0...
# 4     const    0.780467
# RHS1     0.772537
# RHS2     0...
# ...                                                 ...
# 2483  const    0.308709
# RHS1     0.299803
# RHS2     0...
# 2484  const    0.253764
# RHS1     0.249708
# RHS2     0...
# 2485  const    0.392417
# RHS1     0.380984
# RHS2     0...
# 2486  const    0.340089
# RHS1     0.327775
# RHS2     0...
# 2487  const    0.735918
# RHS1     0.786747
# RHS2     0...
#
#                                                 tvalues
# 0     const   -0.748423
# RHS1     0.755815
# RHS2    -0...
# 1     const   -0.712638
# RHS1     0.720491
# RHS2    -0...
# 2     const   -0.287107
# RHS1     0.299582
# RHS2    -0...
# 3     const   -0.254140
# RHS1     0.265198
# RHS2    -0...
# 4     const   -0.280930
# RHS1     0.291372
# RHS2    -0...
# ...                                                 ...
# 2483  const   -1.021759
# RHS1     1.040827
# RHS2    -1...
# 2484  const   -1.146756
# RHS1     1.156663
# RHS2    -1...
# 2485  const   -0.859285
# RHS1     0.880312
# RHS2    -0...
# 2486  const   -0.962193
# RHS1     0.987233
# RHS2    -1...
# 2487  const    0.342252
# RHS1    -0.274389
# RHS2     0...
#
# [2488 rows x 10 columns]

# %%
rolling_result['rsquared'].max()
# Out:
# 0.36521555232540004

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(rolling_result['start_date'], rolling_result['a'], label = 'a')
plt.plot(rolling_result['start_date'], rolling_result['b'], label = 'b')
plt.plot(rolling_result['start_date'], rolling_result['c'], label = 'c')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Plot of a, b, c')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ## 5. Model Validation: difference between MV and BS Deltas parabolic shape, and $E(\Delta_{imp})$ vs $\Delta_{MV}$ or $\Delta_{BS}$

# %%
df1M_ATM_regression_noinf_new.head()
# Out:
#       date_x  date_prev     expiry  strike     dte  c_delta   c_vega     c_iv  \
# 4 2010-01-05 2010-01-04 2010-06-17  1125.0  162.96  0.53264  299.723  0.21070
# 5 2010-01-05 2010-01-04 2010-06-17  1130.0  162.96  0.51981  300.441  0.20902
# 6 2010-01-05 2010-01-04 2010-06-17  1150.0  162.96  0.46705  300.172  0.20307
# 7 2010-01-05 2010-01-04 2010-06-30  1150.0  175.96  0.46909  311.834  0.20477
# 8 2010-01-06 2010-01-05 2010-06-17  1125.0  161.96  0.53469  298.850  0.20609
#
#      c_price  c_price_prev  ...  underlying_prev  S_diff    V_diff  \
# 4  80.922980     81.822963  ...          1136.40   -3.41  0.899983
# 5  78.250371     78.789793  ...          1136.40   -3.41  0.539423
# 6  66.915630     67.434904  ...          1136.40   -3.41  0.519274
# 7  70.542546     70.965083  ...          1136.40   -3.41  0.422537
# 8  81.822963     80.239608  ...          1136.99   -0.59  1.583356
#
#    1D_call_change  1D_stock_change         LHS     RHS1      RHS2  c_mv_delta  \
# 4        0.899983            -3.41  -38.438601  0.53264  0.283705   -0.019329
# 5        0.539423            -3.41  -32.638945  0.51981  0.270202    0.065517
# 6        0.519274            -3.41  -29.841347  0.46705  0.218136    0.468199
# 7        0.422537            -3.41  -28.580191  0.46909  0.220045    0.451205
# 8        1.583356            -0.59 -155.745065  0.53469  0.285893   -0.031023
#
#    diff_delta
# 4   -0.551969
# 5   -0.454293
# 6    0.001149
# 7   -0.017885
# 8   -0.565713
#
# [5 rows x 21 columns]

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_regression_noinf_new['c_delta'], df1M_ATM_regression_noinf_new['c_mv_delta'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS')
plt.legend()

plt.grid(True)
plt.show()

# %%
# the fitting line
x_fit = np.linspace(df1M_ATM_regression_noinf['RHS1'].min(), df1M_ATM_regression_noinf['RHS1'].max(), 100)
X_fit = sm.add_constant(np.column_stack((x_fit, x_fit**2)))
y_fit = model.predict(X_fit)

# %%
#plot the delta_bs vs delta_mv line and fitting line
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_regression_noinf['c_delta'], df1M_ATM_regression_noinf['c_mv_delta'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')


plt.plot(x_fit, y_fit, label = 'Quadratic Fit', color = 'red')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS')
plt.legend()

plt.grid(True)
plt.show()

# %%
df1M_ATM_regression_noinf_new
# Out:
#           date_x  date_prev     expiry  strike     dte  c_delta    c_vega  \
# 4     2010-01-05 2010-01-04 2010-06-17  1125.0  162.96  0.53264   299.723
# 5     2010-01-05 2010-01-04 2010-06-17  1130.0  162.96  0.51981   300.441
# 6     2010-01-05 2010-01-04 2010-06-17  1150.0  162.96  0.46705   300.172
# 7     2010-01-05 2010-01-04 2010-06-30  1150.0  175.96  0.46909   311.834
# 8     2010-01-06 2010-01-05 2010-06-17  1125.0  161.96  0.53469   298.850
# ...          ...        ...        ...     ...     ...      ...       ...
# 78366 2023-12-29 2023-12-28 2024-06-21  4900.0  174.96  0.48445  1310.829
# 78367 2023-12-29 2023-12-28 2024-06-21  4910.0  174.96  0.47431  1309.454
# 78368 2023-12-29 2023-12-28 2024-06-21  4920.0  174.96  0.46574  1307.397
# 78369 2023-12-29 2023-12-28 2024-06-21  4925.0  174.96  0.46011  1306.120
# 78370 2023-12-29 2023-12-28 2024-06-21  4930.0  174.96  0.45615  1304.576
#
#           c_iv     c_price  c_price_prev  ...  underlying_prev  S_diff  \
# 4      0.21070   80.922980     81.822963  ...          1136.40   -3.41
# 5      0.20902   78.250371     78.789793  ...          1136.40   -3.41
# 6      0.20307   66.915630     67.434904  ...          1136.40   -3.41
# 7      0.20477   70.542546     70.965083  ...          1136.40   -3.41
# 8      0.20609   81.822963     80.239608  ...          1136.99   -0.59
# ...        ...         ...           ...  ...              ...     ...
# 78366  0.12893  235.030683    227.597337  ...          4772.17   11.66
# 78367  0.12821  229.672226    221.519183  ...          4772.17   11.66
# 78368  0.12739  222.913124    215.352803  ...          4772.17   11.66
# 78369  0.12657  219.377309    211.653428  ...          4772.17   11.66
# 78370  0.12665  216.846741    209.380376  ...          4772.17   11.66
#
#          V_diff  1D_call_change  1D_stock_change         LHS     RHS1  \
# 4      0.899983        0.899983            -3.41  -38.438601  0.53264
# 5      0.539423        0.539423            -3.41  -32.638945  0.51981
# 6      0.519274        0.519274            -3.41  -29.841347  0.46705
# 7      0.422537        0.422537            -3.41  -28.580191  0.46909
# 8      1.583356        1.583356            -0.59 -155.745065  0.53469
# ...         ...             ...              ...         ...      ...
# 78366  7.433346        7.433346            11.66    7.388493  0.48445
# 78367  8.153043        8.153043            11.66   10.868921  0.47431
# 78368  7.560321        7.560321            11.66    8.840490  0.46574
# 78369  7.723881        7.723881            11.66    9.801467  0.46011
# 78370  7.466365        7.466365            11.66    8.933916  0.45615
#
#            RHS2  c_mv_delta  diff_delta
# 4      0.283705   -0.019329   -0.551969
# 5      0.270202    0.065517   -0.454293
# 6      0.218136    0.468199    0.001149
# 7      0.220045    0.451205   -0.017885
# 8      0.285893   -0.031023   -0.565713
# ...         ...         ...         ...
# 78366  0.234692    0.327235   -0.157215
# 78367  0.224970    0.408425   -0.065885
# 78368  0.216914    0.479116    0.013376
# 78369  0.211701    0.526533    0.066423
# 78370  0.208073    0.560298    0.104148
#
# [43853 rows x 21 columns]

# %%
def expected_change_iv(df, a, b, c):
    df['E_chg_iv'] = ((a + b * df['c_delta'] + c * df['c_delta'] ** 2)/np.sqrt(df['dte'])) * (df['1D_stock_change']/df['underlying'])
    return df

# %%
a = 357.3970
b = -1079.1668 
c = 672.4402
df = df1M_ATM_regression_noinf_new

# %%
df1M_ATM_regression_noinf_expiv = expected_change_iv(df, a, b, c)

# %%
df1M_ATM_regression_noinf_expiv
# Out:
#           date_x  date_prev     expiry  strike     dte  c_delta    c_vega  \
# 4     2010-01-05 2010-01-04 2010-06-17  1125.0  162.96  0.53264   299.723
# 5     2010-01-05 2010-01-04 2010-06-17  1130.0  162.96  0.51981   300.441
# 6     2010-01-05 2010-01-04 2010-06-17  1150.0  162.96  0.46705   300.172
# 7     2010-01-05 2010-01-04 2010-06-30  1150.0  175.96  0.46909   311.834
# 8     2010-01-06 2010-01-05 2010-06-17  1125.0  161.96  0.53469   298.850
# ...          ...        ...        ...     ...     ...      ...       ...
# 78366 2023-12-29 2023-12-28 2024-06-21  4900.0  174.96  0.48445  1310.829
# 78367 2023-12-29 2023-12-28 2024-06-21  4910.0  174.96  0.47431  1309.454
# 78368 2023-12-29 2023-12-28 2024-06-21  4920.0  174.96  0.46574  1307.397
# 78369 2023-12-29 2023-12-28 2024-06-21  4925.0  174.96  0.46011  1306.120
# 78370 2023-12-29 2023-12-28 2024-06-21  4930.0  174.96  0.45615  1304.576
#
#           c_iv     c_price  c_price_prev  ...  S_diff    V_diff  \
# 4      0.21070   80.922980     81.822963  ...   -3.41  0.899983
# 5      0.20902   78.250371     78.789793  ...   -3.41  0.539423
# 6      0.20307   66.915630     67.434904  ...   -3.41  0.519274
# 7      0.20477   70.542546     70.965083  ...   -3.41  0.422537
# 8      0.20609   81.822963     80.239608  ...   -0.59  1.583356
# ...        ...         ...           ...  ...     ...       ...
# 78366  0.12893  235.030683    227.597337  ...   11.66  7.433346
# 78367  0.12821  229.672226    221.519183  ...   11.66  8.153043
# 78368  0.12739  222.913124    215.352803  ...   11.66  7.560321
# 78369  0.12657  219.377309    211.653428  ...   11.66  7.723881
# 78370  0.12665  216.846741    209.380376  ...   11.66  7.466365
#
#        1D_call_change  1D_stock_change         LHS     RHS1      RHS2  \
# 4            0.899983            -3.41  -38.438601  0.53264  0.283705
# 5            0.539423            -3.41  -32.638945  0.51981  0.270202
# 6            0.519274            -3.41  -29.841347  0.46705  0.218136
# 7            0.422537            -3.41  -28.580191  0.46909  0.220045
# 8            1.583356            -0.59 -155.745065  0.53469  0.285893
# ...               ...              ...         ...      ...       ...
# 78366        7.433346            11.66    7.388493  0.48445  0.234692
# 78367        8.153043            11.66   10.868921  0.47431  0.224970
# 78368        7.560321            11.66    8.840490  0.46574  0.216914
# 78369        7.723881            11.66    9.801467  0.46011  0.211701
# 78370        7.466365            11.66    8.933916  0.45615  0.208073
#
#        c_mv_delta  diff_delta  E_chg_iv
# 4       -0.019329   -0.551969  0.006280
# 5        0.065517   -0.454293  0.005156
# 6        0.468199    0.001149 -0.000013
# 7        0.451205   -0.017885  0.000196
# 8       -0.031023   -0.565713  0.001117
# ...           ...         ...       ...
# 78366    0.327235   -0.157215 -0.001398
# 78367    0.408425   -0.065885 -0.000587
# 78368    0.479116    0.013376  0.000119
# 78369    0.526533    0.066423  0.000593
# 78370    0.560298    0.104148  0.000931
#
# [43853 rows x 22 columns]

# %%
# plot expected changes in implied vol wrt delta_bs
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_regression_noinf_expiv['E_chg_iv'], df1M_ATM_regression_noinf_expiv['c_delta'],label = 'Expected Change in IV vs BS Delta', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('BS Delta')
plt.title('Plot of Expected Change in IV vs BS Delta')
plt.legend()

plt.grid(True)
plt.show()

# %%
# plot expected changes in implied vol wrt delta_mv
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_regression_noinf_expiv['E_chg_iv'], df1M_ATM_regression_noinf_expiv['c_mv_delta'],label = 'Expected Change in IV vs MV Delta', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('MV Delta')
plt.title('Plot of Expected Change in IV vs MV Delta')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Hedging Gain

# %%
df1M_ATM_regression_noinf_expiv[df1M_ATM_regression_noinf_expiv['E_chg_iv']<0]
# Out:
#           date_x  date_prev     expiry  strike     dte  c_delta    c_vega  \
# 6     2010-01-05 2010-01-04 2010-06-17  1150.0  162.96  0.46705   300.172
# 10    2010-01-06 2010-01-05 2010-06-17  1150.0  161.96  0.46616   299.445
# 25    2010-01-12 2010-01-11 2010-06-17  1130.0  155.96  0.52220   294.424
# 33    2010-01-14 2010-01-13 2010-06-17  1160.0  153.96  0.46570   295.105
# 47    2010-01-21 2010-01-20 2010-06-17  1125.0  146.96  0.47276   279.990
# ...          ...        ...        ...     ...     ...      ...       ...
# 78363 2023-12-29 2023-12-28 2024-06-21  4875.0  174.96  0.50733  1310.904
# 78364 2023-12-29 2023-12-28 2024-06-21  4880.0  174.96  0.50299  1311.306
# 78365 2023-12-29 2023-12-28 2024-06-21  4890.0  174.96  0.49337  1311.345
# 78366 2023-12-29 2023-12-28 2024-06-21  4900.0  174.96  0.48445  1310.829
# 78367 2023-12-29 2023-12-28 2024-06-21  4910.0  174.96  0.47431  1309.454
#
#           c_iv     c_price  c_price_prev  ...  S_diff    V_diff  \
# 6      0.20307   66.915630     67.434904  ...   -3.41  0.519274
# 10     0.19896   67.434904     65.990706  ...   -0.59  1.444198
# 25     0.19976   80.180969     73.708579  ...   10.72  6.472390
# 33     0.18633   60.915059     61.008712  ...   -2.67  0.093653
# 47     0.20358   74.085935     64.690117  ...   21.84  9.395819
# ...        ...         ...           ...  ...     ...       ...
# 78363  0.13071  250.597304    243.053024  ...   11.66  7.544280
# 78364  0.13061  248.388078    240.324888  ...   11.66  8.063190
# 78365  0.12935  241.251842    233.277216  ...   11.66  7.974626
# 78366  0.12893  235.030683    227.597337  ...   11.66  7.433346
# 78367  0.12821  229.672226    221.519183  ...   11.66  8.153043
#
#        1D_call_change  1D_stock_change         LHS     RHS1      RHS2  \
# 6            0.519274            -3.41  -29.841347  0.46705  0.218136
# 10           1.444198            -0.59 -140.734492  0.46616  0.217305
# 25           6.472390            10.72    3.968050  0.52220  0.272693
# 33           0.093653            -2.67  -24.124850  0.46570  0.216876
# 47           9.395819            21.84   -2.096300  0.47276  0.223502
# ...               ...              ...         ...      ...       ...
# 78363        7.544280            11.66    6.742900  0.50733  0.257384
# 78364        8.063190            11.66    9.097766  0.50299  0.252999
# 78365        7.974626            11.66    9.195182  0.49337  0.243414
# 78366        7.433346            11.66    7.388493  0.48445  0.234692
# 78367        8.153043            11.66   10.868921  0.47431  0.224970
#
#        c_mv_delta  diff_delta  E_chg_iv
# 6        0.468199    0.001149 -0.000013
# 10       0.475629    0.009469 -0.000019
# 25       0.054049   -0.468151 -0.017045
# 33       0.479514    0.013814 -0.000125
# 47       0.422055   -0.050705 -0.003955
# ...           ...         ...       ...
# 78363    0.154696   -0.352634 -0.003137
# 78364    0.186204   -0.316786 -0.002817
# 78365    0.258150   -0.235220 -0.002091
# 78366    0.327235   -0.157215 -0.001398
# 78367    0.408425   -0.065885 -0.000587
#
# [17212 rows x 22 columns]

# %%
df1M_ATM_regression_noinf_expiv[df1M_ATM_regression_noinf_expiv['E_chg_iv']>=0]
# Out:
#           date_x  date_prev     expiry  strike     dte  c_delta    c_vega  \
# 4     2010-01-05 2010-01-04 2010-06-17  1125.0  162.96  0.53264   299.723
# 5     2010-01-05 2010-01-04 2010-06-17  1130.0  162.96  0.51981   300.441
# 7     2010-01-05 2010-01-04 2010-06-30  1150.0  175.96  0.46909   311.834
# 8     2010-01-06 2010-01-05 2010-06-17  1125.0  161.96  0.53469   298.850
# 9     2010-01-06 2010-01-05 2010-06-17  1130.0  161.96  0.52129   299.681
# ...          ...        ...        ...     ...     ...      ...       ...
# 78340 2023-12-28 2023-12-27 2024-06-21  4930.0  175.96  0.47377  1317.997
# 78353 2023-12-29 2023-12-28 2024-05-17  4900.0  139.96  0.45964  1170.301
# 78368 2023-12-29 2023-12-28 2024-06-21  4920.0  174.96  0.46574  1307.397
# 78369 2023-12-29 2023-12-28 2024-06-21  4925.0  174.96  0.46011  1306.120
# 78370 2023-12-29 2023-12-28 2024-06-21  4930.0  174.96  0.45615  1304.576
#
#           c_iv     c_price  c_price_prev  ...  S_diff    V_diff  \
# 4      0.21070   80.922980     81.822963  ...   -3.41  0.899983
# 5      0.20902   78.250371     78.789793  ...   -3.41  0.539423
# 7      0.20477   70.542546     70.965083  ...   -3.41  0.422537
# 8      0.20609   81.822963     80.239608  ...   -0.59  1.583356
# 9      0.20534   78.789793     77.528804  ...   -0.59  1.260989
# ...        ...         ...           ...  ...     ...       ...
# 78340  0.12617  217.182834    216.846741  ...   -1.33  0.336093
# 78353  0.12272  188.242858    179.884981  ...   11.66  8.357877
# 78368  0.12739  222.913124    215.352803  ...   11.66  7.560321
# 78369  0.12657  219.377309    211.653428  ...   11.66  7.723881
# 78370  0.12665  216.846741    209.380376  ...   11.66  7.466365
#
#        1D_call_change  1D_stock_change         LHS     RHS1      RHS2  \
# 4            0.899983            -3.41  -38.438601  0.53264  0.283705
# 5            0.539423            -3.41  -32.638945  0.51981  0.270202
# 7            0.422537            -3.41  -28.580191  0.46909  0.220045
# 8            1.583356            -0.59 -155.745065  0.53469  0.285893
# 9            1.260989            -0.59 -128.298719  0.52129  0.271743
# ...               ...              ...         ...      ...       ...
# 78340        0.336093            -1.33  -34.967624  0.47377  0.224458
# 78353        8.357877            11.66   12.436036  0.45964  0.211269
# 78368        7.560321            11.66    8.840490  0.46574  0.216914
# 78369        7.723881            11.66    9.801467  0.46011  0.211701
# 78370        7.466365            11.66    8.933916  0.45615  0.208073
#
#        c_mv_delta  diff_delta  E_chg_iv
# 4       -0.019329   -0.551969  0.006280
# 5        0.065517   -0.454293  0.005156
# 7        0.451205   -0.017885  0.000196
# 8       -0.031023   -0.565713  0.001117
# 9        0.056488   -0.464802  0.000915
# ...           ...         ...       ...
# 78340    0.412581   -0.061189  0.000062
# 78353    0.530660    0.071020  0.000708
# 78368    0.479116    0.013376  0.000119
# 78369    0.526533    0.066423  0.000593
# 78370    0.560298    0.104148  0.000931
#
# [26641 rows x 22 columns]

# %%
def delta_mv_residual_sum(df, a, b, c):
    df['mv_error'] = df['1D_call_change'] - df['1D_stock_change'] * df['c_delta'] - (df['c_vega']/np.sqrt(df['dte'])) * (df['1D_stock_change']/df['underlying']) * (a + b * df['c_delta'] + c * df['c_delta'] ** 2)
    df['bs_error'] = df['1D_call_change'] - df['c_delta'] * df['1D_stock_change']
    return df

# %%
a = 357.3970
b = -1079.1668 
c = 672.4402
df = df1M_ATM_regression_noinf_new

# %%
delta_mv_residual_sum(df, a, b, c)
# Out:
#           date_x  date_prev     expiry  strike     dte  c_delta    c_vega  \
# 4     2010-01-05 2010-01-04 2010-06-17  1125.0  162.96  0.53264   299.723
# 5     2010-01-05 2010-01-04 2010-06-17  1130.0  162.96  0.51981   300.441
# 6     2010-01-05 2010-01-04 2010-06-17  1150.0  162.96  0.46705   300.172
# 7     2010-01-05 2010-01-04 2010-06-30  1150.0  175.96  0.46909   311.834
# 8     2010-01-06 2010-01-05 2010-06-17  1125.0  161.96  0.53469   298.850
# ...          ...        ...        ...     ...     ...      ...       ...
# 78366 2023-12-29 2023-12-28 2024-06-21  4900.0  174.96  0.48445  1310.829
# 78367 2023-12-29 2023-12-28 2024-06-21  4910.0  174.96  0.47431  1309.454
# 78368 2023-12-29 2023-12-28 2024-06-21  4920.0  174.96  0.46574  1307.397
# 78369 2023-12-29 2023-12-28 2024-06-21  4925.0  174.96  0.46011  1306.120
# 78370 2023-12-29 2023-12-28 2024-06-21  4930.0  174.96  0.45615  1304.576
#
#           c_iv     c_price  c_price_prev  ...  1D_call_change  \
# 4      0.21070   80.922980     81.822963  ...        0.899983
# 5      0.20902   78.250371     78.789793  ...        0.539423
# 6      0.20307   66.915630     67.434904  ...        0.519274
# 7      0.20477   70.542546     70.965083  ...        0.422537
# 8      0.20609   81.822963     80.239608  ...        1.583356
# ...        ...         ...           ...  ...             ...
# 78366  0.12893  235.030683    227.597337  ...        7.433346
# 78367  0.12821  229.672226    221.519183  ...        8.153043
# 78368  0.12739  222.913124    215.352803  ...        7.560321
# 78369  0.12657  219.377309    211.653428  ...        7.723881
# 78370  0.12665  216.846741    209.380376  ...        7.466365
#
#        1D_stock_change         LHS     RHS1      RHS2  c_mv_delta  diff_delta  \
# 4                -3.41  -38.438601  0.53264  0.283705   -0.019329   -0.551969
# 5                -3.41  -32.638945  0.51981  0.270202    0.065517   -0.454293
# 6                -3.41  -29.841347  0.46705  0.218136    0.468199    0.001149
# 7                -3.41  -28.580191  0.46909  0.220045    0.451205   -0.017885
# 8                -0.59 -155.745065  0.53469  0.285893   -0.031023   -0.565713
# ...                ...         ...      ...       ...         ...         ...
# 78366            11.66    7.388493  0.48445  0.234692    0.327235   -0.157215
# 78367            11.66   10.868921  0.47431  0.224970    0.408425   -0.065885
# 78368            11.66    8.840490  0.46574  0.216914    0.479116    0.013376
# 78369            11.66    9.801467  0.46011  0.211701    0.526533    0.066423
# 78370            11.66    8.933916  0.45615  0.208073    0.560298    0.104148
#
#        E_chg_iv  mv_error  bs_error
# 4      0.006280  0.834072  2.716286
# 5      0.005156  0.762837  2.311975
# 6     -0.000013  2.115833  2.111915
# 7      0.000196  1.961147  2.022134
# 8      0.001117  1.565052  1.898823
# ...         ...       ...       ...
# 78366 -0.001398  3.617787  1.784659
# 78367 -0.000587  3.390803  2.622588
# 78368  0.000119  1.973830  2.129792
# 78369  0.000593  1.584504  2.358998
# 78370  0.000931  0.933285  2.147656
#
# [43853 rows x 24 columns]

# %%
df1M_ATM_regression_noinf_new_err = delta_mv_residual_sum(df, a, b, c)

# %%
SSE_mv = (df1M_ATM_regression_noinf_new_err['mv_error'] ** 2).sum()
SSE_bs = (df1M_ATM_regression_noinf_new_err['bs_error'] ** 2).sum()
gain_ATM1M = 1 - SSE_mv/SSE_bs

# %%
gain_ATM1M
# Out:
# 0.5935154763890741

# %% [markdown]
# ## Apply the rolling window calibrated $a,b,c$ - daily frequency

# %%
def rolling_quadratic_regression(df1, window_size_days=1095):  # ~3 years (365 * 3)
    min_date = df1['date'].min()
    max_date = df1['date'].max()
    window_size = pd.Timedelta(days=window_size_days)
    
    results = []

    # Start rolling from the first date after the initial 3 years
    start_date = min_date + window_size
    while start_date <= max_date:
        end_date = start_date
        window_start_date = start_date - window_size

        # Select data within the 3-year window
        window_data = df1[(df1['date'] > window_start_date) & (df1['date'] <= end_date)]
        
        if len(window_data) > 1:  # At least two data points needed for regression
            y = window_data['LHS']
            X = window_data[['RHS1', 'RHS2']]
            X = sm.add_constant(X)

            # Fit the quadratic regression model
            model = sm.OLS(y, X).fit()

            # Store the coefficients for the current date
            results.append({
                'date': end_date,
                'a': model.params['const'],
                'b': model.params['RHS1'],
                'c': model.params['RHS2']
            })
        
        # Move forward by one day
        start_date = start_date + pd.DateOffset(days=1)

    return pd.DataFrame(results)

# # Apply the rolling quadratic regression
# coefficients_df1 = rolling_quadratic_regression(df1)

# # Discard results for the first 3 years
# coefficients_df1 = coefficients_df1[coefficients_df1['date'] > df1['date'].min() + pd.DateOffset(years=3)]

# # Display the resulting coefficients DataFrame
# print(coefficients_df1)

# %%
df1M_ATM_calibrating = df1M_ATM_regression_noinf
df1M_ATM_calibrating = df1M_ATM_calibrating.rename(columns = {'date_x':'date'})

# %%
df1M_ATM_calibrating.head()
# Out:
#         date  date_prev     expiry  strike     dte  c_delta   c_vega     c_iv  \
# 4 2010-01-05 2010-01-04 2010-06-17  1125.0  162.96  0.53264  299.723  0.21070
# 5 2010-01-05 2010-01-04 2010-06-17  1130.0  162.96  0.51981  300.441  0.20902
# 6 2010-01-05 2010-01-04 2010-06-17  1150.0  162.96  0.46705  300.172  0.20307
# 7 2010-01-05 2010-01-04 2010-06-30  1150.0  175.96  0.46909  311.834  0.20477
# 8 2010-01-06 2010-01-05 2010-06-17  1125.0  161.96  0.53469  298.850  0.20609
#
#      c_price  c_price_prev  ...  1D_call_change  1D_stock_change         LHS  \
# 4  80.922980     81.822963  ...        0.899983            -3.41  -38.438601
# 5  78.250371     78.789793  ...        0.539423            -3.41  -32.638945
# 6  66.915630     67.434904  ...        0.519274            -3.41  -29.841347
# 7  70.542546     70.965083  ...        0.422537            -3.41  -28.580191
# 8  81.822963     80.239608  ...        1.583356            -0.59 -155.745065
#
#       RHS1      RHS2  c_mv_delta  diff_delta  E_chg_iv  mv_error  bs_error
# 4  0.53264  0.283705   -0.019329   -0.551969  0.006280  0.834072  2.716286
# 5  0.51981  0.270202    0.065517   -0.454293  0.005156  0.762837  2.311975
# 6  0.46705  0.218136    0.468199    0.001149 -0.000013  2.115833  2.111915
# 7  0.46909  0.220045    0.451205   -0.017885  0.000196  1.961147  2.022134
# 8  0.53469  0.285893   -0.031023   -0.565713  0.001117  1.565052  1.898823
#
# [5 rows x 24 columns]

# %%
df1M_ATM_calibrated = rolling_quadratic_regression(df1M_ATM_calibrating)

# %%
df1M_ATM_calibrated.head()
# Out:
#         date            a             b             c
# 0 2013-01-04 -4978.905815  19733.191394 -19639.386855
# 1 2013-01-05 -4938.078512  19572.211727 -19479.655904
# 2 2013-01-06 -4947.844103  19612.512563 -19521.083784
# 3 2013-01-07 -4956.351328  19647.574082 -19557.163121
# 4 2013-01-08 -4980.960028  19744.805361 -19652.497276

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated['date'], df1M_ATM_calibrated['a'], label = 'a')
plt.plot(df1M_ATM_calibrated['date'], df1M_ATM_calibrated['b'], label = 'b')
plt.plot(df1M_ATM_calibrated['date'], df1M_ATM_calibrated['c'], label = 'c')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Plot of a, b, c')
plt.legend()

plt.grid(True)
plt.show()

# %%
df1M_ATM_calibrated_abc = df1M_ATM_regression_noinf_new.merge(df1M_ATM_calibrated, left_on = ['date_x'], right_on = ['date'], how = 'left')

# %%
def calibration_apply(df):
    df['c_mv_delta_calibrated'] = df['a'] + df['b'] * df['c_delta'] + df['c'] * df['c_delta'] ** 2
    df['diff_delta_calibrated'] = df['c_mv_delta_calibrated'] - df['c_delta']
    df['E_chg_iv_calibrate'] = (df['a'] + df['b'] * df['c_delta'] + df['c'] * df['c_delta'] ** 2)/np.sqrt(df['dte']) * (df['1D_stock_change']/df['underlying'])
    df['mv_error_calibrate'] = df['1D_call_change'] - df['1D_stock_change'] * df['c_delta'] - (df['c_vega']/np.sqrt(df['dte'])) * (df['1D_stock_change']/df['underlying']) * (df['a'] + df['b'] * df['c_delta'] + df['c'] * df['c_delta'] ** 2)
    df['bs_error_calibrate'] = df['1D_call_change'] - df['c_delta'] * df['1D_stock_change']
    return df

# %%
df1M_ATM_calibrated_abc_new = calibration_apply(df1M_ATM_calibrated_abc)

# %%
df1M_ATM_calibrated_abc_new = df1M_ATM_calibrated_abc_new[~(df1M_ATM_calibrated_abc_new['a'].isna())]

# %%
df1M_ATM_calibrated_abc_new.head()
# Out:
#          date_x  date_prev     expiry  strike     dte  c_delta   c_vega  \
# 1096 2013-01-04 2013-01-03 2013-06-20  1445.0  166.96  0.54164  387.324
# 1097 2013-01-04 2013-01-03 2013-06-20  1450.0  166.96  0.52866  388.742
# 1098 2013-01-04 2013-01-03 2013-06-28  1450.0  174.96  0.52854  397.944
# 1099 2013-01-08 2013-01-07 2013-06-20  1445.0  162.96  0.52382  384.066
# 1100 2013-01-08 2013-01-07 2013-06-20  1450.0  162.96  0.50980  384.751
#
#          c_iv    c_price  c_price_prev  ...  bs_error       date            a  \
# 1096  0.16142  82.345319     87.002699  ...  8.465110 2013-01-04 -4978.905815
# 1097  0.16010  79.048135     83.815349  ...  8.483693 2013-01-04 -4978.905815
# 1098  0.16043  81.580147     85.758801  ...  7.894291 2013-01-04 -4978.905815
# 1099  0.15662  82.302198     78.796387  ...  1.054333 2013-01-08 -4980.960028
# 1100  0.15471  79.134249     75.429071  ...  1.319314 2013-01-08 -4980.960028
#
#                  b             c  c_mv_delta_calibrated  \
# 1096  19733.191394 -19639.386855             -52.303339
# 1097  19733.191394 -19639.386855             -35.600099
# 1098  19733.191394 -19639.386855             -35.476551
# 1099  19744.805361 -19652.497276             -30.633566
# 1100  19744.805361 -19652.497276             -22.664473
#
#       diff_delta_calibrated  E_chg_iv_calibrate  mv_error_calibrate  \
# 1096             -52.844979            0.019503            0.911113
# 1097             -36.128759            0.013275            3.323266
# 1098             -36.005091            0.012923            2.751804
# 1099             -31.157386           -0.007683            4.005146
# 1100             -23.174273           -0.005684            3.506388
#
#       bs_error_calibrate
# 1096            8.465110
# 1097            8.483693
# 1098            7.894291
# 1099            1.054333
# 1100            1.319314
#
# [5 rows x 33 columns]

# %%
SSE_mv_calibrated = (df1M_ATM_calibrated_abc_new['mv_error_calibrate'] ** 2).sum()
SSE_bs_calibrated = (df1M_ATM_calibrated_abc_new['bs_error_calibrate'] ** 2).sum()
gain_ATM1M_calibrated = 1 - SSE_mv_calibrated/SSE_bs_calibrated

# %%
gain_ATM1M_calibrated
# Out:
# 0.5373763081917386

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_abc_new['c_delta'], df1M_ATM_calibrated_abc_new['c_mv_delta'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS (Calibrated by Rolling Estimation of Daily Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# the fitting line
x_fit = np.linspace(df1M_ATM_calibrated_abc_new['RHS1'].min(), df1M_ATM_calibrated_abc_new['RHS1'].max(), 100)
X_fit = sm.add_constant(np.column_stack((x_fit, x_fit**2)))
y_fit = model.predict(X_fit)

#plot the delta_bs vs delta_mv line and fitting line
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_abc_new['c_delta'], df1M_ATM_calibrated_abc_new['c_mv_delta'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')


plt.plot(x_fit, y_fit, label = 'Quadratic Fit', color = 'red')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS (Calibrated by Rolling Estimation of Daily Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# plot expected changes in implied vol wrt delta_bs
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_abc_new['E_chg_iv'], df1M_ATM_calibrated_abc_new['c_delta'],label = 'Expected Change in IV vs BS Delta', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('BS Delta')
plt.title('Plot of Expected Change in IV vs BS Delta (Calibrated by Rolling Estimation of Daily Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# plot expected changes in implied vol wrt delta_mv
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_abc_new['E_chg_iv'], df1M_ATM_calibrated_abc_new['c_mv_delta'],label = 'Expected Change in IV vs MV Delta ', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('MV Delta')
plt.title('Plot of Expected Change in IV vs MV Delta (Calibrated by Rolling Estimation of Daily Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ## Apply the rolling window calibrated $a,b,c$ - monthly frequency

# %%
from pandas.tseries.offsets import MonthEnd

# %%
def rolling_quadratic_regression_monthly(df1, window_size_days=1095):  # ~3 years (365 * 3)
    min_date = df1['date'].min()
    max_date = df1['date'].max()
    window_size = pd.Timedelta(days=window_size_days)
    
    results = []

    # Start rolling from the first date after the initial 3 years
    start_date = min_date + window_size
    while start_date <= max_date:
        end_date = start_date
        window_start_date = start_date - window_size

        # Select data within the 3-year window
        window_data = df1[(df1['date'] > window_start_date) & (df1['date'] <= end_date)]
        
        if len(window_data) > 1:  # At least two data points needed for regression
            y = window_data['LHS']
            X = window_data[['RHS1', 'RHS2']]
            X = sm.add_constant(X)

            # Fit the quadratic regression model
            model = sm.OLS(y, X).fit()

            # Apply the coefficient to the next month
            next_month_start = end_date + pd.DateOffset(days=1)
            next_month_end = next_month_start + MonthEnd(1)

            days_in_next_month = pd.date_range(next_month_start, next_month_end)

            # Store the coefficients for the current date
            results.append({
                'date': end_date,
                'a': model.params['const'],
                'b': model.params['RHS1'],
                'c': model.params['RHS2']
            })
        
        # Move forward by one day
        start_date = start_date + pd.DateOffset(months=1)

    return pd.DataFrame(results)

# %%
df1M_ATM_calibrated_monthly = rolling_quadratic_regression_monthly(df1M_ATM_calibrating)

# %%
df1M_ATM_calibrated_monthly.head()
# Out:
#         date            a             b             c
# 0 2013-01-04 -4978.905815  19733.191394 -19639.386855
# 1 2013-02-04 -4780.926388  18933.740150 -18833.966704
# 2 2013-03-04 -4644.690233  18396.419906 -18306.508264
# 3 2013-04-04 -3703.766193  14737.150948 -14752.381537
# 4 2013-05-04 -3834.141903  15254.730838 -15262.813154

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_monthly['date'], df1M_ATM_calibrated_monthly['a'], label = 'a')
plt.plot(df1M_ATM_calibrated_monthly['date'], df1M_ATM_calibrated_monthly['b'], label = 'b')
plt.plot(df1M_ATM_calibrated_monthly['date'], df1M_ATM_calibrated_monthly['c'], label = 'c')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Plot of a, b, c')
plt.legend()

plt.grid(True)
plt.show()

# %%
df1M_ATM_calibrated_monthly = df1M_ATM_calibrated_monthly[df1M_ATM_calibrated_monthly['date'] > df1M_ATM_calibrated_monthly['date'].min() + pd.DateOffset(years=3)]

# %%
df1M_ATM_calibrated_monthly_abc = df1M_ATM_regression_noinf_new.merge(df1M_ATM_calibrated_monthly, left_on = ['date_x'], right_on = ['date'], how = 'left')

# %%
df1M_ATM_calibrated_monthly_abc['a'] = df1M_ATM_calibrated_monthly_abc['a'].fillna(method = 'ffill')
df1M_ATM_calibrated_monthly_abc['b'] = df1M_ATM_calibrated_monthly_abc['b'].fillna(method = 'ffill')
df1M_ATM_calibrated_monthly_abc['c'] = df1M_ATM_calibrated_monthly_abc['c'].fillna(method = 'ffill')
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/679602923.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1M_ATM_calibrated_monthly_abc['a'] = df1M_ATM_calibrated_monthly_abc['a'].fillna(method = 'ffill')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/679602923.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1M_ATM_calibrated_monthly_abc['b'] = df1M_ATM_calibrated_monthly_abc['b'].fillna(method = 'ffill')
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/679602923.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1M_ATM_calibrated_monthly_abc['c'] = df1M_ATM_calibrated_monthly_abc['c'].fillna(method = 'ffill')

# %%
df1M_ATM_calibrated_monthly_abc = df1M_ATM_calibrated_monthly_abc[~df1M_ATM_calibrated_monthly_abc['a'].isna()]

# %%
df1M_ATM_calibrated_monthly_abc_new = calibration_apply(df1M_ATM_calibrated_monthly_abc)
# Out:
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3158627104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['c_mv_delta_calibrated'] = df['a'] + df['b'] * df['c_delta'] + df['c'] * df['c_delta'] ** 2
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3158627104.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diff_delta_calibrated'] = df['c_mv_delta_calibrated'] - df['c_delta']
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3158627104.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['E_chg_iv_calibrate'] = (df['a'] + df['b'] * df['c_delta'] + df['c'] * df['c_delta'] ** 2)/np.sqrt(df['dte']) * (df['1D_stock_change']/df['underlying'])
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3158627104.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mv_error_calibrate'] = df['1D_call_change'] - df['1D_stock_change'] * df['c_delta'] - (df['c_vega']/np.sqrt(df['dte'])) * (df['1D_stock_change']/df['underlying']) * (df['a'] + df['b'] * df['c_delta'] + df['c'] * df['c_delta'] ** 2)
# /var/folders/xb/t7lfmnsd0f588j8mmvp38hd00000gn/T/ipykernel_1381/3158627104.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bs_error_calibrate'] = df['1D_call_change'] - df['c_delta'] * df['1D_stock_change']

# %%
df1M_ATM_calibrated_monthly_abc_new
# Out:
#           date_x  date_prev     expiry  strike     dte  c_delta    c_vega  \
# 3077  2016-02-04 2016-02-03 2016-06-16  1900.0  132.96  0.52161   456.320
# 3078  2016-02-04 2016-02-03 2016-06-16  1910.0  132.96  0.50415   457.193
# 3079  2016-02-04 2016-02-03 2016-06-16  1920.0  132.96  0.48594   457.206
# 3080  2016-02-04 2016-02-03 2016-06-16  1925.0  132.96  0.47614   456.813
# 3081  2016-02-04 2016-02-03 2016-06-16  1930.0  132.96  0.46702   456.254
# ...          ...        ...        ...     ...     ...      ...       ...
# 43848 2023-12-29 2023-12-28 2024-06-21  4900.0  174.96  0.48445  1310.829
# 43849 2023-12-29 2023-12-28 2024-06-21  4910.0  174.96  0.47431  1309.454
# 43850 2023-12-29 2023-12-28 2024-06-21  4920.0  174.96  0.46574  1307.397
# 43851 2023-12-29 2023-12-28 2024-06-21  4925.0  174.96  0.46011  1306.120
# 43852 2023-12-29 2023-12-28 2024-06-21  4930.0  174.96  0.45615  1304.576
#
#           c_iv     c_price  c_price_prev  ...  bs_error       date  \
# 3077   0.20788  117.831753    123.176918  ...  6.784809 2016-02-04
# 3078   0.20526  111.519591    116.863142  ...  6.735005 2016-02-04
# 3079   0.20213  105.563937    110.399425  ...  6.176683 2016-02-04
# 3080   0.20020  102.241772    107.016573  ...  6.088947 2016-02-04
# 3081   0.19920   99.203405    104.179459  ...  6.265028 2016-02-04
# ...        ...         ...           ...  ...       ...        ...
# 43848  0.12893  235.030683    227.597337  ...  1.784659        NaT
# 43849  0.12821  229.672226    221.519183  ...  2.622588        NaT
# 43850  0.12739  222.913124    215.352803  ...  2.129792        NaT
# 43851  0.12657  219.377309    211.653428  ...  2.358998        NaT
# 43852  0.12665  216.846741    209.380376  ...  2.147656        NaT
#
#                  a            b            c  c_mv_delta_calibrated  \
# 3077   1053.182035 -3990.597512  3656.266117             -33.567646
# 3078   1053.182035 -3990.597512  3656.266117             -29.374697
# 3079   1053.182035 -3990.597512  3656.266117             -22.626708
# 3080   1053.182035 -3990.597512  3656.266117             -17.991534
# 3081   1053.182035 -3990.597512  3656.266117             -13.047093
# ...            ...          ...          ...                    ...
# 43848   236.045735  -583.355903   175.856198              -5.289024
# 43849   236.045735  -583.355903   175.856198              -1.083439
# 43850   236.045735  -583.355903   175.856198               2.499184
# 43851   236.045735  -583.355903   175.856198               4.866821
# 43852   236.045735  -583.355903   175.856198               6.538835
#
#        diff_delta_calibrated  E_chg_iv_calibrate  mv_error_calibrate  \
# 3077              -34.089256            0.004201            4.867862
# 3078              -29.878847            0.003676            5.054294
# 3079              -23.112648            0.002832            4.882031
# 3080              -18.467674            0.002252            5.060394
# 3081              -13.514113            0.001633            5.520056
# ...                      ...                 ...                 ...
# 43848              -5.773474           -0.000975            3.062201
# 43849              -1.557749           -0.000200            2.884014
# 43850               2.033444            0.000461            1.527706
# 43851               4.406711            0.000897            1.187661
# 43852               6.082685            0.001205            0.575762
#
#        bs_error_calibrate
# 3077             6.784809
# 3078             6.735005
# 3079             6.176683
# 3080             6.088947
# 3081             6.265028
# ...                   ...
# 43848            1.784659
# 43849            2.622588
# 43850            2.129792
# 43851            2.358998
# 43852            2.147656
#
# [40776 rows x 33 columns]

# %%
SSE_mv_calibrated_month = (df1M_ATM_calibrated_monthly_abc_new['mv_error_calibrate'] ** 2).sum()
SSE_bs_calibrated_month = (df1M_ATM_calibrated_monthly_abc_new['bs_error_calibrate'] ** 2).sum()
gain_ATM1M_calibrated_month = 1 - SSE_mv_calibrated_month/SSE_bs_calibrated_month

# %%
gain_ATM1M_calibrated_month
# Out:
# 0.5245452891920424

# %%
#plot the term structure
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_monthly_abc_new['c_delta'], df1M_ATM_calibrated_monthly_abc_new['c_mv_delta'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS (Calibrated by Rolling Estimation of Monthly Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# the fitting line
x_fit = np.linspace(df1M_ATM_calibrated_monthly_abc_new['RHS1'].min(), df1M_ATM_calibrated_monthly_abc_new['RHS1'].max(), 100)
X_fit = sm.add_constant(np.column_stack((x_fit, x_fit**2)))
y_fit = model.predict(X_fit)

#plot the delta_bs vs delta_mv line and fitting line
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_monthly_abc_new['c_delta'], df1M_ATM_calibrated_monthly_abc_new['c_mv_delta'],label = 'delta_MV vs delta_BS', linestyle = '', marker = 'o', color = 'blue')


plt.plot(x_fit, y_fit, label = 'Quadratic Fit', color = 'red')

plt.xlabel('c_bs_delta')
plt.ylabel('c_mv_delta')
plt.title('Plot of delta_MV vs delta_BS (Calibrated by Rolling Estimation of Monthly Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# plot expected changes in implied vol wrt delta_bs
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_monthly_abc_new['E_chg_iv'], df1M_ATM_calibrated_monthly_abc_new['c_delta'],label = 'Expected Change in IV vs BS Delta', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('BS Delta')
plt.title('Plot of Expected Change in IV vs BS Delta (Calibrated by Rolling Estimation of Monthly Frequency)')
plt.legend()

plt.grid(True)
plt.show()

# %%
# plot expected changes in implied vol wrt delta_mv
plt.figure(figsize = (10,6))

plt.plot(df1M_ATM_calibrated_monthly_abc_new['E_chg_iv'], df1M_ATM_calibrated_monthly_abc_new['c_mv_delta'],label = 'Expected Change in IV vs MV Delta ', linestyle = '', marker = 'o', color = 'blue')

plt.xlabel('Expected Change in IV')
plt.ylabel('MV Delta')
plt.title('Plot of Expected Change in IV vs MV Delta (Calibrated by Rolling Estimation of Monthly Frequency)')
plt.legend()

plt.grid(True)
plt.show()
